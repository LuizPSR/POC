# %%
import numpy as np
import pandas as pd
import time

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

import torch
from torch import nn, optim
from torch.utils.data import TensorDataset, DataLoader
import torch.nn.functional as F

from torchinfo import summary

torch.manual_seed(123)
np.random.seed(123)

if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

torch.set_default_device(device)
print(f"Using {device}")
# Out:
# Using cpu

# %%
from bokeh.io import show, output_notebook
from bokeh.models  import TabPanel, Tabs, LegendItem, Legend
from bokeh.plotting import figure, Row
from bokeh.layouts import column

output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c17891b3-63f6-4fbf-81fb-f125fb9b30a3">Loading BokehJS ...</span>
#     </div>

# %%
# General Parameters

EPOCHS = 30
BATCH = 128
TEST_SPLIT = 0.2

OVERSAMPLING = 0.4         # Final fraction of positives in the training set

INPUT_SIZE = 30            # Time, Amount and features V1 thought V28
MID_SIZE = 30*30           # single layer common to all models
TARGET_SIZE = 2            # is fraud? 0/1

DATAPATH = "creditcard.csv"

# %% [markdown]
# # Data Exploration and Preparation

# %% [markdown]
# The data utilized for this project is available [here](https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud).

# %%
df = pd.read_csv(DATAPATH)
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
t = len(df)
f = df["Class"].sum()

print(f"Total Transactions:\t{ t }")
print(f"Total Frauds:\t\t{ f }")
print(f"Total Not Frauds:\t{ t - f }")
print(f"Fraud Fraction:\t\t{100 * f / t :00000.000}%")
# Out:
# Total Transactions:	284807
# Total Frauds:		492
# Total Not Frauds:	284315
# Fraud Fraction:		0.2%

# %%
df=(df-df.min())/(df.max()-df.min())

# %%
class PandasDataset(TensorDataset):
    def __init__(self, features, targets):
        self.features = torch.tensor(features.values, dtype=torch.float32)
        self.targets = torch.tensor(targets.values, dtype=torch.long)  # Adjust dtype for regression

    def __len__(self):
        return len(self.features)

    def __getitem__(self, idx):
        return self.features[idx], self.targets[idx]

# %%
X = df.drop(["Class"], axis=1)
y = df["Class"]

# Separate training and validation sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SPLIT, stratify=y, random_state=42)

# Oversampling training set
rebalance = X_train
rebalance["Class"] = y_train
positive = rebalance[rebalance["Class"] == 1]
while (rebalance["Class"] == 1).sum() / len(rebalance) < OVERSAMPLING:
    rebalance= pd.concat([rebalance, positive], ignore_index=True)

X_train = rebalance.drop(["Class"], axis=1)
y_train = rebalance["Class"]

# Convert to torch tensors
training_loader = DataLoader(PandasDataset(X_train, y_train), batch_size=BATCH, shuffle=True)
validation_loader = DataLoader(PandasDataset(X_test, y_test), batch_size=BATCH, shuffle=False)

# %% [markdown]
# # Models Implementation

# %% [markdown]
# ### Multiple Layer Perceptron

# %%
class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(INPUT_SIZE, 512)
        self.fc2 = nn.Linear(512, TARGET_SIZE)

    def forward(self, x):
        x = F.relu(self.fc1(x))  
        return self.fc2(x)

# %%
summary(MLP())
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# MLP                                      --
# ├─Linear: 1-1                            15,872
# ├─Linear: 1-2                            1,026
# =================================================================
# Total params: 16,898
# Trainable params: 16,898
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# ### Convolutional Neural Network

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.fc1 = nn.Linear(INPUT_SIZE, 900)
        self.conv = nn.Conv2d(
            in_channels=4, 
            out_channels=8, 
            kernel_size=(10, 10)
        )
        self.pool = nn.MaxPool2d(kernel_size=(3, 3), stride=1)
        self.flatten = nn.Flatten()
        self.fc2 = nn.Linear(128, TARGET_SIZE)

    def forward(self, x):
        x = F.relu(self.fc1(x))  
        #print(x.shape)
        x = x.view(-1, 4, 15, 15)
        #print(x.shape)
        x = F.relu(self.conv(x))
        #print(x.shape)
        x = self.pool(x)
        #print(x.shape)
        x = self.flatten(x)
        #print(x.shape)
        return self.fc2(x)

# %%
summary(CNN())
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# CNN                                      --
# ├─Linear: 1-1                            27,900
# ├─Conv2d: 1-2                            3,208
# ├─MaxPool2d: 1-3                         --
# ├─Flatten: 1-4                           --
# ├─Linear: 1-5                            258
# =================================================================
# Total params: 31,366
# Trainable params: 31,366
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# ### Long-Short Term Memory

# %%
class LSTM(nn.Module):
    def __init__(self):
        super(LSTM, self).__init__()
        self.fc1 = nn.Linear(INPUT_SIZE, 900)
        
        # Bidirectional LSTM layers
        self.lstm = nn.LSTM(input_size=30, 
                            hidden_size=30,
                            num_layers=2,
                            batch_first=True,
                            bidirectional=True)
        
        self.fc2 = nn.Linear(60, TARGET_SIZE)

    def forward(self, x):
        x = F.relu(self.fc1(x))  
        x = x.view(-1, 30, 30)
        x, (h_n, c_n) = self.lstm(x) 
        return self.fc2(x[:,-1,:])

# %%
summary(LSTM())
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# LSTM                                     --
# ├─Linear: 1-1                            27,900
# ├─LSTM: 1-2                              36,960
# ├─Linear: 1-3                            122
# =================================================================
# Total params: 64,982
# Trainable params: 64,982
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# ### Swarm Characteristic Neural Network

# %%
class SwarmFilter(nn.Module):
    def __init__(self, units=32):
        super(SwarmFilter, self).__init__()
        self.units = units
        self.filter = nn.Parameter(torch.randn(units))  # Trainable parameter with random initialization

    def forward(self, x):
        # Compute the mean along the last axis, keeping the dimensions
        mean_values = torch.mean(x, dim=-1, keepdim=True)
        return mean_values * self.filter

# %%
class SCNN(nn.Module):
    def __init__(self):
        super(SCNN, self).__init__()
        self.fc1 = nn.Linear(INPUT_SIZE, 300)
        self.swarm1 = SwarmFilter(units=300)
        self.swarm2 = SwarmFilter(units=100)
        self.fc2 = nn.Linear(100, TARGET_SIZE) 

    def forward(self, x):
        x = F.relu(self.fc1(x))  
        x = self.swarm1(x)     
        x = self.swarm2(x)     
        return self.fc2(x)

# %%
summary(SCNN())
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# SCNN                                     --
# ├─Linear: 1-1                            9,300
# ├─SwarmFilter: 1-2                       300
# ├─SwarmFilter: 1-3                       100
# ├─Linear: 1-4                            202
# =================================================================
# Total params: 9,902
# Trainable params: 9,902
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# # Running the models

# %% [markdown]
# ### Implementation

# %% [markdown]
# ##### Visuals

# %%
def progressbar(i, total, start):
    x = int(100*i/total)
    print(f"\t[{ u'█' * x }{ '.' * (100-x) }] { i : 6.0f}/{ total } Waiting for {time.time()-start:5.3f} seconds", end='\r')
    if i == total:
        print()

# %%
def display_stats(loss, cm):
    
    # Extract confusion matrix values
    TN = cm[0, 0]
    FP = cm[0, 1]
    FN = cm[1, 0]
    TP = cm[1, 1]
    
    # Calculate metrics
    accuracy = (TP + TN) / cm.sum()
    precision = TP / (TP + FP) if (TP + FP) > 0 else 0
    sensitivity = TP / (TP + FN) if (TP + FN) > 0 else 0
    specificity = TN / (TN + FP) if (TN + FP) > 0 else 0
    
    # Display metrics
    print(f'\t\tLoss: {loss}')
    
    print(f'\t\tConfusion Matrix')
    print(f'\t\t   True  Negative:  {int(TN)}')
    print(f'\t\t   False Negative:  {int(FN)}')
    print(f'\t\t   False Positive:  {int(FP)}')
    print(f'\t\t   True  Positive:  {int(TP)}')
    
    print(f'\t\tAccuracy:           {accuracy:0.3f}')
    print(f'\t\tPrecision:          {precision:0.3f}')
    print(f'\t\tSensitivity:        {sensitivity:0.3f}')
    print(f'\t\tSpecificity:        {specificity:0.3f}')

    return accuracy, precision, sensitivity, specificity

# %% [markdown]
# ##### Training and Validation

# %%
def train_epoch(model, optimizer, criterion):
    total_loss = 0.
    confusion = np.zeros((2,2))
    size = len(training_loader)
    start = time.time()
    for i, data in enumerate(training_loader):
        # Update progress bar
        progressbar(i,size,start)
        
        # Every data instance is an input + label pair
        inputs, labels = data
        
        # Zero your gradients for every batch!
        optimizer.zero_grad()
        
        # Make predictions for this batch
        outputs = model(inputs)

        # Compute the loss and its gradients
        loss = criterion(outputs, labels)
        loss.backward()
        
        # Adjust learning weights
        optimizer.step()
        
        # Gather data and report
        preds = outputs.data.max(1)[1]
        total_loss += loss.item()
        confusion += confusion_matrix(labels.detach().numpy(), preds.detach().numpy(), labels=[0,1])
        
    # Finish progress bar
    progressbar(size,size,start)

    # return average loss during training
    return total_loss / size, confusion

# %%
def validate_epoch(model, criterion):
    total_loss = 0.
    confusion = np.zeros((2,2))
    size = len(validation_loader)
    start = time.time()
    for i, data in enumerate(validation_loader):
        # Update progress bar
        progressbar(i,size,start)
        
        # Every data instance is an input + label pair
        inputs, labels = data
        
        # Make predictions for this batch
        outputs = model(inputs)
        
        # Compute the loss and its gradients
        loss = criterion(outputs, labels)
                
        # Gather data and report
        preds = outputs.data.max(1)[1]
        total_loss += loss.item()
        confusion += confusion_matrix(labels.detach().numpy(), preds.detach().numpy(), labels=[0,1])

    # Finish progress bar
    progressbar(size,size,start)

    # return average loss during training
    return total_loss / size, confusion

# %% [markdown]
# ##### Data Collection

# %%
def run_model(model, label="", color="navy", epochs=EPOCHS):
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss()

    stats = {
        "Label": label,
        "Color": color,
        "Training": {
            "Loss": [],
            "Accuracy": [],
            "Precision": [],
            "Sensitivity": [],
            "Specificity": [],
            "Time": 0.0,
            "Time/Epoch": 0.0
        },
        "Validation": {
            "Loss": [],
            "Accuracy": [],
            "Precision": [],
            "Sensitivity": [],
            "Specificity": [],
            "Time": 0.0,
            "Time/Epoch": 0.0
        },
        "Parameters": sum(p.numel() for p in model.parameters()),
    }
    
    train_time = 0
    val_time = 0
    
    for epoch in range(epochs):
        
        # Set the model to training mode
        model.train()  
        
        # Train epoch
        print(f"Epoch {epoch + 1}/{epochs}")
        print(f"\tTraining")
        start = time.time()
        train_loss, train_cm = train_epoch(model, optimizer, criterion)
        train_time += time.time() - start
        # Print training stats for the epoch
        train_acc, train_pre, train_sen, train_spe = display_stats(train_loss, train_cm)
        
        # Run validation
        model.eval()
        val_loss = 0.0
        val_cm = np.zeros((2,2))
    
        print(f"\tValidation")
        start = time.time()
        with torch.no_grad():  # Disable gradient calculation during validation
            # Run validation
            val_loss, val_cm = validate_epoch(model, criterion)
        val_time += time.time() - start
        # Print validation stats
        val_acc, val_pre, val_sen, val_spe = display_stats(val_loss, val_cm)

        # save stats
        stats["Training"]["Loss"].append(train_loss)
        stats["Training"]["Accuracy"].append(train_acc)
        stats["Training"]["Precision"].append(train_pre)
        stats["Training"]["Sensitivity"].append(train_sen)
        stats["Training"]["Specificity"].append(train_spe)

        stats["Validation"]["Loss"].append(val_loss)
        stats["Validation"]["Accuracy"].append(val_acc)
        stats["Validation"]["Precision"].append(val_pre)
        stats["Validation"]["Sensitivity"].append(val_sen)
        stats["Validation"]["Specificity"].append(val_spe)

    stats["Training"]["Loss"] = np.array(stats["Training"]["Loss"])
    stats["Validation"]["Loss"] = np.array(stats["Validation"]["Loss"])
    
    stats["Training"]["Time"] = train_time
    stats["Training"]["Time/Epoch"] = train_time / epochs

    stats["Validation"]["Time"] = val_time
    stats["Validation"]["Time/Epoch"] = val_time / epochs
    
    return stats

# %% [markdown]
# ### Running

# %%
mlp_stats = run_model(MLP(), label="MLP", color="green")
# Out:
# Epoch 1/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 8.712 seconds
# 		Loss: 0.16051812238118715
# 		Confusion Matrix
# 		   True  Negative:  223999
# 		   False Negative:  19008
# 		   False Positive:  3452
# 		   True  Positive:  132682
# 		Accuracy:           0.941
# 		Precision:          0.975
# 		Sensitivity:        0.875
# 		Specificity:        0.985
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.887 seconds
# 		Loss: 0.0953514797554556
# 		Confusion Matrix
# 		   True  Negative:  55804
# 		   False Negative:  8
# 		   False Positive:  1060
# 		   True  Positive:  90
# 		Accuracy:           0.981
# 		Precision:          0.078
# 		Sensitivity:        0.918
# 		Specificity:        0.981
# Epoch 2/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 8.349 seconds
# 		Loss: 0.13039333233311193
# 		Confusion Matrix
# 		   True  Negative:  223526
# 		   False Negative:  14858
# 		   False Positive:  3925
# 		   True  Positive:  136832
# 		Accuracy:           0.950
# 		Precision:          0.972
# 		Sensitivity:        0.902
# 		Specificity:        0.983
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.875 seconds
# 		Loss: 0.061458864549985115
# 		Confusion Matrix
# 		   True  Negative:  56259
# 		   False Negative:  10
# 		   False Positive:  605
# 		   True  Positive:  88
# 		Accuracy:           0.989
# 		Precision:          0.127
# 		Sensitivity:        0.898
# 		Specificity:        0.989
# Epoch 3/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 8.431 seconds
# 		Loss: 0.11011305939716702
# 		Confusion Matrix
# 		   True  Negative:  223919
# 		   False Negative:  12089
# 		   False Positive:  3532
# 		   True  Positive:  139601
# 		Accuracy:           0.959
# 		Precision:          0.975
# 		Sensitivity:        0.920
# 		Specificity:        0.984
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.843 seconds
# 		Loss: 0.11484088243357002
# 		Confusion Matrix
# 		   True  Negative:  55227
# 		   False Negative:  9
# 		   False Positive:  1637
# 		   True  Positive:  89
# 		Accuracy:           0.971
# 		Precision:          0.052
# 		Sensitivity:        0.908
# 		Specificity:        0.971
# Epoch 4/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 8.859 seconds
# 		Loss: 0.09400852687042074
# 		Confusion Matrix
# 		   True  Negative:  224168
# 		   False Negative:  10158
# 		   False Positive:  3283
# 		   True  Positive:  141532
# 		Accuracy:           0.965
# 		Precision:          0.977
# 		Sensitivity:        0.933
# 		Specificity:        0.986
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.872 seconds
# 		Loss: 0.047887823080869536
# 		Confusion Matrix
# 		   True  Negative:  56337
# 		   False Negative:  10
# 		   False Positive:  527
# 		   True  Positive:  88
# 		Accuracy:           0.991
# 		Precision:          0.143
# 		Sensitivity:        0.898
# 		Specificity:        0.991
# Epoch 5/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 8.361 seconds
# 		Loss: 0.08124514865188272
# 		Confusion Matrix
# 		   True  Negative:  224272
# 		   False Negative:  8737
# 		   False Positive:  3179
# 		   True  Positive:  142953
# 		Accuracy:           0.969
# 		Precision:          0.978
# 		Sensitivity:        0.942
# 		Specificity:        0.986
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.877 seconds
# 		Loss: 0.050636949687945604
# 		Confusion Matrix
# 		   True  Negative:  56199
# 		   False Negative:  9
# 		   False Positive:  665
# 		   True  Positive:  89
# 		Accuracy:           0.988
# 		Precision:          0.118
# 		Sensitivity:        0.908
# 		Specificity:        0.988
# Epoch 6/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 8.512 seconds
# 		Loss: 0.07121593669579288
# 		Confusion Matrix
# 		   True  Negative:  224298
# 		   False Negative:  7405
# 		   False Positive:  3153
# 		   True  Positive:  144285
# 		Accuracy:           0.972
# 		Precision:          0.979
# 		Sensitivity:        0.951
# 		Specificity:        0.986
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.875 seconds
# 		Loss: 0.029850315886253132
# 		Confusion Matrix
# 		   True  Negative:  56518
# 		   False Negative:  12
# 		   False Positive:  346
# 		   True  Positive:  86
# 		Accuracy:           0.994
# 		Precision:          0.199
# 		Sensitivity:        0.878
# 		Specificity:        0.994
# Epoch 7/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 8.943 seconds
# 		Loss: 0.06211709091219821
# 		Confusion Matrix
# 		   True  Negative:  224430
# 		   False Negative:  6033
# 		   False Positive:  3021
# 		   True  Positive:  145657
# 		Accuracy:           0.976
# 		Precision:          0.980
# 		Sensitivity:        0.960
# 		Specificity:        0.987
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.734 seconds
# 		Loss: 0.08409486775758422
# 		Confusion Matrix
# 		   True  Negative:  55356
# 		   False Negative:  10
# 		   False Positive:  1508
# 		   True  Positive:  88
# 		Accuracy:           0.973
# 		Precision:          0.055
# 		Sensitivity:        0.898
# 		Specificity:        0.973
# Epoch 8/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 8.654 seconds
# 		Loss: 0.05595451832660921
# 		Confusion Matrix
# 		   True  Negative:  224513
# 		   False Negative:  5114
# 		   False Positive:  2938
# 		   True  Positive:  146576
# 		Accuracy:           0.979
# 		Precision:          0.980
# 		Sensitivity:        0.966
# 		Specificity:        0.987
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.911 seconds
# 		Loss: 0.08226145583000284
# 		Confusion Matrix
# 		   True  Negative:  55321
# 		   False Negative:  9
# 		   False Positive:  1543
# 		   True  Positive:  89
# 		Accuracy:           0.973
# 		Precision:          0.055
# 		Sensitivity:        0.908
# 		Specificity:        0.973
# Epoch 9/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 8.646 seconds
# 		Loss: 0.049311973342820975
# 		Confusion Matrix
# 		   True  Negative:  224683
# 		   False Negative:  4073
# 		   False Positive:  2768
# 		   True  Positive:  147617
# 		Accuracy:           0.982
# 		Precision:          0.982
# 		Sensitivity:        0.973
# 		Specificity:        0.988
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.893 seconds
# 		Loss: 0.03829818693273638
# 		Confusion Matrix
# 		   True  Negative:  56304
# 		   False Negative:  12
# 		   False Positive:  560
# 		   True  Positive:  86
# 		Accuracy:           0.990
# 		Precision:          0.133
# 		Sensitivity:        0.878
# 		Specificity:        0.990
# Epoch 10/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 8.892 seconds
# 		Loss: 0.04545790567474551
# 		Confusion Matrix
# 		   True  Negative:  224733
# 		   False Negative:  3494
# 		   False Positive:  2718
# 		   True  Positive:  148196
# 		Accuracy:           0.984
# 		Precision:          0.982
# 		Sensitivity:        0.977
# 		Specificity:        0.988
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.769 seconds
# 		Loss: 0.09400866784138663
# 		Confusion Matrix
# 		   True  Negative:  54885
# 		   False Negative:  8
# 		   False Positive:  1979
# 		   True  Positive:  90
# 		Accuracy:           0.965
# 		Precision:          0.043
# 		Sensitivity:        0.918
# 		Specificity:        0.965
# Epoch 11/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 8.984 seconds
# 		Loss: 0.041285585391844896
# 		Confusion Matrix
# 		   True  Negative:  224873
# 		   False Negative:  2958
# 		   False Positive:  2578
# 		   True  Positive:  148732
# 		Accuracy:           0.985
# 		Precision:          0.983
# 		Sensitivity:        0.980
# 		Specificity:        0.989
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.859 seconds
# 		Loss: 0.01376616641969917
# 		Confusion Matrix
# 		   True  Negative:  56697
# 		   False Negative:  13
# 		   False Positive:  167
# 		   True  Positive:  85
# 		Accuracy:           0.997
# 		Precision:          0.337
# 		Sensitivity:        0.867
# 		Specificity:        0.997
# Epoch 12/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 8.664 seconds
# 		Loss: 0.038072326484127166
# 		Confusion Matrix
# 		   True  Negative:  224961
# 		   False Negative:  2522
# 		   False Positive:  2490
# 		   True  Positive:  149168
# 		Accuracy:           0.987
# 		Precision:          0.984
# 		Sensitivity:        0.983
# 		Specificity:        0.989
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.881 seconds
# 		Loss: 0.10317387730885515
# 		Confusion Matrix
# 		   True  Negative:  54612
# 		   False Negative:  8
# 		   False Positive:  2252
# 		   True  Positive:  90
# 		Accuracy:           0.960
# 		Precision:          0.038
# 		Sensitivity:        0.918
# 		Specificity:        0.960
# Epoch 13/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 8.503 seconds
# 		Loss: 0.03643667569476388
# 		Confusion Matrix
# 		   True  Negative:  224999
# 		   False Negative:  2371
# 		   False Positive:  2452
# 		   True  Positive:  149319
# 		Accuracy:           0.987
# 		Precision:          0.984
# 		Sensitivity:        0.984
# 		Specificity:        0.989
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.884 seconds
# 		Loss: 0.028313254905685013
# 		Confusion Matrix
# 		   True  Negative:  56401
# 		   False Negative:  10
# 		   False Positive:  463
# 		   True  Positive:  88
# 		Accuracy:           0.992
# 		Precision:          0.160
# 		Sensitivity:        0.898
# 		Specificity:        0.992
# Epoch 14/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 9.175 seconds
# 		Loss: 0.03201446502558746
# 		Confusion Matrix
# 		   True  Negative:  225259
# 		   False Negative:  1704
# 		   False Positive:  2192
# 		   True  Positive:  149986
# 		Accuracy:           0.990
# 		Precision:          0.986
# 		Sensitivity:        0.989
# 		Specificity:        0.990
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.836 seconds
# 		Loss: 0.1493141573056111
# 		Confusion Matrix
# 		   True  Negative:  53489
# 		   False Negative:  7
# 		   False Positive:  3375
# 		   True  Positive:  91
# 		Accuracy:           0.941
# 		Precision:          0.026
# 		Sensitivity:        0.929
# 		Specificity:        0.941
# Epoch 15/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 8.707 seconds
# 		Loss: 0.0327149768197457
# 		Confusion Matrix
# 		   True  Negative:  225228
# 		   False Negative:  1850
# 		   False Positive:  2223
# 		   True  Positive:  149840
# 		Accuracy:           0.989
# 		Precision:          0.985
# 		Sensitivity:        0.988
# 		Specificity:        0.990
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.896 seconds
# 		Loss: 0.08266840011065182
# 		Confusion Matrix
# 		   True  Negative:  55081
# 		   False Negative:  8
# 		   False Positive:  1783
# 		   True  Positive:  90
# 		Accuracy:           0.969
# 		Precision:          0.048
# 		Sensitivity:        0.918
# 		Specificity:        0.969
# Epoch 16/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 8.696 seconds
# 		Loss: 0.02910542719025111
# 		Confusion Matrix
# 		   True  Negative:  225385
# 		   False Negative:  1480
# 		   False Positive:  2066
# 		   True  Positive:  150210
# 		Accuracy:           0.991
# 		Precision:          0.986
# 		Sensitivity:        0.990
# 		Specificity:        0.991
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.925 seconds
# 		Loss: 0.03502802197370394
# 		Confusion Matrix
# 		   True  Negative:  56229
# 		   False Negative:  11
# 		   False Positive:  635
# 		   True  Positive:  87
# 		Accuracy:           0.989
# 		Precision:          0.120
# 		Sensitivity:        0.888
# 		Specificity:        0.989
# Epoch 17/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 8.817 seconds
# 		Loss: 0.027875290291597285
# 		Confusion Matrix
# 		   True  Negative:  225463
# 		   False Negative:  1343
# 		   False Positive:  1988
# 		   True  Positive:  150347
# 		Accuracy:           0.991
# 		Precision:          0.987
# 		Sensitivity:        0.991
# 		Specificity:        0.991
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.734 seconds
# 		Loss: 0.05907625039087216
# 		Confusion Matrix
# 		   True  Negative:  55672
# 		   False Negative:  9
# 		   False Positive:  1192
# 		   True  Positive:  89
# 		Accuracy:           0.979
# 		Precision:          0.069
# 		Sensitivity:        0.908
# 		Specificity:        0.979
# Epoch 18/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 9.217 seconds
# 		Loss: 0.027068653857442945
# 		Confusion Matrix
# 		   True  Negative:  225492
# 		   False Negative:  1248
# 		   False Positive:  1959
# 		   True  Positive:  150442
# 		Accuracy:           0.992
# 		Precision:          0.987
# 		Sensitivity:        0.992
# 		Specificity:        0.991
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.939 seconds
# 		Loss: 0.03351599097798992
# 		Confusion Matrix
# 		   True  Negative:  56270
# 		   False Negative:  10
# 		   False Positive:  594
# 		   True  Positive:  88
# 		Accuracy:           0.989
# 		Precision:          0.129
# 		Sensitivity:        0.898
# 		Specificity:        0.990
# Epoch 19/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 8.595 seconds
# 		Loss: 0.02511922471517413
# 		Confusion Matrix
# 		   True  Negative:  225599
# 		   False Negative:  1063
# 		   False Positive:  1852
# 		   True  Positive:  150627
# 		Accuracy:           0.992
# 		Precision:          0.988
# 		Sensitivity:        0.993
# 		Specificity:        0.992
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.917 seconds
# 		Loss: 0.04729656170794715
# 		Confusion Matrix
# 		   True  Negative:  55942
# 		   False Negative:  10
# 		   False Positive:  922
# 		   True  Positive:  88
# 		Accuracy:           0.984
# 		Precision:          0.087
# 		Sensitivity:        0.898
# 		Specificity:        0.984
# Epoch 20/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 8.651 seconds
# 		Loss: 0.0239840626257396
# 		Confusion Matrix
# 		   True  Negative:  225624
# 		   False Negative:  961
# 		   False Positive:  1827
# 		   True  Positive:  150729
# 		Accuracy:           0.993
# 		Precision:          0.988
# 		Sensitivity:        0.994
# 		Specificity:        0.992
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.897 seconds
# 		Loss: 0.027794439106242054
# 		Confusion Matrix
# 		   True  Negative:  56354
# 		   False Negative:  14
# 		   False Positive:  510
# 		   True  Positive:  84
# 		Accuracy:           0.991
# 		Precision:          0.141
# 		Sensitivity:        0.857
# 		Specificity:        0.991
# Epoch 21/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 9.450 seconds
# 		Loss: 0.023069638192576333
# 		Confusion Matrix
# 		   True  Negative:  225739
# 		   False Negative:  859
# 		   False Positive:  1712
# 		   True  Positive:  150831
# 		Accuracy:           0.993
# 		Precision:          0.989
# 		Sensitivity:        0.994
# 		Specificity:        0.992
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.880 seconds
# 		Loss: 0.0267042596509937
# 		Confusion Matrix
# 		   True  Negative:  56400
# 		   False Negative:  12
# 		   False Positive:  464
# 		   True  Positive:  86
# 		Accuracy:           0.992
# 		Precision:          0.156
# 		Sensitivity:        0.878
# 		Specificity:        0.992
# Epoch 22/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 8.582 seconds
# 		Loss: 0.021702013639385873
# 		Confusion Matrix
# 		   True  Negative:  225791
# 		   False Negative:  748
# 		   False Positive:  1660
# 		   True  Positive:  150942
# 		Accuracy:           0.994
# 		Precision:          0.989
# 		Sensitivity:        0.995
# 		Specificity:        0.993
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.882 seconds
# 		Loss: 0.061525165428085914
# 		Confusion Matrix
# 		   True  Negative:  55609
# 		   False Negative:  11
# 		   False Positive:  1255
# 		   True  Positive:  87
# 		Accuracy:           0.978
# 		Precision:          0.065
# 		Sensitivity:        0.888
# 		Specificity:        0.978
# Epoch 23/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 8.600 seconds
# 		Loss: 0.021436878632461142
# 		Confusion Matrix
# 		   True  Negative:  225820
# 		   False Negative:  802
# 		   False Positive:  1631
# 		   True  Positive:  150888
# 		Accuracy:           0.994
# 		Precision:          0.989
# 		Sensitivity:        0.995
# 		Specificity:        0.993
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.857 seconds
# 		Loss: 0.06320195903400201
# 		Confusion Matrix
# 		   True  Negative:  55624
# 		   False Negative:  9
# 		   False Positive:  1240
# 		   True  Positive:  89
# 		Accuracy:           0.978
# 		Precision:          0.067
# 		Sensitivity:        0.908
# 		Specificity:        0.978
# Epoch 24/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 8.912 seconds
# 		Loss: 0.019859408122011805
# 		Confusion Matrix
# 		   True  Negative:  225924
# 		   False Negative:  647
# 		   False Positive:  1527
# 		   True  Positive:  151043
# 		Accuracy:           0.994
# 		Precision:          0.990
# 		Sensitivity:        0.996
# 		Specificity:        0.993
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.748 seconds
# 		Loss: 0.03764320211458926
# 		Confusion Matrix
# 		   True  Negative:  56155
# 		   False Negative:  11
# 		   False Positive:  709
# 		   True  Positive:  87
# 		Accuracy:           0.987
# 		Precision:          0.109
# 		Sensitivity:        0.888
# 		Specificity:        0.988
# Epoch 25/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 9.003 seconds
# 		Loss: 0.019469086681582797
# 		Confusion Matrix
# 		   True  Negative:  225981
# 		   False Negative:  612
# 		   False Positive:  1470
# 		   True  Positive:  151078
# 		Accuracy:           0.995
# 		Precision:          0.990
# 		Sensitivity:        0.996
# 		Specificity:        0.994
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.890 seconds
# 		Loss: 0.03590402475191748
# 		Confusion Matrix
# 		   True  Negative:  56202
# 		   False Negative:  10
# 		   False Positive:  662
# 		   True  Positive:  88
# 		Accuracy:           0.988
# 		Precision:          0.117
# 		Sensitivity:        0.898
# 		Specificity:        0.988
# Epoch 26/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 8.719 seconds
# 		Loss: 0.019652222251826452
# 		Confusion Matrix
# 		   True  Negative:  225913
# 		   False Negative:  694
# 		   False Positive:  1538
# 		   True  Positive:  150996
# 		Accuracy:           0.994
# 		Precision:          0.990
# 		Sensitivity:        0.995
# 		Specificity:        0.993
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.911 seconds
# 		Loss: 0.01840500039272449
# 		Confusion Matrix
# 		   True  Negative:  56573
# 		   False Negative:  12
# 		   False Positive:  291
# 		   True  Positive:  86
# 		Accuracy:           0.995
# 		Precision:          0.228
# 		Sensitivity:        0.878
# 		Specificity:        0.995
# Epoch 27/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 8.698 seconds
# 		Loss: 0.018168002451600513
# 		Confusion Matrix
# 		   True  Negative:  226033
# 		   False Negative:  565
# 		   False Positive:  1418
# 		   True  Positive:  151125
# 		Accuracy:           0.995
# 		Precision:          0.991
# 		Sensitivity:        0.996
# 		Specificity:        0.994
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.887 seconds
# 		Loss: 0.007194995572132486
# 		Confusion Matrix
# 		   True  Negative:  56802
# 		   False Negative:  17
# 		   False Positive:  62
# 		   True  Positive:  81
# 		Accuracy:           0.999
# 		Precision:          0.566
# 		Sensitivity:        0.827
# 		Specificity:        0.999
# Epoch 28/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 9.165 seconds
# 		Loss: 0.017853017102636495
# 		Confusion Matrix
# 		   True  Negative:  226059
# 		   False Negative:  542
# 		   False Positive:  1392
# 		   True  Positive:  151148
# 		Accuracy:           0.995
# 		Precision:          0.991
# 		Sensitivity:        0.996
# 		Specificity:        0.994
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.912 seconds
# 		Loss: 0.021858802996445322
# 		Confusion Matrix
# 		   True  Negative:  56506
# 		   False Negative:  14
# 		   False Positive:  358
# 		   True  Positive:  84
# 		Accuracy:           0.993
# 		Precision:          0.190
# 		Sensitivity:        0.857
# 		Specificity:        0.994
# Epoch 29/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 8.714 seconds
# 		Loss: 0.017982686114930844
# 		Confusion Matrix
# 		   True  Negative:  226068
# 		   False Negative:  602
# 		   False Positive:  1383
# 		   True  Positive:  151088
# 		Accuracy:           0.995
# 		Precision:          0.991
# 		Sensitivity:        0.996
# 		Specificity:        0.994
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.906 seconds
# 		Loss: 0.01251780801666603
# 		Confusion Matrix
# 		   True  Negative:  56700
# 		   False Negative:  16
# 		   False Positive:  164
# 		   True  Positive:  82
# 		Accuracy:           0.997
# 		Precision:          0.333
# 		Sensitivity:        0.837
# 		Specificity:        0.997
# Epoch 30/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 8.535 seconds
# 		Loss: 0.016597056366719175
# 		Confusion Matrix
# 		   True  Negative:  226153
# 		   False Negative:  455
# 		   False Positive:  1298
# 		   True  Positive:  151235
# 		Accuracy:           0.995
# 		Precision:          0.991
# 		Sensitivity:        0.997
# 		Specificity:        0.994
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.848 seconds
# 		Loss: 0.014428082007024112
# 		Confusion Matrix
# 		   True  Negative:  56668
# 		   False Negative:  15
# 		   False Positive:  196
# 		   True  Positive:  83
# 		Accuracy:           0.996
# 		Precision:          0.297
# 		Sensitivity:        0.847
# 		Specificity:        0.997

# %%
cnn_stats = run_model(CNN(), label="CNN", color="navy")
# Out:
# Epoch 1/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 12.868 seconds
# 		Loss: 0.14967255821747633
# 		Confusion Matrix
# 		   True  Negative:  223148
# 		   False Negative:  16968
# 		   False Positive:  4303
# 		   True  Positive:  134722
# 		Accuracy:           0.944
# 		Precision:          0.969
# 		Sensitivity:        0.888
# 		Specificity:        0.981
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.078 seconds
# 		Loss: 0.030799211123999994
# 		Confusion Matrix
# 		   True  Negative:  56481
# 		   False Negative:  11
# 		   False Positive:  383
# 		   True  Positive:  87
# 		Accuracy:           0.993
# 		Precision:          0.185
# 		Sensitivity:        0.888
# 		Specificity:        0.993
# Epoch 2/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 12.904 seconds
# 		Loss: 0.10672441600541227
# 		Confusion Matrix
# 		   True  Negative:  223174
# 		   False Negative:  11292
# 		   False Positive:  4277
# 		   True  Positive:  140398
# 		Accuracy:           0.959
# 		Precision:          0.970
# 		Sensitivity:        0.926
# 		Specificity:        0.981
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.069 seconds
# 		Loss: 0.06704124690121198
# 		Confusion Matrix
# 		   True  Negative:  55759
# 		   False Negative:  9
# 		   False Positive:  1105
# 		   True  Positive:  89
# 		Accuracy:           0.980
# 		Precision:          0.075
# 		Sensitivity:        0.908
# 		Specificity:        0.981
# Epoch 3/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 13.224 seconds
# 		Loss: 0.07660695124062994
# 		Confusion Matrix
# 		   True  Negative:  223654
# 		   False Negative:  7773
# 		   False Positive:  3797
# 		   True  Positive:  143917
# 		Accuracy:           0.969
# 		Precision:          0.974
# 		Sensitivity:        0.949
# 		Specificity:        0.983
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.107 seconds
# 		Loss: 0.08514434288594154
# 		Confusion Matrix
# 		   True  Negative:  55062
# 		   False Negative:  10
# 		   False Positive:  1802
# 		   True  Positive:  88
# 		Accuracy:           0.968
# 		Precision:          0.047
# 		Sensitivity:        0.898
# 		Specificity:        0.968
# Epoch 4/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 14.399 seconds
# 		Loss: 0.054508510805569635
# 		Confusion Matrix
# 		   True  Negative:  224144
# 		   False Negative:  4715
# 		   False Positive:  3307
# 		   True  Positive:  146975
# 		Accuracy:           0.979
# 		Precision:          0.978
# 		Sensitivity:        0.969
# 		Specificity:        0.985
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.940 seconds
# 		Loss: 0.03229392791060405
# 		Confusion Matrix
# 		   True  Negative:  56304
# 		   False Negative:  9
# 		   False Positive:  560
# 		   True  Positive:  89
# 		Accuracy:           0.990
# 		Precision:          0.137
# 		Sensitivity:        0.908
# 		Specificity:        0.990
# Epoch 5/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 15.861 seconds
# 		Loss: 0.04253798104211917
# 		Confusion Matrix
# 		   True  Negative:  224506
# 		   False Negative:  3181
# 		   False Positive:  2945
# 		   True  Positive:  148509
# 		Accuracy:           0.984
# 		Precision:          0.981
# 		Sensitivity:        0.979
# 		Specificity:        0.987
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.207 seconds
# 		Loss: 0.01799477024527602
# 		Confusion Matrix
# 		   True  Negative:  56618
# 		   False Negative:  14
# 		   False Positive:  246
# 		   True  Positive:  84
# 		Accuracy:           0.995
# 		Precision:          0.255
# 		Sensitivity:        0.857
# 		Specificity:        0.996
# Epoch 6/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 16.018 seconds
# 		Loss: 0.034373593257439064
# 		Confusion Matrix
# 		   True  Negative:  224951
# 		   False Negative:  2235
# 		   False Positive:  2500
# 		   True  Positive:  149455
# 		Accuracy:           0.988
# 		Precision:          0.984
# 		Sensitivity:        0.985
# 		Specificity:        0.989
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.224 seconds
# 		Loss: 0.020959284700789477
# 		Confusion Matrix
# 		   True  Negative:  56567
# 		   False Negative:  14
# 		   False Positive:  297
# 		   True  Positive:  84
# 		Accuracy:           0.995
# 		Precision:          0.220
# 		Sensitivity:        0.857
# 		Specificity:        0.995
# Epoch 7/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 14.274 seconds
# 		Loss: 0.029548911687134884
# 		Confusion Matrix
# 		   True  Negative:  225256
# 		   False Negative:  1695
# 		   False Positive:  2195
# 		   True  Positive:  149995
# 		Accuracy:           0.990
# 		Precision:          0.986
# 		Sensitivity:        0.989
# 		Specificity:        0.990
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.190 seconds
# 		Loss: 0.02943804541408531
# 		Confusion Matrix
# 		   True  Negative:  56366
# 		   False Negative:  12
# 		   False Positive:  498
# 		   True  Positive:  86
# 		Accuracy:           0.991
# 		Precision:          0.147
# 		Sensitivity:        0.878
# 		Specificity:        0.991
# Epoch 8/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 14.054 seconds
# 		Loss: 0.02566830406788645
# 		Confusion Matrix
# 		   True  Negative:  225448
# 		   False Negative:  1380
# 		   False Positive:  2003
# 		   True  Positive:  150310
# 		Accuracy:           0.991
# 		Precision:          0.987
# 		Sensitivity:        0.991
# 		Specificity:        0.991
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.124 seconds
# 		Loss: 0.013203300657477742
# 		Confusion Matrix
# 		   True  Negative:  56675
# 		   False Negative:  14
# 		   False Positive:  189
# 		   True  Positive:  84
# 		Accuracy:           0.996
# 		Precision:          0.308
# 		Sensitivity:        0.857
# 		Specificity:        0.997
# Epoch 9/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 14.633 seconds
# 		Loss: 0.024118062663791826
# 		Confusion Matrix
# 		   True  Negative:  225603
# 		   False Negative:  1279
# 		   False Positive:  1848
# 		   True  Positive:  150411
# 		Accuracy:           0.992
# 		Precision:          0.988
# 		Sensitivity:        0.992
# 		Specificity:        0.992
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.944 seconds
# 		Loss: 0.023761098665412882
# 		Confusion Matrix
# 		   True  Negative:  56431
# 		   False Negative:  14
# 		   False Positive:  433
# 		   True  Positive:  84
# 		Accuracy:           0.992
# 		Precision:          0.162
# 		Sensitivity:        0.857
# 		Specificity:        0.992
# Epoch 10/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 14.470 seconds
# 		Loss: 0.020354172520460817
# 		Confusion Matrix
# 		   True  Negative:  225890
# 		   False Negative:  964
# 		   False Positive:  1561
# 		   True  Positive:  150726
# 		Accuracy:           0.993
# 		Precision:          0.990
# 		Sensitivity:        0.994
# 		Specificity:        0.993
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.125 seconds
# 		Loss: 0.023744841637544024
# 		Confusion Matrix
# 		   True  Negative:  56471
# 		   False Negative:  10
# 		   False Positive:  393
# 		   True  Positive:  88
# 		Accuracy:           0.993
# 		Precision:          0.183
# 		Sensitivity:        0.898
# 		Specificity:        0.993
# Epoch 11/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 14.179 seconds
# 		Loss: 0.019831137075150603
# 		Confusion Matrix
# 		   True  Negative:  225901
# 		   False Negative:  965
# 		   False Positive:  1550
# 		   True  Positive:  150725
# 		Accuracy:           0.993
# 		Precision:          0.990
# 		Sensitivity:        0.994
# 		Specificity:        0.993
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.120 seconds
# 		Loss: 0.02754662215481032
# 		Confusion Matrix
# 		   True  Negative:  56386
# 		   False Negative:  13
# 		   False Positive:  478
# 		   True  Positive:  85
# 		Accuracy:           0.991
# 		Precision:          0.151
# 		Sensitivity:        0.867
# 		Specificity:        0.992
# Epoch 12/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 14.438 seconds
# 		Loss: 0.017010982736564907
# 		Confusion Matrix
# 		   True  Negative:  226086
# 		   False Negative:  775
# 		   False Positive:  1365
# 		   True  Positive:  150915
# 		Accuracy:           0.994
# 		Precision:          0.991
# 		Sensitivity:        0.995
# 		Specificity:        0.994
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.116 seconds
# 		Loss: 0.015310906444652663
# 		Confusion Matrix
# 		   True  Negative:  56628
# 		   False Negative:  15
# 		   False Positive:  236
# 		   True  Positive:  83
# 		Accuracy:           0.996
# 		Precision:          0.260
# 		Sensitivity:        0.847
# 		Specificity:        0.996
# Epoch 13/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 14.878 seconds
# 		Loss: 0.017924924080177276
# 		Confusion Matrix
# 		   True  Negative:  226060
# 		   False Negative:  843
# 		   False Positive:  1391
# 		   True  Positive:  150847
# 		Accuracy:           0.994
# 		Precision:          0.991
# 		Sensitivity:        0.994
# 		Specificity:        0.994
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.041 seconds
# 		Loss: 0.01951598455255534
# 		Confusion Matrix
# 		   True  Negative:  56556
# 		   False Negative:  13
# 		   False Positive:  308
# 		   True  Positive:  85
# 		Accuracy:           0.994
# 		Precision:          0.216
# 		Sensitivity:        0.867
# 		Specificity:        0.995
# Epoch 14/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 16.457 seconds
# 		Loss: 0.014913388464129079
# 		Confusion Matrix
# 		   True  Negative:  226286
# 		   False Negative:  601
# 		   False Positive:  1165
# 		   True  Positive:  151089
# 		Accuracy:           0.995
# 		Precision:          0.992
# 		Sensitivity:        0.996
# 		Specificity:        0.995
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.076 seconds
# 		Loss: 0.024997112815891655
# 		Confusion Matrix
# 		   True  Negative:  56430
# 		   False Negative:  14
# 		   False Positive:  434
# 		   True  Positive:  84
# 		Accuracy:           0.992
# 		Precision:          0.162
# 		Sensitivity:        0.857
# 		Specificity:        0.992
# Epoch 15/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 14.408 seconds
# 		Loss: 0.015018841343014351
# 		Confusion Matrix
# 		   True  Negative:  226257
# 		   False Negative:  685
# 		   False Positive:  1194
# 		   True  Positive:  151005
# 		Accuracy:           0.995
# 		Precision:          0.992
# 		Sensitivity:        0.995
# 		Specificity:        0.995
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.147 seconds
# 		Loss: 0.03747549025611242
# 		Confusion Matrix
# 		   True  Negative:  56174
# 		   False Negative:  11
# 		   False Positive:  690
# 		   True  Positive:  87
# 		Accuracy:           0.988
# 		Precision:          0.112
# 		Sensitivity:        0.888
# 		Specificity:        0.988
# Epoch 16/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 14.265 seconds
# 		Loss: 0.014521606192913676
# 		Confusion Matrix
# 		   True  Negative:  226299
# 		   False Negative:  616
# 		   False Positive:  1152
# 		   True  Positive:  151074
# 		Accuracy:           0.995
# 		Precision:          0.992
# 		Sensitivity:        0.996
# 		Specificity:        0.995
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.133 seconds
# 		Loss: 0.00887925404803795
# 		Confusion Matrix
# 		   True  Negative:  56788
# 		   False Negative:  13
# 		   False Positive:  76
# 		   True  Positive:  85
# 		Accuracy:           0.998
# 		Precision:          0.528
# 		Sensitivity:        0.867
# 		Specificity:        0.999
# Epoch 17/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 14.318 seconds
# 		Loss: 0.01291543087172963
# 		Confusion Matrix
# 		   True  Negative:  226437
# 		   False Negative:  532
# 		   False Positive:  1014
# 		   True  Positive:  151158
# 		Accuracy:           0.996
# 		Precision:          0.993
# 		Sensitivity:        0.996
# 		Specificity:        0.996
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.115 seconds
# 		Loss: 0.017012463541109375
# 		Confusion Matrix
# 		   True  Negative:  56603
# 		   False Negative:  15
# 		   False Positive:  261
# 		   True  Positive:  83
# 		Accuracy:           0.995
# 		Precision:          0.241
# 		Sensitivity:        0.847
# 		Specificity:        0.995
# Epoch 18/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 14.704 seconds
# 		Loss: 0.012657963138235159
# 		Confusion Matrix
# 		   True  Negative:  226433
# 		   False Negative:  527
# 		   False Positive:  1018
# 		   True  Positive:  151163
# 		Accuracy:           0.996
# 		Precision:          0.993
# 		Sensitivity:        0.997
# 		Specificity:        0.996
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.929 seconds
# 		Loss: 0.016505059411102824
# 		Confusion Matrix
# 		   True  Negative:  56624
# 		   False Negative:  15
# 		   False Positive:  240
# 		   True  Positive:  83
# 		Accuracy:           0.996
# 		Precision:          0.257
# 		Sensitivity:        0.847
# 		Specificity:        0.996
# Epoch 19/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 14.940 seconds
# 		Loss: 0.012009068042450605
# 		Confusion Matrix
# 		   True  Negative:  226515
# 		   False Negative:  482
# 		   False Positive:  936
# 		   True  Positive:  151208
# 		Accuracy:           0.996
# 		Precision:          0.994
# 		Sensitivity:        0.997
# 		Specificity:        0.996
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.135 seconds
# 		Loss: 0.017028156533711654
# 		Confusion Matrix
# 		   True  Negative:  56613
# 		   False Negative:  14
# 		   False Positive:  251
# 		   True  Positive:  84
# 		Accuracy:           0.995
# 		Precision:          0.251
# 		Sensitivity:        0.857
# 		Specificity:        0.996
# Epoch 20/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 14.278 seconds
# 		Loss: 0.010940633797321296
# 		Confusion Matrix
# 		   True  Negative:  226605
# 		   False Negative:  426
# 		   False Positive:  846
# 		   True  Positive:  151264
# 		Accuracy:           0.997
# 		Precision:          0.994
# 		Sensitivity:        0.997
# 		Specificity:        0.996
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.163 seconds
# 		Loss: 0.015728801351114405
# 		Confusion Matrix
# 		   True  Negative:  56642
# 		   False Negative:  13
# 		   False Positive:  222
# 		   True  Positive:  85
# 		Accuracy:           0.996
# 		Precision:          0.277
# 		Sensitivity:        0.867
# 		Specificity:        0.996
# Epoch 21/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 14.152 seconds
# 		Loss: 0.011345154548035311
# 		Confusion Matrix
# 		   True  Negative:  226552
# 		   False Negative:  456
# 		   False Positive:  899
# 		   True  Positive:  151234
# 		Accuracy:           0.996
# 		Precision:          0.994
# 		Sensitivity:        0.997
# 		Specificity:        0.996
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.123 seconds
# 		Loss: 0.012828431825956887
# 		Confusion Matrix
# 		   True  Negative:  56693
# 		   False Negative:  12
# 		   False Positive:  171
# 		   True  Positive:  86
# 		Accuracy:           0.997
# 		Precision:          0.335
# 		Sensitivity:        0.878
# 		Specificity:        0.997
# Epoch 22/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 14.448 seconds
# 		Loss: 0.010210849959805406
# 		Confusion Matrix
# 		   True  Negative:  226680
# 		   False Negative:  387
# 		   False Positive:  771
# 		   True  Positive:  151303
# 		Accuracy:           0.997
# 		Precision:          0.995
# 		Sensitivity:        0.997
# 		Specificity:        0.997
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.132 seconds
# 		Loss: 0.02442219064680853
# 		Confusion Matrix
# 		   True  Negative:  56477
# 		   False Negative:  13
# 		   False Positive:  387
# 		   True  Positive:  85
# 		Accuracy:           0.993
# 		Precision:          0.180
# 		Sensitivity:        0.867
# 		Specificity:        0.993
# Epoch 23/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 15.774 seconds
# 		Loss: 0.010411999728445018
# 		Confusion Matrix
# 		   True  Negative:  226652
# 		   False Negative:  436
# 		   False Positive:  799
# 		   True  Positive:  151254
# 		Accuracy:           0.997
# 		Precision:          0.995
# 		Sensitivity:        0.997
# 		Specificity:        0.996
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.030 seconds
# 		Loss: 0.01361425071113832
# 		Confusion Matrix
# 		   True  Negative:  56704
# 		   False Negative:  15
# 		   False Positive:  160
# 		   True  Positive:  83
# 		Accuracy:           0.997
# 		Precision:          0.342
# 		Sensitivity:        0.847
# 		Specificity:        0.997
# Epoch 24/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 14.956 seconds
# 		Loss: 0.00997135605499012
# 		Confusion Matrix
# 		   True  Negative:  226679
# 		   False Negative:  415
# 		   False Positive:  772
# 		   True  Positive:  151275
# 		Accuracy:           0.997
# 		Precision:          0.995
# 		Sensitivity:        0.997
# 		Specificity:        0.997
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.132 seconds
# 		Loss: 0.023146889734407157
# 		Confusion Matrix
# 		   True  Negative:  56479
# 		   False Negative:  13
# 		   False Positive:  385
# 		   True  Positive:  85
# 		Accuracy:           0.993
# 		Precision:          0.181
# 		Sensitivity:        0.867
# 		Specificity:        0.993
# Epoch 25/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 14.585 seconds
# 		Loss: 0.00898402646924071
# 		Confusion Matrix
# 		   True  Negative:  226756
# 		   False Negative:  365
# 		   False Positive:  695
# 		   True  Positive:  151325
# 		Accuracy:           0.997
# 		Precision:          0.995
# 		Sensitivity:        0.998
# 		Specificity:        0.997
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.191 seconds
# 		Loss: 0.00999294584207012
# 		Confusion Matrix
# 		   True  Negative:  56759
# 		   False Negative:  15
# 		   False Positive:  105
# 		   True  Positive:  83
# 		Accuracy:           0.998
# 		Precision:          0.441
# 		Sensitivity:        0.847
# 		Specificity:        0.998
# Epoch 26/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 14.684 seconds
# 		Loss: 0.008796859078019175
# 		Confusion Matrix
# 		   True  Negative:  226750
# 		   False Negative:  357
# 		   False Positive:  701
# 		   True  Positive:  151333
# 		Accuracy:           0.997
# 		Precision:          0.995
# 		Sensitivity:        0.998
# 		Specificity:        0.997
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.152 seconds
# 		Loss: 0.011020319593329775
# 		Confusion Matrix
# 		   True  Negative:  56723
# 		   False Negative:  16
# 		   False Positive:  141
# 		   True  Positive:  82
# 		Accuracy:           0.997
# 		Precision:          0.368
# 		Sensitivity:        0.837
# 		Specificity:        0.998
# Epoch 27/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 14.823 seconds
# 		Loss: 0.008324434234714878
# 		Confusion Matrix
# 		   True  Negative:  226800
# 		   False Negative:  298
# 		   False Positive:  651
# 		   True  Positive:  151392
# 		Accuracy:           0.997
# 		Precision:          0.996
# 		Sensitivity:        0.998
# 		Specificity:        0.997
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.033 seconds
# 		Loss: 0.015616820932306262
# 		Confusion Matrix
# 		   True  Negative:  56645
# 		   False Negative:  15
# 		   False Positive:  219
# 		   True  Positive:  83
# 		Accuracy:           0.996
# 		Precision:          0.275
# 		Sensitivity:        0.847
# 		Specificity:        0.996
# Epoch 28/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 14.979 seconds
# 		Loss: 0.008708830439739804
# 		Confusion Matrix
# 		   True  Negative:  226783
# 		   False Negative:  345
# 		   False Positive:  668
# 		   True  Positive:  151345
# 		Accuracy:           0.997
# 		Precision:          0.996
# 		Sensitivity:        0.998
# 		Specificity:        0.997
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.129 seconds
# 		Loss: 0.010420880686095212
# 		Confusion Matrix
# 		   True  Negative:  56754
# 		   False Negative:  17
# 		   False Positive:  110
# 		   True  Positive:  81
# 		Accuracy:           0.998
# 		Precision:          0.424
# 		Sensitivity:        0.827
# 		Specificity:        0.998
# Epoch 29/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 14.490 seconds
# 		Loss: 0.009098500786488852
# 		Confusion Matrix
# 		   True  Negative:  226737
# 		   False Negative:  385
# 		   False Positive:  714
# 		   True  Positive:  151305
# 		Accuracy:           0.997
# 		Precision:          0.995
# 		Sensitivity:        0.997
# 		Specificity:        0.997
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.144 seconds
# 		Loss: 0.0535653231502615
# 		Confusion Matrix
# 		   True  Negative:  55930
# 		   False Negative:  14
# 		   False Positive:  934
# 		   True  Positive:  84
# 		Accuracy:           0.983
# 		Precision:          0.083
# 		Sensitivity:        0.857
# 		Specificity:        0.984
# Epoch 30/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 14.442 seconds
# 		Loss: 0.008042599817730148
# 		Confusion Matrix
# 		   True  Negative:  226821
# 		   False Negative:  307
# 		   False Positive:  630
# 		   True  Positive:  151383
# 		Accuracy:           0.998
# 		Precision:          0.996
# 		Sensitivity:        0.998
# 		Specificity:        0.997
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.196 seconds
# 		Loss: 0.021848512392520076
# 		Confusion Matrix
# 		   True  Negative:  56591
# 		   False Negative:  11
# 		   False Positive:  273
# 		   True  Positive:  87
# 		Accuracy:           0.995
# 		Precision:          0.242
# 		Sensitivity:        0.888
# 		Specificity:        0.995

# %%
lstm_stats = run_model(LSTM(), label="LSTM", color="orange")
# Out:
# Epoch 1/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 165.162 seconds
# 		Loss: 0.1649920960012578
# 		Confusion Matrix
# 		   True  Negative:  223320
# 		   False Negative:  19510
# 		   False Positive:  4131
# 		   True  Positive:  132180
# 		Accuracy:           0.938
# 		Precision:          0.970
# 		Sensitivity:        0.871
# 		Specificity:        0.982
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 2.948 seconds
# 		Loss: 0.05763439415231548
# 		Confusion Matrix
# 		   True  Negative:  56227
# 		   False Negative:  10
# 		   False Positive:  637
# 		   True  Positive:  88
# 		Accuracy:           0.989
# 		Precision:          0.121
# 		Sensitivity:        0.898
# 		Specificity:        0.989
# Epoch 2/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 144.918 seconds
# 		Loss: 0.13789205274560687
# 		Confusion Matrix
# 		   True  Negative:  223244
# 		   False Negative:  15476
# 		   False Positive:  4207
# 		   True  Positive:  136214
# 		Accuracy:           0.948
# 		Precision:          0.970
# 		Sensitivity:        0.898
# 		Specificity:        0.982
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 2.652 seconds
# 		Loss: 0.02707596931130429
# 		Confusion Matrix
# 		   True  Negative:  56766
# 		   False Negative:  13
# 		   False Positive:  98
# 		   True  Positive:  85
# 		Accuracy:           0.998
# 		Precision:          0.464
# 		Sensitivity:        0.867
# 		Specificity:        0.998
# Epoch 3/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 151.817 seconds
# 		Loss: 0.12245169432957632
# 		Confusion Matrix
# 		   True  Negative:  222754
# 		   False Negative:  13451
# 		   False Positive:  4697
# 		   True  Positive:  138239
# 		Accuracy:           0.952
# 		Precision:          0.967
# 		Sensitivity:        0.911
# 		Specificity:        0.979
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 2.689 seconds
# 		Loss: 0.0629603297245008
# 		Confusion Matrix
# 		   True  Negative:  56303
# 		   False Negative:  10
# 		   False Positive:  561
# 		   True  Positive:  88
# 		Accuracy:           0.990
# 		Precision:          0.136
# 		Sensitivity:        0.898
# 		Specificity:        0.990
# Epoch 4/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 144.689 seconds
# 		Loss: 0.10535603680531927
# 		Confusion Matrix
# 		   True  Negative:  222596
# 		   False Negative:  11335
# 		   False Positive:  4855
# 		   True  Positive:  140355
# 		Accuracy:           0.957
# 		Precision:          0.967
# 		Sensitivity:        0.925
# 		Specificity:        0.979
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 2.655 seconds
# 		Loss: 0.03252982548144038
# 		Confusion Matrix
# 		   True  Negative:  56336
# 		   False Negative:  10
# 		   False Positive:  528
# 		   True  Positive:  88
# 		Accuracy:           0.991
# 		Precision:          0.143
# 		Sensitivity:        0.898
# 		Specificity:        0.991
# Epoch 5/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 147.237 seconds
# 		Loss: 0.09040248995364578
# 		Confusion Matrix
# 		   True  Negative:  222506
# 		   False Negative:  9262
# 		   False Positive:  4945
# 		   True  Positive:  142428
# 		Accuracy:           0.963
# 		Precision:          0.966
# 		Sensitivity:        0.939
# 		Specificity:        0.978
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 2.953 seconds
# 		Loss: 0.10854255965171641
# 		Confusion Matrix
# 		   True  Negative:  54731
# 		   False Negative:  10
# 		   False Positive:  2133
# 		   True  Positive:  88
# 		Accuracy:           0.962
# 		Precision:          0.040
# 		Sensitivity:        0.898
# 		Specificity:        0.962
# Epoch 6/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 147.194 seconds
# 		Loss: 0.07545396814800465
# 		Confusion Matrix
# 		   True  Negative:  222566
# 		   False Negative:  7078
# 		   False Positive:  4885
# 		   True  Positive:  144612
# 		Accuracy:           0.968
# 		Precision:          0.967
# 		Sensitivity:        0.953
# 		Specificity:        0.979
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 2.766 seconds
# 		Loss: 0.03932772139050776
# 		Confusion Matrix
# 		   True  Negative:  56169
# 		   False Negative:  11
# 		   False Positive:  695
# 		   True  Positive:  87
# 		Accuracy:           0.988
# 		Precision:          0.111
# 		Sensitivity:        0.888
# 		Specificity:        0.988
# Epoch 7/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 149.506 seconds
# 		Loss: 0.0633803025479584
# 		Confusion Matrix
# 		   True  Negative:  222800
# 		   False Negative:  5531
# 		   False Positive:  4651
# 		   True  Positive:  146159
# 		Accuracy:           0.973
# 		Precision:          0.969
# 		Sensitivity:        0.964
# 		Specificity:        0.980
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 2.775 seconds
# 		Loss: 0.0867773841799241
# 		Confusion Matrix
# 		   True  Negative:  54815
# 		   False Negative:  9
# 		   False Positive:  2049
# 		   True  Positive:  89
# 		Accuracy:           0.964
# 		Precision:          0.042
# 		Sensitivity:        0.908
# 		Specificity:        0.964
# Epoch 8/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 146.773 seconds
# 		Loss: 0.05502241710246089
# 		Confusion Matrix
# 		   True  Negative:  222955
# 		   False Negative:  4226
# 		   False Positive:  4496
# 		   True  Positive:  147464
# 		Accuracy:           0.977
# 		Precision:          0.970
# 		Sensitivity:        0.972
# 		Specificity:        0.980
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 2.914 seconds
# 		Loss: 0.02147179864442527
# 		Confusion Matrix
# 		   True  Negative:  56491
# 		   False Negative:  13
# 		   False Positive:  373
# 		   True  Positive:  85
# 		Accuracy:           0.993
# 		Precision:          0.186
# 		Sensitivity:        0.867
# 		Specificity:        0.993
# Epoch 9/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 146.795 seconds
# 		Loss: 0.047202912387694286
# 		Confusion Matrix
# 		   True  Negative:  223461
# 		   False Negative:  3266
# 		   False Positive:  3990
# 		   True  Positive:  148424
# 		Accuracy:           0.981
# 		Precision:          0.974
# 		Sensitivity:        0.978
# 		Specificity:        0.982
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 2.700 seconds
# 		Loss: 0.08540698289119476
# 		Confusion Matrix
# 		   True  Negative:  54621
# 		   False Negative:  10
# 		   False Positive:  2243
# 		   True  Positive:  88
# 		Accuracy:           0.960
# 		Precision:          0.038
# 		Sensitivity:        0.898
# 		Specificity:        0.961
# Epoch 10/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 145.548 seconds
# 		Loss: 0.044125640056675304
# 		Confusion Matrix
# 		   True  Negative:  223865
# 		   False Negative:  3079
# 		   False Positive:  3586
# 		   True  Positive:  148611
# 		Accuracy:           0.982
# 		Precision:          0.976
# 		Sensitivity:        0.980
# 		Specificity:        0.984
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 2.822 seconds
# 		Loss: 0.05370977333216456
# 		Confusion Matrix
# 		   True  Negative:  55703
# 		   False Negative:  13
# 		   False Positive:  1161
# 		   True  Positive:  85
# 		Accuracy:           0.979
# 		Precision:          0.068
# 		Sensitivity:        0.867
# 		Specificity:        0.980
# Epoch 11/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 149.704 seconds
# 		Loss: 0.04009465983725969
# 		Confusion Matrix
# 		   True  Negative:  224127
# 		   False Negative:  2621
# 		   False Positive:  3324
# 		   True  Positive:  149069
# 		Accuracy:           0.984
# 		Precision:          0.978
# 		Sensitivity:        0.983
# 		Specificity:        0.985
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 2.758 seconds
# 		Loss: 0.06180978054102435
# 		Confusion Matrix
# 		   True  Negative:  55449
# 		   False Negative:  9
# 		   False Positive:  1415
# 		   True  Positive:  89
# 		Accuracy:           0.975
# 		Precision:          0.059
# 		Sensitivity:        0.908
# 		Specificity:        0.975
# Epoch 12/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 154.641 seconds
# 		Loss: 0.03214570788858811
# 		Confusion Matrix
# 		   True  Negative:  224727
# 		   False Negative:  1748
# 		   False Positive:  2724
# 		   True  Positive:  149942
# 		Accuracy:           0.988
# 		Precision:          0.982
# 		Sensitivity:        0.988
# 		Specificity:        0.988
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 2.889 seconds
# 		Loss: 0.05212811901531132
# 		Confusion Matrix
# 		   True  Negative:  55731
# 		   False Negative:  13
# 		   False Positive:  1133
# 		   True  Positive:  85
# 		Accuracy:           0.980
# 		Precision:          0.070
# 		Sensitivity:        0.867
# 		Specificity:        0.980
# Epoch 13/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 145.327 seconds
# 		Loss: 0.026695138890328794
# 		Confusion Matrix
# 		   True  Negative:  225204
# 		   False Negative:  1305
# 		   False Positive:  2247
# 		   True  Positive:  150385
# 		Accuracy:           0.991
# 		Precision:          0.985
# 		Sensitivity:        0.991
# 		Specificity:        0.990
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 2.747 seconds
# 		Loss: 0.02119634066963501
# 		Confusion Matrix
# 		   True  Negative:  56519
# 		   False Negative:  13
# 		   False Positive:  345
# 		   True  Positive:  85
# 		Accuracy:           0.994
# 		Precision:          0.198
# 		Sensitivity:        0.867
# 		Specificity:        0.994
# Epoch 14/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 145.140 seconds
# 		Loss: 0.02563520172125494
# 		Confusion Matrix
# 		   True  Negative:  225331
# 		   False Negative:  1266
# 		   False Positive:  2120
# 		   True  Positive:  150424
# 		Accuracy:           0.991
# 		Precision:          0.986
# 		Sensitivity:        0.992
# 		Specificity:        0.991
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 3.310 seconds
# 		Loss: 0.0592339358066998
# 		Confusion Matrix
# 		   True  Negative:  55581
# 		   False Negative:  12
# 		   False Positive:  1283
# 		   True  Positive:  86
# 		Accuracy:           0.977
# 		Precision:          0.063
# 		Sensitivity:        0.878
# 		Specificity:        0.977
# Epoch 15/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 144.321 seconds
# 		Loss: 0.023294125168930507
# 		Confusion Matrix
# 		   True  Negative:  225502
# 		   False Negative:  1099
# 		   False Positive:  1949
# 		   True  Positive:  150591
# 		Accuracy:           0.992
# 		Precision:          0.987
# 		Sensitivity:        0.993
# 		Specificity:        0.991
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 2.697 seconds
# 		Loss: 0.014455381943538986
# 		Confusion Matrix
# 		   True  Negative:  56659
# 		   False Negative:  14
# 		   False Positive:  205
# 		   True  Positive:  84
# 		Accuracy:           0.996
# 		Precision:          0.291
# 		Sensitivity:        0.857
# 		Specificity:        0.996
# Epoch 16/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 150.804 seconds
# 		Loss: 0.019980621517800033
# 		Confusion Matrix
# 		   True  Negative:  225801
# 		   False Negative:  908
# 		   False Positive:  1650
# 		   True  Positive:  150782
# 		Accuracy:           0.993
# 		Precision:          0.989
# 		Sensitivity:        0.994
# 		Specificity:        0.993
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 2.995 seconds
# 		Loss: 0.022555147111972165
# 		Confusion Matrix
# 		   True  Negative:  56475
# 		   False Negative:  14
# 		   False Positive:  389
# 		   True  Positive:  84
# 		Accuracy:           0.993
# 		Precision:          0.178
# 		Sensitivity:        0.857
# 		Specificity:        0.993
# Epoch 17/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 147.663 seconds
# 		Loss: 0.01788126451099732
# 		Confusion Matrix
# 		   True  Negative:  225976
# 		   False Negative:  758
# 		   False Positive:  1475
# 		   True  Positive:  150932
# 		Accuracy:           0.994
# 		Precision:          0.990
# 		Sensitivity:        0.995
# 		Specificity:        0.994
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 2.754 seconds
# 		Loss: 0.013097468731546994
# 		Confusion Matrix
# 		   True  Negative:  56686
# 		   False Negative:  15
# 		   False Positive:  178
# 		   True  Positive:  83
# 		Accuracy:           0.997
# 		Precision:          0.318
# 		Sensitivity:        0.847
# 		Specificity:        0.997
# Epoch 18/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 150.035 seconds
# 		Loss: 0.017215573282079157
# 		Confusion Matrix
# 		   True  Negative:  226034
# 		   False Negative:  736
# 		   False Positive:  1417
# 		   True  Positive:  150954
# 		Accuracy:           0.994
# 		Precision:          0.991
# 		Sensitivity:        0.995
# 		Specificity:        0.994
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 2.765 seconds
# 		Loss: 0.012716409150364968
# 		Confusion Matrix
# 		   True  Negative:  56692
# 		   False Negative:  15
# 		   False Positive:  172
# 		   True  Positive:  83
# 		Accuracy:           0.997
# 		Precision:          0.325
# 		Sensitivity:        0.847
# 		Specificity:        0.997
# Epoch 19/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 199.019 seconds
# 		Loss: 0.015344710397061654
# 		Confusion Matrix
# 		   True  Negative:  226199
# 		   False Negative:  604
# 		   False Positive:  1252
# 		   True  Positive:  151086
# 		Accuracy:           0.995
# 		Precision:          0.992
# 		Sensitivity:        0.996
# 		Specificity:        0.994
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 2.959 seconds
# 		Loss: 0.023782670420273197
# 		Confusion Matrix
# 		   True  Negative:  56465
# 		   False Negative:  14
# 		   False Positive:  399
# 		   True  Positive:  84
# 		Accuracy:           0.993
# 		Precision:          0.174
# 		Sensitivity:        0.857
# 		Specificity:        0.993
# Epoch 20/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 163.598 seconds
# 		Loss: 0.013937142298194535
# 		Confusion Matrix
# 		   True  Negative:  226313
# 		   False Negative:  537
# 		   False Positive:  1138
# 		   True  Positive:  151153
# 		Accuracy:           0.996
# 		Precision:          0.993
# 		Sensitivity:        0.996
# 		Specificity:        0.995
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 3.360 seconds
# 		Loss: 0.010668153443844959
# 		Confusion Matrix
# 		   True  Negative:  56737
# 		   False Negative:  15
# 		   False Positive:  127
# 		   True  Positive:  83
# 		Accuracy:           0.998
# 		Precision:          0.395
# 		Sensitivity:        0.847
# 		Specificity:        0.998
# Epoch 21/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 167.867 seconds
# 		Loss: 0.013186614284104413
# 		Confusion Matrix
# 		   True  Negative:  226443
# 		   False Negative:  514
# 		   False Positive:  1008
# 		   True  Positive:  151176
# 		Accuracy:           0.996
# 		Precision:          0.993
# 		Sensitivity:        0.997
# 		Specificity:        0.996
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 3.529 seconds
# 		Loss: 0.01950578740905251
# 		Confusion Matrix
# 		   True  Negative:  56568
# 		   False Negative:  13
# 		   False Positive:  296
# 		   True  Positive:  85
# 		Accuracy:           0.995
# 		Precision:          0.223
# 		Sensitivity:        0.867
# 		Specificity:        0.995
# Epoch 22/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 178.840 seconds
# 		Loss: 0.012204333833338013
# 		Confusion Matrix
# 		   True  Negative:  226480
# 		   False Negative:  447
# 		   False Positive:  971
# 		   True  Positive:  151243
# 		Accuracy:           0.996
# 		Precision:          0.994
# 		Sensitivity:        0.997
# 		Specificity:        0.996
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 3.628 seconds
# 		Loss: 0.01230420351657557
# 		Confusion Matrix
# 		   True  Negative:  56725
# 		   False Negative:  14
# 		   False Positive:  139
# 		   True  Positive:  84
# 		Accuracy:           0.997
# 		Precision:          0.377
# 		Sensitivity:        0.857
# 		Specificity:        0.998
# Epoch 23/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 184.789 seconds
# 		Loss: 0.012207045977746368
# 		Confusion Matrix
# 		   True  Negative:  226502
# 		   False Negative:  496
# 		   False Positive:  949
# 		   True  Positive:  151194
# 		Accuracy:           0.996
# 		Precision:          0.994
# 		Sensitivity:        0.997
# 		Specificity:        0.996
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 3.626 seconds
# 		Loss: 0.013438546479253768
# 		Confusion Matrix
# 		   True  Negative:  56693
# 		   False Negative:  14
# 		   False Positive:  171
# 		   True  Positive:  84
# 		Accuracy:           0.997
# 		Precision:          0.329
# 		Sensitivity:        0.857
# 		Specificity:        0.997
# Epoch 24/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 174.394 seconds
# 		Loss: 0.01135378448891378
# 		Confusion Matrix
# 		   True  Negative:  226556
# 		   False Negative:  419
# 		   False Positive:  895
# 		   True  Positive:  151271
# 		Accuracy:           0.997
# 		Precision:          0.994
# 		Sensitivity:        0.997
# 		Specificity:        0.996
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 4.075 seconds
# 		Loss: 0.016070564288352185
# 		Confusion Matrix
# 		   True  Negative:  56628
# 		   False Negative:  14
# 		   False Positive:  236
# 		   True  Positive:  84
# 		Accuracy:           0.996
# 		Precision:          0.263
# 		Sensitivity:        0.857
# 		Specificity:        0.996
# Epoch 25/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 179.796 seconds
# 		Loss: 0.012031350806856812
# 		Confusion Matrix
# 		   True  Negative:  226480
# 		   False Negative:  501
# 		   False Positive:  971
# 		   True  Positive:  151189
# 		Accuracy:           0.996
# 		Precision:          0.994
# 		Sensitivity:        0.997
# 		Specificity:        0.996
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 4.171 seconds
# 		Loss: 0.012188089679717866
# 		Confusion Matrix
# 		   True  Negative:  56714
# 		   False Negative:  14
# 		   False Positive:  150
# 		   True  Positive:  84
# 		Accuracy:           0.997
# 		Precision:          0.359
# 		Sensitivity:        0.857
# 		Specificity:        0.997
# Epoch 26/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 190.658 seconds
# 		Loss: 0.04515659066290072
# 		Confusion Matrix
# 		   True  Negative:  224292
# 		   False Negative:  3260
# 		   False Positive:  3159
# 		   True  Positive:  148430
# 		Accuracy:           0.983
# 		Precision:          0.979
# 		Sensitivity:        0.979
# 		Specificity:        0.986
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 3.601 seconds
# 		Loss: 0.024717450008945138
# 		Confusion Matrix
# 		   True  Negative:  56387
# 		   False Negative:  13
# 		   False Positive:  477
# 		   True  Positive:  85
# 		Accuracy:           0.991
# 		Precision:          0.151
# 		Sensitivity:        0.867
# 		Specificity:        0.992
# Epoch 27/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 179.079 seconds
# 		Loss: 0.022364711821524955
# 		Confusion Matrix
# 		   True  Negative:  225581
# 		   False Negative:  968
# 		   False Positive:  1870
# 		   True  Positive:  150722
# 		Accuracy:           0.993
# 		Precision:          0.988
# 		Sensitivity:        0.994
# 		Specificity:        0.992
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 3.796 seconds
# 		Loss: 0.022513242305975605
# 		Confusion Matrix
# 		   True  Negative:  56502
# 		   False Negative:  14
# 		   False Positive:  362
# 		   True  Positive:  84
# 		Accuracy:           0.993
# 		Precision:          0.188
# 		Sensitivity:        0.857
# 		Specificity:        0.994
# Epoch 28/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 181.654 seconds
# 		Loss: 0.018640621056795308
# 		Confusion Matrix
# 		   True  Negative:  225932
# 		   False Negative:  748
# 		   False Positive:  1519
# 		   True  Positive:  150942
# 		Accuracy:           0.994
# 		Precision:          0.990
# 		Sensitivity:        0.995
# 		Specificity:        0.993
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 3.784 seconds
# 		Loss: 0.02274926455569658
# 		Confusion Matrix
# 		   True  Negative:  56467
# 		   False Negative:  16
# 		   False Positive:  397
# 		   True  Positive:  82
# 		Accuracy:           0.993
# 		Precision:          0.171
# 		Sensitivity:        0.837
# 		Specificity:        0.993
# Epoch 29/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 181.848 seconds
# 		Loss: 0.01981924627211754
# 		Confusion Matrix
# 		   True  Negative:  225869
# 		   False Negative:  867
# 		   False Positive:  1582
# 		   True  Positive:  150823
# 		Accuracy:           0.994
# 		Precision:          0.990
# 		Sensitivity:        0.994
# 		Specificity:        0.993
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 3.622 seconds
# 		Loss: 0.016260899724433137
# 		Confusion Matrix
# 		   True  Negative:  56592
# 		   False Negative:  15
# 		   False Positive:  272
# 		   True  Positive:  83
# 		Accuracy:           0.995
# 		Precision:          0.234
# 		Sensitivity:        0.847
# 		Specificity:        0.995
# Epoch 30/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 188.716 seconds
# 		Loss: 0.015242355361860119
# 		Confusion Matrix
# 		   True  Negative:  226270
# 		   False Negative:  585
# 		   False Positive:  1181
# 		   True  Positive:  151105
# 		Accuracy:           0.995
# 		Precision:          0.992
# 		Sensitivity:        0.996
# 		Specificity:        0.995
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 3.726 seconds
# 		Loss: 0.02388099529749269
# 		Confusion Matrix
# 		   True  Negative:  56471
# 		   False Negative:  13
# 		   False Positive:  393
# 		   True  Positive:  85
# 		Accuracy:           0.993
# 		Precision:          0.178
# 		Sensitivity:        0.867
# 		Specificity:        0.993

# %%
scnn_stats = run_model(SCNN(), label="SCNN", color="red")
# Out:
# Epoch 1/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 13.306 seconds
# 		Loss: 0.23460934541986234
# 		Confusion Matrix
# 		   True  Negative:  223232
# 		   False Negative:  27055
# 		   False Positive:  4219
# 		   True  Positive:  124635
# 		Accuracy:           0.918
# 		Precision:          0.967
# 		Sensitivity:        0.822
# 		Specificity:        0.981
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.053 seconds
# 		Loss: 0.11680390644033393
# 		Confusion Matrix
# 		   True  Negative:  55140
# 		   False Negative:  8
# 		   False Positive:  1724
# 		   True  Positive:  90
# 		Accuracy:           0.970
# 		Precision:          0.050
# 		Sensitivity:        0.918
# 		Specificity:        0.970
# Epoch 2/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 12.816 seconds
# 		Loss: 0.1420213974763363
# 		Confusion Matrix
# 		   True  Negative:  222890
# 		   False Negative:  15103
# 		   False Positive:  4561
# 		   True  Positive:  136587
# 		Accuracy:           0.948
# 		Precision:          0.968
# 		Sensitivity:        0.900
# 		Specificity:        0.980
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.032 seconds
# 		Loss: 0.047862598409400124
# 		Confusion Matrix
# 		   True  Negative:  56242
# 		   False Negative:  10
# 		   False Positive:  622
# 		   True  Positive:  88
# 		Accuracy:           0.989
# 		Precision:          0.124
# 		Sensitivity:        0.898
# 		Specificity:        0.989
# Epoch 3/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 13.327 seconds
# 		Loss: 0.12948260039004358
# 		Confusion Matrix
# 		   True  Negative:  222946
# 		   False Negative:  13994
# 		   False Positive:  4505
# 		   True  Positive:  137696
# 		Accuracy:           0.951
# 		Precision:          0.968
# 		Sensitivity:        0.908
# 		Specificity:        0.980
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.078 seconds
# 		Loss: 0.03896353970336072
# 		Confusion Matrix
# 		   True  Negative:  56389
# 		   False Negative:  11
# 		   False Positive:  475
# 		   True  Positive:  87
# 		Accuracy:           0.991
# 		Precision:          0.155
# 		Sensitivity:        0.888
# 		Specificity:        0.992
# Epoch 4/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 11.930 seconds
# 		Loss: 0.1208029634750175
# 		Confusion Matrix
# 		   True  Negative:  222947
# 		   False Negative:  13011
# 		   False Positive:  4504
# 		   True  Positive:  138679
# 		Accuracy:           0.954
# 		Precision:          0.969
# 		Sensitivity:        0.914
# 		Specificity:        0.980
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.943 seconds
# 		Loss: 0.06118343827302146
# 		Confusion Matrix
# 		   True  Negative:  56000
# 		   False Negative:  10
# 		   False Positive:  864
# 		   True  Positive:  88
# 		Accuracy:           0.985
# 		Precision:          0.092
# 		Sensitivity:        0.898
# 		Specificity:        0.985
# Epoch 5/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 11.346 seconds
# 		Loss: 0.11387766308836084
# 		Confusion Matrix
# 		   True  Negative:  222882
# 		   False Negative:  11878
# 		   False Positive:  4569
# 		   True  Positive:  139812
# 		Accuracy:           0.957
# 		Precision:          0.968
# 		Sensitivity:        0.922
# 		Specificity:        0.980
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.928 seconds
# 		Loss: 0.056803370642187614
# 		Confusion Matrix
# 		   True  Negative:  56018
# 		   False Negative:  10
# 		   False Positive:  846
# 		   True  Positive:  88
# 		Accuracy:           0.985
# 		Precision:          0.094
# 		Sensitivity:        0.898
# 		Specificity:        0.985
# Epoch 6/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 12.690 seconds
# 		Loss: 0.10752132901349182
# 		Confusion Matrix
# 		   True  Negative:  222854
# 		   False Negative:  11003
# 		   False Positive:  4597
# 		   True  Positive:  140687
# 		Accuracy:           0.959
# 		Precision:          0.968
# 		Sensitivity:        0.927
# 		Specificity:        0.980
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.182 seconds
# 		Loss: 0.1759573829782116
# 		Confusion Matrix
# 		   True  Negative:  53106
# 		   False Negative:  7
# 		   False Positive:  3758
# 		   True  Positive:  91
# 		Accuracy:           0.934
# 		Precision:          0.024
# 		Sensitivity:        0.929
# 		Specificity:        0.934
# Epoch 7/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 13.115 seconds
# 		Loss: 0.10217917435829237
# 		Confusion Matrix
# 		   True  Negative:  222930
# 		   False Negative:  10453
# 		   False Positive:  4521
# 		   True  Positive:  141237
# 		Accuracy:           0.961
# 		Precision:          0.969
# 		Sensitivity:        0.931
# 		Specificity:        0.980
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.173 seconds
# 		Loss: 0.11673451078044994
# 		Confusion Matrix
# 		   True  Negative:  54608
# 		   False Negative:  8
# 		   False Positive:  2256
# 		   True  Positive:  90
# 		Accuracy:           0.960
# 		Precision:          0.038
# 		Sensitivity:        0.918
# 		Specificity:        0.960
# Epoch 8/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 13.212 seconds
# 		Loss: 0.09745843334335971
# 		Confusion Matrix
# 		   True  Negative:  223040
# 		   False Negative:  10018
# 		   False Positive:  4411
# 		   True  Positive:  141672
# 		Accuracy:           0.962
# 		Precision:          0.970
# 		Sensitivity:        0.934
# 		Specificity:        0.981
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.960 seconds
# 		Loss: 0.034745868497983355
# 		Confusion Matrix
# 		   True  Negative:  56384
# 		   False Negative:  11
# 		   False Positive:  480
# 		   True  Positive:  87
# 		Accuracy:           0.991
# 		Precision:          0.153
# 		Sensitivity:        0.888
# 		Specificity:        0.992
# Epoch 9/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 14.246 seconds
# 		Loss: 0.0935140704931619
# 		Confusion Matrix
# 		   True  Negative:  222954
# 		   False Negative:  9569
# 		   False Positive:  4497
# 		   True  Positive:  142121
# 		Accuracy:           0.963
# 		Precision:          0.969
# 		Sensitivity:        0.937
# 		Specificity:        0.980
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.019 seconds
# 		Loss: 0.03337816136258533
# 		Confusion Matrix
# 		   True  Negative:  56429
# 		   False Negative:  11
# 		   False Positive:  435
# 		   True  Positive:  87
# 		Accuracy:           0.992
# 		Precision:          0.167
# 		Sensitivity:        0.888
# 		Specificity:        0.992
# Epoch 10/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 14.085 seconds
# 		Loss: 0.08882835098072997
# 		Confusion Matrix
# 		   True  Negative:  222975
# 		   False Negative:  9061
# 		   False Positive:  4476
# 		   True  Positive:  142629
# 		Accuracy:           0.964
# 		Precision:          0.970
# 		Sensitivity:        0.940
# 		Specificity:        0.980
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.102 seconds
# 		Loss: 0.036852243161163055
# 		Confusion Matrix
# 		   True  Negative:  56299
# 		   False Negative:  11
# 		   False Positive:  565
# 		   True  Positive:  87
# 		Accuracy:           0.990
# 		Precision:          0.133
# 		Sensitivity:        0.888
# 		Specificity:        0.990
# Epoch 11/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 10.359 seconds
# 		Loss: 0.08411210095035268
# 		Confusion Matrix
# 		   True  Negative:  223031
# 		   False Negative:  8613
# 		   False Positive:  4420
# 		   True  Positive:  143077
# 		Accuracy:           0.966
# 		Precision:          0.970
# 		Sensitivity:        0.943
# 		Specificity:        0.981
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.870 seconds
# 		Loss: 0.0416908373830698
# 		Confusion Matrix
# 		   True  Negative:  56186
# 		   False Negative:  11
# 		   False Positive:  678
# 		   True  Positive:  87
# 		Accuracy:           0.988
# 		Precision:          0.114
# 		Sensitivity:        0.888
# 		Specificity:        0.988
# Epoch 12/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 11.805 seconds
# 		Loss: 0.08116687710382486
# 		Confusion Matrix
# 		   True  Negative:  223092
# 		   False Negative:  8144
# 		   False Positive:  4359
# 		   True  Positive:  143546
# 		Accuracy:           0.967
# 		Precision:          0.971
# 		Sensitivity:        0.946
# 		Specificity:        0.981
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.131 seconds
# 		Loss: 0.0623624099819449
# 		Confusion Matrix
# 		   True  Negative:  55659
# 		   False Negative:  9
# 		   False Positive:  1205
# 		   True  Positive:  89
# 		Accuracy:           0.979
# 		Precision:          0.069
# 		Sensitivity:        0.908
# 		Specificity:        0.979
# Epoch 13/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 11.766 seconds
# 		Loss: 0.07738910543748376
# 		Confusion Matrix
# 		   True  Negative:  223193
# 		   False Negative:  7648
# 		   False Positive:  4258
# 		   True  Positive:  144042
# 		Accuracy:           0.969
# 		Precision:          0.971
# 		Sensitivity:        0.950
# 		Specificity:        0.981
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.016 seconds
# 		Loss: 0.02155638989708449
# 		Confusion Matrix
# 		   True  Negative:  56573
# 		   False Negative:  11
# 		   False Positive:  291
# 		   True  Positive:  87
# 		Accuracy:           0.995
# 		Precision:          0.230
# 		Sensitivity:        0.888
# 		Specificity:        0.995
# Epoch 14/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 11.633 seconds
# 		Loss: 0.07360281760908394
# 		Confusion Matrix
# 		   True  Negative:  223230
# 		   False Negative:  7128
# 		   False Positive:  4221
# 		   True  Positive:  144562
# 		Accuracy:           0.970
# 		Precision:          0.972
# 		Sensitivity:        0.953
# 		Specificity:        0.981
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.970 seconds
# 		Loss: 0.06886822143527825
# 		Confusion Matrix
# 		   True  Negative:  55419
# 		   False Negative:  9
# 		   False Positive:  1445
# 		   True  Positive:  89
# 		Accuracy:           0.974
# 		Precision:          0.058
# 		Sensitivity:        0.908
# 		Specificity:        0.975
# Epoch 15/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 11.545 seconds
# 		Loss: 0.07021321519678744
# 		Confusion Matrix
# 		   True  Negative:  223198
# 		   False Negative:  6600
# 		   False Positive:  4253
# 		   True  Positive:  145090
# 		Accuracy:           0.971
# 		Precision:          0.972
# 		Sensitivity:        0.956
# 		Specificity:        0.981
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.980 seconds
# 		Loss: 0.1371369070953986
# 		Confusion Matrix
# 		   True  Negative:  53598
# 		   False Negative:  8
# 		   False Positive:  3266
# 		   True  Positive:  90
# 		Accuracy:           0.943
# 		Precision:          0.027
# 		Sensitivity:        0.918
# 		Specificity:        0.943
# Epoch 16/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 11.631 seconds
# 		Loss: 0.06684482827785146
# 		Confusion Matrix
# 		   True  Negative:  223255
# 		   False Negative:  6130
# 		   False Positive:  4196
# 		   True  Positive:  145560
# 		Accuracy:           0.973
# 		Precision:          0.972
# 		Sensitivity:        0.960
# 		Specificity:        0.982
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.009 seconds
# 		Loss: 0.04263758019339544
# 		Confusion Matrix
# 		   True  Negative:  56050
# 		   False Negative:  11
# 		   False Positive:  814
# 		   True  Positive:  87
# 		Accuracy:           0.986
# 		Precision:          0.097
# 		Sensitivity:        0.888
# 		Specificity:        0.986
# Epoch 17/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 12.650 seconds
# 		Loss: 0.0652649786374857
# 		Confusion Matrix
# 		   True  Negative:  223326
# 		   False Negative:  5899
# 		   False Positive:  4125
# 		   True  Positive:  145791
# 		Accuracy:           0.974
# 		Precision:          0.972
# 		Sensitivity:        0.961
# 		Specificity:        0.982
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.967 seconds
# 		Loss: 0.04474607381328623
# 		Confusion Matrix
# 		   True  Negative:  55992
# 		   False Negative:  12
# 		   False Positive:  872
# 		   True  Positive:  86
# 		Accuracy:           0.984
# 		Precision:          0.090
# 		Sensitivity:        0.878
# 		Specificity:        0.985
# Epoch 18/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 11.676 seconds
# 		Loss: 0.06212909260313358
# 		Confusion Matrix
# 		   True  Negative:  223340
# 		   False Negative:  5509
# 		   False Positive:  4111
# 		   True  Positive:  146181
# 		Accuracy:           0.975
# 		Precision:          0.973
# 		Sensitivity:        0.964
# 		Specificity:        0.982
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.963 seconds
# 		Loss: 0.3047186696041593
# 		Confusion Matrix
# 		   True  Negative:  48915
# 		   False Negative:  6
# 		   False Positive:  7949
# 		   True  Positive:  92
# 		Accuracy:           0.860
# 		Precision:          0.011
# 		Sensitivity:        0.939
# 		Specificity:        0.860
# Epoch 19/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 12.123 seconds
# 		Loss: 0.0617977641786911
# 		Confusion Matrix
# 		   True  Negative:  223456
# 		   False Negative:  5426
# 		   False Positive:  3995
# 		   True  Positive:  146264
# 		Accuracy:           0.975
# 		Precision:          0.973
# 		Sensitivity:        0.964
# 		Specificity:        0.982
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.008 seconds
# 		Loss: 0.03617251041473721
# 		Confusion Matrix
# 		   True  Negative:  56203
# 		   False Negative:  14
# 		   False Positive:  661
# 		   True  Positive:  84
# 		Accuracy:           0.988
# 		Precision:          0.113
# 		Sensitivity:        0.857
# 		Specificity:        0.988
# Epoch 20/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 11.766 seconds
# 		Loss: 0.05879249509205206
# 		Confusion Matrix
# 		   True  Negative:  223466
# 		   False Negative:  5157
# 		   False Positive:  3985
# 		   True  Positive:  146533
# 		Accuracy:           0.976
# 		Precision:          0.974
# 		Sensitivity:        0.966
# 		Specificity:        0.982
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.991 seconds
# 		Loss: 0.05555760369880434
# 		Confusion Matrix
# 		   True  Negative:  55711
# 		   False Negative:  13
# 		   False Positive:  1153
# 		   True  Positive:  85
# 		Accuracy:           0.980
# 		Precision:          0.069
# 		Sensitivity:        0.867
# 		Specificity:        0.980
# Epoch 21/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 11.904 seconds
# 		Loss: 0.05628640493164307
# 		Confusion Matrix
# 		   True  Negative:  223551
# 		   False Negative:  4820
# 		   False Positive:  3900
# 		   True  Positive:  146870
# 		Accuracy:           0.977
# 		Precision:          0.974
# 		Sensitivity:        0.968
# 		Specificity:        0.983
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.044 seconds
# 		Loss: 0.03528215566656819
# 		Confusion Matrix
# 		   True  Negative:  56172
# 		   False Negative:  15
# 		   False Positive:  692
# 		   True  Positive:  83
# 		Accuracy:           0.988
# 		Precision:          0.107
# 		Sensitivity:        0.847
# 		Specificity:        0.988
# Epoch 22/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 13.873 seconds
# 		Loss: 0.05407189758094685
# 		Confusion Matrix
# 		   True  Negative:  223612
# 		   False Negative:  4499
# 		   False Positive:  3839
# 		   True  Positive:  147191
# 		Accuracy:           0.978
# 		Precision:          0.975
# 		Sensitivity:        0.970
# 		Specificity:        0.983
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.986 seconds
# 		Loss: 0.05224419414768446
# 		Confusion Matrix
# 		   True  Negative:  55770
# 		   False Negative:  14
# 		   False Positive:  1094
# 		   True  Positive:  84
# 		Accuracy:           0.981
# 		Precision:          0.071
# 		Sensitivity:        0.857
# 		Specificity:        0.981
# Epoch 23/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 12.695 seconds
# 		Loss: 0.05399886772519305
# 		Confusion Matrix
# 		   True  Negative:  223590
# 		   False Negative:  4521
# 		   False Positive:  3861
# 		   True  Positive:  147169
# 		Accuracy:           0.978
# 		Precision:          0.974
# 		Sensitivity:        0.970
# 		Specificity:        0.983
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.025 seconds
# 		Loss: 0.031021218743246266
# 		Confusion Matrix
# 		   True  Negative:  56294
# 		   False Negative:  15
# 		   False Positive:  570
# 		   True  Positive:  83
# 		Accuracy:           0.990
# 		Precision:          0.127
# 		Sensitivity:        0.847
# 		Specificity:        0.990
# Epoch 24/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 13.694 seconds
# 		Loss: 0.05103205941331205
# 		Confusion Matrix
# 		   True  Negative:  223716
# 		   False Negative:  4025
# 		   False Positive:  3735
# 		   True  Positive:  147665
# 		Accuracy:           0.980
# 		Precision:          0.975
# 		Sensitivity:        0.973
# 		Specificity:        0.984
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.055 seconds
# 		Loss: 0.02671237158784961
# 		Confusion Matrix
# 		   True  Negative:  56378
# 		   False Negative:  15
# 		   False Positive:  486
# 		   True  Positive:  83
# 		Accuracy:           0.991
# 		Precision:          0.146
# 		Sensitivity:        0.847
# 		Specificity:        0.991
# Epoch 25/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 12.568 seconds
# 		Loss: 0.0497388748878439
# 		Confusion Matrix
# 		   True  Negative:  223687
# 		   False Negative:  3862
# 		   False Positive:  3764
# 		   True  Positive:  147828
# 		Accuracy:           0.980
# 		Precision:          0.975
# 		Sensitivity:        0.975
# 		Specificity:        0.983
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.099 seconds
# 		Loss: 0.037122397752845586
# 		Confusion Matrix
# 		   True  Negative:  56118
# 		   False Negative:  15
# 		   False Positive:  746
# 		   True  Positive:  83
# 		Accuracy:           0.987
# 		Precision:          0.100
# 		Sensitivity:        0.847
# 		Specificity:        0.987
# Epoch 26/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 11.868 seconds
# 		Loss: 0.04858990215108307
# 		Confusion Matrix
# 		   True  Negative:  223779
# 		   False Negative:  3668
# 		   False Positive:  3672
# 		   True  Positive:  148022
# 		Accuracy:           0.981
# 		Precision:          0.976
# 		Sensitivity:        0.976
# 		Specificity:        0.984
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.988 seconds
# 		Loss: 0.02231113045637753
# 		Confusion Matrix
# 		   True  Negative:  56487
# 		   False Negative:  15
# 		   False Positive:  377
# 		   True  Positive:  83
# 		Accuracy:           0.993
# 		Precision:          0.180
# 		Sensitivity:        0.847
# 		Specificity:        0.993
# Epoch 27/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 12.299 seconds
# 		Loss: 0.04718484624271375
# 		Confusion Matrix
# 		   True  Negative:  223856
# 		   False Negative:  3600
# 		   False Positive:  3595
# 		   True  Positive:  148090
# 		Accuracy:           0.981
# 		Precision:          0.976
# 		Sensitivity:        0.976
# 		Specificity:        0.984
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.399 seconds
# 		Loss: 0.08401698144924077
# 		Confusion Matrix
# 		   True  Negative:  54932
# 		   False Negative:  13
# 		   False Positive:  1932
# 		   True  Positive:  85
# 		Accuracy:           0.966
# 		Precision:          0.042
# 		Sensitivity:        0.867
# 		Specificity:        0.966
# Epoch 28/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 11.018 seconds
# 		Loss: 0.044620661165799734
# 		Confusion Matrix
# 		   True  Negative:  223987
# 		   False Negative:  3173
# 		   False Positive:  3464
# 		   True  Positive:  148517
# 		Accuracy:           0.982
# 		Precision:          0.977
# 		Sensitivity:        0.979
# 		Specificity:        0.985
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.856 seconds
# 		Loss: 0.039031242728161886
# 		Confusion Matrix
# 		   True  Negative:  56070
# 		   False Negative:  15
# 		   False Positive:  794
# 		   True  Positive:  83
# 		Accuracy:           0.986
# 		Precision:          0.095
# 		Sensitivity:        0.847
# 		Specificity:        0.986
# Epoch 29/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 10.234 seconds
# 		Loss: 0.04362624611169945
# 		Confusion Matrix
# 		   True  Negative:  224005
# 		   False Negative:  2962
# 		   False Positive:  3446
# 		   True  Positive:  148728
# 		Accuracy:           0.983
# 		Precision:          0.977
# 		Sensitivity:        0.980
# 		Specificity:        0.985
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 0.942 seconds
# 		Loss: 0.07773109307672385
# 		Confusion Matrix
# 		   True  Negative:  55103
# 		   False Negative:  14
# 		   False Positive:  1761
# 		   True  Positive:  84
# 		Accuracy:           0.969
# 		Precision:          0.046
# 		Sensitivity:        0.857
# 		Specificity:        0.969
# Epoch 30/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]   2963/2963 Waiting for 11.191 seconds
# 		Loss: 0.042139079745269876
# 		Confusion Matrix
# 		   True  Negative:  224104
# 		   False Negative:  2787
# 		   False Positive:  3347
# 		   True  Positive:  148903
# 		Accuracy:           0.984
# 		Precision:          0.978
# 		Sensitivity:        0.982
# 		Specificity:        0.985
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    446/446 Waiting for 1.140 seconds
# 		Loss: 0.05732589450908481
# 		Confusion Matrix
# 		   True  Negative:  55622
# 		   False Negative:  15
# 		   False Positive:  1242
# 		   True  Positive:  83
# 		Accuracy:           0.978
# 		Precision:          0.063
# 		Sensitivity:        0.847
# 		Specificity:        0.978

# %% [markdown]
# # Comparative Analyse

# %%
models = [mlp_stats, cnn_stats, lstm_stats, scnn_stats]

# %% [markdown]
# ### Extracting Visualization

# %%
# Define line plots
# Loss
loss = figure(width=800, height=400, title="Loss")
delta_loss = figure(width=800, height=400, title="Overfitting")

delta_loss.yaxis.axis_label = "Val - Train Loss"

# Metrics
accuracy = figure(width=800, height=400, title="Accuracy")
precision = figure(width=800, height=400, title="Precision")
sensitivity = figure(width=800, height=400, title="Sensitivity")
specificity = figure(width=800, height=400, title="Specificity")

guide = [[0], [0], [1], [1], [1], [1]]
for i, fig in enumerate([loss, delta_loss, accuracy, precision, sensitivity, specificity]):
    fig.add_layout(Legend(), 'right')
    fig.line([0], guide[i], line_width=3, legend_label="Training", line_dash="dashed",line_color="black")
    fig.xaxis.axis_label = 'epoch'

# Create auxiliar arrays
x_epoches = np.arange(EPOCHS)

# Plot lines
for stats in models:
    label = stats["Label"]
    color = stats["Color"]
    line_w = 3

    # Plot loss data
    loss.line(x_epoches, stats["Validation"]["Loss"], line_width=line_w, legend_label=label,line_color=color)
    loss.line(x_epoches, stats["Training"]["Loss"], line_width=line_w, line_dash="dashed", line_color=color)

    delta = stats["Validation"]["Loss"] - stats["Training"]["Loss"]
    delta_loss.line(x_epoches, delta, line_width=line_w, legend_label=label, line_color=color)

    # Plot Validation Metrics
    accuracy.line(x_epoches, stats["Validation"]["Accuracy"], line_width=line_w, legend_label=label, line_color=color)
    precision.line(x_epoches, stats["Validation"]["Precision"], line_width=line_w, legend_label=label, line_color=color)
    sensitivity.line(x_epoches, stats["Validation"]["Sensitivity"], line_width=line_w, legend_label=label, line_color=color)
    specificity.line(x_epoches, stats["Validation"]["Specificity"], line_width=line_w, legend_label=label, line_color=color)

    # Plot Training Metrics
    accuracy.line(x_epoches, stats["Training"]["Accuracy"], line_width=line_w, line_color=color, line_dash="dashed")
    precision.line(x_epoches, stats["Training"]["Precision"], line_width=line_w, line_color=color, line_dash="dashed")
    sensitivity.line(x_epoches, stats["Training"]["Sensitivity"], line_width=line_w, line_color=color, line_dash="dashed")
    specificity.line(x_epoches, stats["Training"]["Specificity"], line_width=line_w, line_color=color, line_dash="dashed")

# %%
# Prepare histograms
model_labels = []

total_time_values = [[],[]]
epoch_time_values = [[],[]]

parameters = []

best_acc  = [[],[]]
best_pre  = [[],[]]
best_sen  = [[],[]]
best_spe  = [[],[]]

for stats in models:
    label = stats["Label"]
    model_labels.append(label)

    total_time_values[0].append(stats["Training"]["Time"])
    epoch_time_values[0].append(stats["Training"]["Time/Epoch"])
    total_time_values[1].append(stats["Validation"]["Time"])
    epoch_time_values[1].append(stats["Validation"]["Time/Epoch"])


    parameters.append(stats["Parameters"])
    
    best_acc[0].append(max(stats["Training"]["Accuracy"]))
    best_acc[1].append(max(stats["Validation"]["Accuracy"]))
    
    best_pre[0].append(max(stats["Training"]["Precision"]))
    best_pre[1].append(max(stats["Validation"]["Precision"]))
    
    best_sen[0].append(max(stats["Training"]["Sensitivity"]))
    best_sen[1].append(max(stats["Validation"]["Sensitivity"]))
    
    best_spe[0].append(max(stats["Training"]["Specificity"]))
    best_spe[1].append(max(stats["Validation"]["Specificity"]))

# %%
# Time related
total_time = figure(x_range=model_labels, width=800, height=400, title="Total Running Time")
epoch_time = figure(x_range=model_labels, width=800, height=400, title="Time per Epoch")

total_time.vbar(x=model_labels, top=total_time_values[0], color="navy", width=0.75,legend_label="Training")
total_time.vbar(x=model_labels, top=total_time_values[1], color="orange", width=0.5,legend_label="Validation")

epoch_time.vbar(x=model_labels, top=epoch_time_values[0], color="navy", width=0.75,legend_label="Training")
epoch_time.vbar(x=model_labels, top=epoch_time_values[1], color="orange", width=0.5,legend_label="Validation")

for fig in [total_time, epoch_time]:
    fig.legend.location = 'top_left'
    fig.yaxis.axis_label = 'seconds'
    fig.y_range.start = 0

# %%
# Parameter
param = figure(x_range=model_labels, width=800, height=400, title="Parameters")
param_exp = figure(x_range=model_labels, width=800, height=400, title="Parameters", y_axis_type="log",  y_range = [10 ** 3, 10 ** 5])

param.vbar(x=model_labels, top=parameters, color="navy", width=0.75)
param_exp.vbar(x=model_labels, bottom=[10 ** 0]*len(model_labels), top=parameters, color="navy", width=0.75)

param.y_range.start = 0

# %%
# Best performance plots
b_accuracy    = figure(x_range=model_labels, width=800, height=400, title="Best Accuracy")
b_precision   = figure(x_range=model_labels, width=800, height=400, title="Best Precision")
b_sensitivity = figure(x_range=model_labels, width=800, height=400, title="Best Sensitivity")
b_specificity = figure(x_range=model_labels, width=800, height=400, title="Best Specificity")

# Add unified evolution legends
for fig in [b_accuracy, b_precision, b_sensitivity, b_specificity]:
    fig.add_layout(Legend(), 'right')

b_accuracy.vbar(x=model_labels, top=best_acc[0], color="navy", width=0.75,legend_label="Training")
b_accuracy.vbar(x=model_labels, top=best_acc[1], color="orange", width=0.5,legend_label="Validation")
b_accuracy.y_range.start = 0.95

b_precision.vbar(x=model_labels, top=best_pre[0], color="navy", width=0.75,legend_label="Training")
b_precision.vbar(x=model_labels, top=best_pre[1], color="orange", width=0.5,legend_label="Validation")
b_precision.y_range.start = 0

b_sensitivity.vbar(x=model_labels, top=best_sen[0], color="navy", width=0.75,legend_label="Training")
b_sensitivity.vbar(x=model_labels, top=best_sen[1], color="orange", width=0.5,legend_label="Validation")
b_sensitivity.y_range.start = 0.9

b_specificity.vbar(x=model_labels, top=best_spe[0], color="navy", width=0.75,legend_label="Training")
b_specificity.vbar(x=model_labels, top=best_spe[1], color="orange", width=0.5,legend_label="Validation")
b_specificity.y_range.start = 0.985

# %% [markdown]
# ### Visualizing

# %%
# Increase font size and make them all bold
for fig in [
    param, param_exp,
    loss, delta_loss,
    total_time, epoch_time,
    accuracy, b_accuracy,
    precision, b_precision,
    sensitivity, b_sensitivity,
    specificity, b_specificity,
]:
    fig.title.text_font_size = "15pt"
    fig.title.padding = 5
    
    fig.yaxis.major_label_text_font_size = "12pt"
    fig.yaxis.major_label_text_font_style = "bold"
    fig.yaxis.axis_label_text_font_size = "12pt"
    fig.yaxis.axis_label_text_font_style = "bold"
    
    fig.xaxis.major_label_text_font_size = "12pt"
    fig.xaxis.major_label_text_font_style = "bold"
    fig.xaxis.axis_label_text_font_size = "12pt"
    fig.xaxis.axis_label_text_font_style = "bold"

# %%
# Create tabs using TabPanel
tabs = Tabs(tabs=[
    TabPanel(child=column(param, param_exp), title="Size"),
    TabPanel(child=column(loss, delta_loss), title="Loss"),
    TabPanel(child=column(total_time, epoch_time), title="Time"),
    TabPanel(child=column(accuracy, b_accuracy), title="Accuracy"),
    TabPanel(child=column(precision, b_precision), title="Precision"),
    TabPanel(child=column(sensitivity, b_sensitivity), title="Sensitivity"),
    TabPanel(child=column(specificity, b_specificity), title="Specificity"),
])

# Show the tabs
show(tabs)
# Out:
#   <div id="d0a0c39e-c3a6-4106-af57-2f76a9e87d82" data-root-id="p2146" style="display: contents;"></div>
