# %%
import numpy as np
import pandas as pd
from yfinance import Ticker
import time

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

import os

import torch
import torch.nn.functional as F
import torchvision.transforms.v2 as transforms
from torch import nn, optim
from torch.utils.data import TensorDataset, DataLoader

from PIL import Image

from torchinfo import summary

torch.manual_seed(123)
np.random.seed(123)

if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

torch.set_default_device(device)
print(f"Using {device}")
# Out:
# Using cpu

# %%
from bokeh.io import show, output_notebook
from bokeh.models  import TabPanel, Tabs, LegendItem, Legend
from bokeh.plotting import figure, Row
from bokeh.layouts import column

output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e0828dd1-ae92-445d-a0ca-e4a2ec01aee6">Loading BokehJS ...</span>
#     </div>

# %%
# Hyper Parameters

EPOCHS = 30
BATCH = 64
LEARNING_RATE = 0.001

SEQ_LEN = 32 # 31 previous + the next business day
FEATURES = 5 # Open / High / Low / Close / Volume
INPUT_SIZE = (SEQ_LEN - 1) * FEATURES 
TARGET_SIZE = 5 # next day features

PERIOD = "3y"
VALIDATION_DAYS = 30
STOCK = "GOOG"
#STOCK = "AMZN"
#STOCK = "NVDA"

# %% [markdown]
# # Data Exploration and Preparation

# %% [markdown]
# The data utilized for this project is pulled from yahoo finances, using the last 3 years of the selected stock.

# %%
stock = Ticker(STOCK)
df = stock.history(period="10y")
df.head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2015-06-22 00:00:00-04:00  26.820078  27.026353  26.717686  26.750492
# 2015-06-23 00:00:00-04:00  26.822563  26.914963  26.604361  26.864315
# 2015-06-24 00:00:00-04:00  26.840457  26.840457  26.624740  26.733095
# 2015-06-25 00:00:00-04:00  26.784291  26.885190  26.603365  26.603365
# 2015-06-26 00:00:00-04:00  26.704266  26.729118  26.410510  26.427410
#
#                              Volume  Dividends  Stock Splits
# Date
# 2015-06-22 00:00:00-04:00  25006000        0.0           0.0
# 2015-06-23 00:00:00-04:00  23950000        0.0           0.0
# 2015-06-24 00:00:00-04:00  25732000        0.0           0.0
# 2015-06-25 00:00:00-04:00  26714000        0.0           0.0
# 2015-06-26 00:00:00-04:00  42182000        0.0           0.0

# %% [markdown]
# As our analyse does not account for dividends and stock splits, we shall remove it from dataframe.
# While the volume of transactions is also not our focus, it is a useful indicator that we choose to keep.

# %%
df = df.drop(["Dividends", "Stock Splits"], axis=1)
mean = df.mean().values
std = df.std().values
df = (df - df.mean()) / df.std()
df.describe()
# Out:
#                Open          High           Low        Close        Volume
# count  2.515000e+03  2.515000e+03  2.515000e+03  2515.000000  2.515000e+03
# mean  -9.040703e-17 -9.040703e-17 -9.040703e-17     0.000000 -6.780527e-17
# std    1.000000e+00  1.000000e+00  1.000000e+00     1.000000  1.000000e+00
# min   -1.357725e+00 -1.359306e+00 -1.357642e+00    -1.361413 -1.532098e+00
# 25%   -8.205689e-01 -8.175017e-01 -8.195862e-01    -0.819675 -6.152777e-01
# 50%   -3.519056e-01 -3.534472e-01 -3.510446e-01    -0.350644 -2.450522e-01
# 75%    8.816560e-01  8.823185e-01  8.822084e-01     0.873148  3.001035e-01
# max    2.466630e+00  2.505985e+00  2.508129e+00     2.533982  1.269229e+01

# %% [markdown]
# Since this is a problem of linear regression, we will not choose randomly the training and validation sets,
# rather we will try to use the previous years as training and the last month as validation.

# %%
seqs = []
for i in range(len(df)-SEQ_LEN+1):
    seqs.append(df.values[i:i+SEQ_LEN])
seqs = np.array(seqs)

# %%
# Train-Test Split
train = seqs[:-VALIDATION_DAYS]
val =   seqs[-VALIDATION_DAYS:]

X_train = train[:,:-1]
y_train = train[:,-1]

X_val = val[:,:-1]
y_val = val[:,-1]

# %%
# Convert to torch tensors
training_loader = DataLoader(TensorDataset(torch.tensor(X_train, dtype=torch.float), torch.tensor(y_train, dtype=torch.float)), batch_size=BATCH, shuffle=False)
validation_loader = DataLoader(TensorDataset(torch.tensor(X_val, dtype=torch.float), torch.tensor(y_val, dtype=torch.float)), batch_size=BATCH, shuffle=False)

# %% [markdown]
# # Models Implementation

# %% [markdown]
# ### Multiple Layer Perceptron

# %%
class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(INPUT_SIZE, 20)
        self.fc2 = nn.Linear(20, TARGET_SIZE)

    def forward(self, x):
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.fc2(x)
        return x

# %%
summary(MLP())
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# MLP                                      --
# ├─Flatten: 1-1                           --
# ├─Linear: 1-2                            3,120
# ├─Linear: 1-3                            105
# =================================================================
# Total params: 3,225
# Trainable params: 3,225
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# ### Convolutional Neural Network

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv1d(5, 20, kernel_size=8, stride=1, padding=0)
        self.pool = nn.MaxPool1d(kernel_size=2, stride=1, padding=0)
        self.conv2 = nn.Conv1d(20, 40, kernel_size=4, stride=1, padding=0)
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(760, TARGET_SIZE)

    def forward(self, x):
        x = torch.permute(x, (0,2,1))
        x = self.pool(self.conv1(x))
        x = self.pool(self.conv2(x))
        x = self.flatten(x)
        x = self.fc1(x)
        return x

# %%
summary(CNN())
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# CNN                                      --
# ├─Conv1d: 1-1                            820
# ├─MaxPool1d: 1-2                         --
# ├─Conv1d: 1-3                            3,240
# ├─Flatten: 1-4                           --
# ├─Linear: 1-5                            3,805
# =================================================================
# Total params: 7,865
# Trainable params: 7,865
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# ### Long-Short Term Memory

# %%
class LSTM(nn.Module):
    def __init__(self):
        super(LSTM, self).__init__()        
        # Bidirectional LSTM layers
        self.lstm = nn.LSTM(input_size=FEATURES, 
                            hidden_size=64,
                            num_layers=2,
                            batch_first=True,
                            bidirectional=False)
        self.fc1 = nn.Linear(64, TARGET_SIZE)
        
    def forward(self, x):
        #print(x)
        #print(x.shape)
        x, (h_n, c_n) = self.lstm(x) 
        #print(h_n.shape)
        x = x[:,-1,:]
        #print(x.shape)
        x = self.fc1(x)
        #print(x.shape)
        return x

# %%
summary(LSTM())
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# LSTM                                     --
# ├─LSTM: 1-1                              51,456
# ├─Linear: 1-2                            325
# =================================================================
# Total params: 51,781
# Trainable params: 51,781
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# ### Swarm Characteristic Neural Network

# %%
class SwarmFilter(nn.Module):
    def __init__(self, units=32):
        super(SwarmFilter, self).__init__()
        self.units = units
        self.filter = nn.Parameter(torch.randn(units))  # Trainable parameter with random initialization

    def forward(self, x):
        # Compute the mean along the last axis, keeping the dimensions
        mean_values = torch.mean(x, dim=-1, keepdim=True)
        return mean_values * self.filter

# %%
class SCNN(nn.Module):
    def __init__(self):
        super(SCNN, self).__init__()
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(INPUT_SIZE, 4)
        self.swarm1 = SwarmFilter(units=256)
        self.swarm2 = SwarmFilter(units=16)
        self.fc2 = nn.Linear(16, TARGET_SIZE) 

    def forward(self, x):
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.swarm1(x)     
        x = self.swarm2(x)     
        x = self.fc2(x)
        return x

# %%
summary(SCNN())
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# SCNN                                     --
# ├─Flatten: 1-1                           --
# ├─Linear: 1-2                            624
# ├─SwarmFilter: 1-3                       256
# ├─SwarmFilter: 1-4                       16
# ├─Linear: 1-5                            85
# =================================================================
# Total params: 981
# Trainable params: 981
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# # Running the models

# %% [markdown]
# ### Implementation

# %% [markdown]
# ##### Visuals

# %%
def progressbar(i, total, start):
    x = int(100*i/total)
    print(f"\t[{ u'█' * x }{ '.' * (100-x) }] { i : 6.0f}/{ total } Waiting for {time.time()-start:5.3f} seconds", end='\r')
    if i == total:
        print()

# %%
def display_stats(loss):
    print(f"\tMean Square Error: {loss:.5}")
    print(f"\t{'='*100}")
    return

# %%
def plot_prediction(train_preds, val_preds):
    x = np.arange(len(y_train) + len(y_val))
    x_train = x[:-len(y_val)]
    x_val = x[-len(y_val):]
    
    high = figure(width=800, height=400, title="High of the Day")
    low = figure(width=800, height=400, title="Low of the Day")
    
    # Plot the predicted high and low
    high.line(x_train, train_preds[:,1], line_width=4, line_color="navy", legend_label="Training")
    low.line(x_train, train_preds[:,2], line_width=4, line_color="navy")
    
    high.line(x_val, val_preds[:,1], line_width=4, line_color="orange", legend_label="Validation")
    low.line(x_val, val_preds[:,2], line_width=4, line_color="orange")

    # Plot the true high and low of each day as borders
    high.line(x_train, y_train[:,1], line_width=2, line_color="black", legend_label="True Values")
    low.line(x_train, y_train[:,2], line_width=2, line_color="black")
    
    high.line(x_val, y_val[:,1], line_width=2, line_color="black")
    low.line(x_val, y_val[:,2], line_width=2, line_color="black")
    
    show(column(high, low))
    return

# %% [markdown]
# ##### Training and Validation

# %%
def train_epoch(model, optimizer, criterion):
    total_loss = 0.
    predictions = []
    size = len(training_loader)
    start = time.time()
    for i, data in enumerate(training_loader):
        # Update progress bar
        progressbar(i,size,start)
        
        # Every data instance is an input + label pair
        inputs, labels = data
        
        # Zero your gradients for every batch!
        optimizer.zero_grad()
        
        # Make predictions for this batch
        outputs = model(inputs)

        # Compute the loss and its gradients
        loss = criterion(outputs, labels)
        loss.backward()
        
        # Adjust learning weights
        optimizer.step()
        
        # Gather data and report
        total_loss += loss.item()
        predictions += list(outputs.detach().numpy())

    # Finish progress bar
    progressbar(size,size,start)

    # return average loss during training
    return total_loss / size, np.array(predictions)

# %%
def validate_epoch(model, criterion):
    total_loss = 0.
    predictions = []
    size = len(validation_loader)
    start = time.time()
    for i, data in enumerate(validation_loader):
        # Update progress bar
        progressbar(i,size,start)
        
        # Every data instance is an input + label pair
        inputs, labels = data
        
        # Make predictions for this batch
        outputs = model(inputs)
        
        # Compute the loss and its gradients
        loss = criterion(outputs, labels)
                
        # Gather data and report
        total_loss += loss.item()
        predictions += list(outputs.detach().numpy())

    # Finish progress bar
    progressbar(size,size,start)

    # return average loss during training
    return total_loss / size, np.array(predictions)

# %% [markdown]
# ##### Data Collection

# %%
def run_model(model, label="", color="navy", epochs=EPOCHS):
    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
    criterion = nn.MSELoss()

    stats = {
        "Label": label,
        "Color": color,
        "Parameters": sum(p.numel() for p in model.parameters()),
        "Training": {
            "Loss": [],
            "Time": 0.0,
            "Time/Epoch": 0.0
        },
        "Validation": {
            "Loss": [],
            "Time": 0.0,
            "Time/Epoch": 0.0
        },
        "Prediction": {
            "Open": [],
            "High": [],
            "Low": [],
            "Close": [],
            "Volume": [],
        },
    }
    
    train_time = 0
    val_time = 0

    train_preds = []
    val_preds = []
    
    for epoch in range(epochs):
        
        # Set the model to training mode
        model.train()  
        
        # Train epoch
        print(f"Epoch {epoch + 1}/{epochs}")
        print(f"\tTraining")
        start = time.time()
        train_loss, train_preds = train_epoch(model, optimizer, criterion)
        train_time += time.time() - start
        # Print training stats for the epoch
        display_stats(train_loss)
        
        # Run validation
        model.eval()
        val_loss = 0.0
        val_cm = np.zeros((2,2))
    
        print(f"\tValidation")
        start = time.time()
        with torch.no_grad():  # Disable gradient calculation during validation
            # Run validation
            val_loss, val_preds = validate_epoch(model, criterion)
        val_time += time.time() - start
        # Print validation stats
        display_stats(val_loss)
        
        # display the last model
        if epoch == epochs - 1:
            plot_prediction(train_preds, val_preds)
        
        # save stats
        stats["Training"]["Loss"].append(train_loss)
        stats["Validation"]["Loss"].append(val_loss)
        
    stats["Training"]["Loss"] = np.array(stats["Training"]["Loss"])
    stats["Validation"]["Loss"] = np.array(stats["Validation"]["Loss"])
    
    stats["Training"]["Time"] = train_time
    stats["Training"]["Time/Epoch"] = train_time / epochs

    stats["Validation"]["Time"] = val_time
    stats["Validation"]["Time/Epoch"] = val_time / epochs

    stats["Prediction"]["Open"] = np.concatenate([train_preds[:,0], val_preds[:,0]])
    stats["Prediction"]["High"] = np.concatenate([train_preds[:,1], val_preds[:,1]])
    stats["Prediction"]["Low"] = np.concatenate([train_preds[:,2], val_preds[:,2]])
    stats["Prediction"]["Close"] = np.concatenate([train_preds[:,3], val_preds[:,3]])
    stats["Prediction"]["Volume"] = np.concatenate([train_preds[:,4], val_preds[:,4]])
    
    return stats

# %% [markdown]
# ### Running

# %%
mlp_stats = run_model(MLP(), label="MLP", color="green")
# Out:
# Epoch 1/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.038 seconds
# 	Mean Square Error: 0.33205
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.17812
# 	====================================================================================================
# Epoch 2/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.033 seconds
# 	Mean Square Error: 0.18625
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.12942
# 	====================================================================================================
# Epoch 3/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.028 seconds
# 	Mean Square Error: 0.16387
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.11858
# 	====================================================================================================
# Epoch 4/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.039 seconds
# 	Mean Square Error: 0.15353
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.11593
# 	====================================================================================================
# Epoch 5/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.037 seconds
# 	Mean Square Error: 0.14708
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.11608
# 	====================================================================================================
# Epoch 6/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.035 seconds
# 	Mean Square Error: 0.14278
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.11691
# 	====================================================================================================
# Epoch 7/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.037 seconds
# 	Mean Square Error: 0.13989
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.11727
# 	====================================================================================================
# Epoch 8/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.034 seconds
# 	Mean Square Error: 0.13799
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.11702
# 	====================================================================================================
# Epoch 9/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.033 seconds
# 	Mean Square Error: 0.13688
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.11655
# 	====================================================================================================
# Epoch 10/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.033 seconds
# 	Mean Square Error: 0.13641
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.11648
# 	====================================================================================================
# Epoch 11/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.033 seconds
# 	Mean Square Error: 0.13633
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.11742
# 	====================================================================================================
# Epoch 12/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.034 seconds
# 	Mean Square Error: 0.13619
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.11908
# 	====================================================================================================
# Epoch 13/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.034 seconds
# 	Mean Square Error: 0.13532
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.11949
# 	====================================================================================================
# Epoch 14/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.033 seconds
# 	Mean Square Error: 0.13301
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.11631
# 	====================================================================================================
# Epoch 15/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.033 seconds
# 	Mean Square Error: 0.12921
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.11014
# 	====================================================================================================
# Epoch 16/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.034 seconds
# 	Mean Square Error: 0.12494
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.10359
# 	====================================================================================================
# Epoch 17/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.034 seconds
# 	Mean Square Error: 0.12157
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.098246
# 	====================================================================================================
# Epoch 18/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.032 seconds
# 	Mean Square Error: 0.11964
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.094361
# 	====================================================================================================
# Epoch 19/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.037 seconds
# 	Mean Square Error: 0.11878
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.091571
# 	====================================================================================================
# Epoch 20/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.032 seconds
# 	Mean Square Error: 0.11844
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.089523
# 	====================================================================================================
# Epoch 21/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.035 seconds
# 	Mean Square Error: 0.11831
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.088047
# 	====================================================================================================
# Epoch 22/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.031 seconds
# 	Mean Square Error: 0.11823
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.086999
# 	====================================================================================================
# Epoch 23/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.032 seconds
# 	Mean Square Error: 0.11816
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.086154
# 	====================================================================================================
# Epoch 24/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.032 seconds
# 	Mean Square Error: 0.11809
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.085245
# 	====================================================================================================
# Epoch 25/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.033 seconds
# 	Mean Square Error: 0.11809
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.08411
# 	====================================================================================================
# Epoch 26/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.031 seconds
# 	Mean Square Error: 0.11826
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.082783
# 	====================================================================================================
# Epoch 27/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.032 seconds
# 	Mean Square Error: 0.11874
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.081508
# 	====================================================================================================
# Epoch 28/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.032 seconds
# 	Mean Square Error: 0.1196
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.080841
# 	====================================================================================================
# Epoch 29/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.032 seconds
# 	Mean Square Error: 0.12089
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.081889
# 	====================================================================================================
# Epoch 30/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.032 seconds
# 	Mean Square Error: 0.12249
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.086274
# 	====================================================================================================
#   <div id="c3de8ed8-ec74-449d-bcbd-47f9c1c2e75c" data-root-id="p1149" style="display: contents;"></div>

# %%
cnn_stats = run_model(CNN(), label="CNN", color="navy")
# Out:
# Epoch 1/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.071 seconds
# 	Mean Square Error: 0.31251
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.36109
# 	====================================================================================================
# Epoch 2/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.063 seconds
# 	Mean Square Error: 0.18861
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.14634
# 	====================================================================================================
# Epoch 3/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.064 seconds
# 	Mean Square Error: 0.1704
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.10696
# 	====================================================================================================
# Epoch 4/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.061 seconds
# 	Mean Square Error: 0.16743
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.096285
# 	====================================================================================================
# Epoch 5/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.065 seconds
# 	Mean Square Error: 0.17167
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.11554
# 	====================================================================================================
# Epoch 6/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.059 seconds
# 	Mean Square Error: 0.16889
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.11931
# 	====================================================================================================
# Epoch 7/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.068 seconds
# 	Mean Square Error: 0.16103
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.11556
# 	====================================================================================================
# Epoch 8/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.065 seconds
# 	Mean Square Error: 0.15658
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.12243
# 	====================================================================================================
# Epoch 9/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.065 seconds
# 	Mean Square Error: 0.15297
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.13017
# 	====================================================================================================
# Epoch 10/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.069 seconds
# 	Mean Square Error: 0.14657
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.12339
# 	====================================================================================================
# Epoch 11/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.062 seconds
# 	Mean Square Error: 0.14343
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.12334
# 	====================================================================================================
# Epoch 12/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.062 seconds
# 	Mean Square Error: 0.1421
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.12379
# 	====================================================================================================
# Epoch 13/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.063 seconds
# 	Mean Square Error: 0.14086
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.126
# 	====================================================================================================
# Epoch 14/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.063 seconds
# 	Mean Square Error: 0.13733
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.123
# 	====================================================================================================
# Epoch 15/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.062 seconds
# 	Mean Square Error: 0.13578
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.12589
# 	====================================================================================================
# Epoch 16/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.063 seconds
# 	Mean Square Error: 0.13321
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.12459
# 	====================================================================================================
# Epoch 17/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.066 seconds
# 	Mean Square Error: 0.13258
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.12613
# 	====================================================================================================
# Epoch 18/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.063 seconds
# 	Mean Square Error: 0.13051
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.12474
# 	====================================================================================================
# Epoch 19/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.063 seconds
# 	Mean Square Error: 0.12995
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.12485
# 	====================================================================================================
# Epoch 20/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.064 seconds
# 	Mean Square Error: 0.12757
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.002 seconds
# 	Mean Square Error: 0.12333
# 	====================================================================================================
# Epoch 21/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.075 seconds
# 	Mean Square Error: 0.12656
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.1224
# 	====================================================================================================
# Epoch 22/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.082 seconds
# 	Mean Square Error: 0.12401
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.11966
# 	====================================================================================================
# Epoch 23/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.067 seconds
# 	Mean Square Error: 0.12242
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.11983
# 	====================================================================================================
# Epoch 24/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.065 seconds
# 	Mean Square Error: 0.12054
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.11569
# 	====================================================================================================
# Epoch 25/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.079 seconds
# 	Mean Square Error: 0.11867
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.12062
# 	====================================================================================================
# Epoch 26/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.066 seconds
# 	Mean Square Error: 0.11802
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.11266
# 	====================================================================================================
# Epoch 27/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.063 seconds
# 	Mean Square Error: 0.11624
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.12685
# 	====================================================================================================
# Epoch 28/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.063 seconds
# 	Mean Square Error: 0.11613
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.11048
# 	====================================================================================================
# Epoch 29/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.081 seconds
# 	Mean Square Error: 0.11424
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.12762
# 	====================================================================================================
# Epoch 30/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.078 seconds
# 	Mean Square Error: 0.11401
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.11021
# 	====================================================================================================
#   <div id="ff063fc7-d11b-40d8-86cd-e112e5f5a626" data-root-id="p1312" style="display: contents;"></div>

# %%
lstm_stats = run_model(LSTM(), label="LSTM", color="orange")
# Out:
# Epoch 1/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.480 seconds
# 	Mean Square Error: 0.80784
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.002 seconds
# 	Mean Square Error: 1.3855
# 	====================================================================================================
# Epoch 2/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.507 seconds
# 	Mean Square Error: 0.3416
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.56094
# 	====================================================================================================
# Epoch 3/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.479 seconds
# 	Mean Square Error: 0.32339
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.39931
# 	====================================================================================================
# Epoch 4/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.482 seconds
# 	Mean Square Error: 0.23388
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.23943
# 	====================================================================================================
# Epoch 5/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.476 seconds
# 	Mean Square Error: 0.23996
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.21585
# 	====================================================================================================
# Epoch 6/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.494 seconds
# 	Mean Square Error: 0.203
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.17619
# 	====================================================================================================
# Epoch 7/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.500 seconds
# 	Mean Square Error: 0.18578
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.15221
# 	====================================================================================================
# Epoch 8/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.480 seconds
# 	Mean Square Error: 0.16933
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.010 seconds
# 	Mean Square Error: 0.14026
# 	====================================================================================================
# Epoch 9/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.487 seconds
# 	Mean Square Error: 0.15258
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.13287
# 	====================================================================================================
# Epoch 10/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.489 seconds
# 	Mean Square Error: 0.13598
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.004 seconds
# 	Mean Square Error: 0.12975
# 	====================================================================================================
# Epoch 11/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.488 seconds
# 	Mean Square Error: 0.12492
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.009 seconds
# 	Mean Square Error: 0.12556
# 	====================================================================================================
# Epoch 12/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.514 seconds
# 	Mean Square Error: 0.1236
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.11786
# 	====================================================================================================
# Epoch 13/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.723 seconds
# 	Mean Square Error: 0.11993
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.018 seconds
# 	Mean Square Error: 0.114
# 	====================================================================================================
# Epoch 14/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.724 seconds
# 	Mean Square Error: 0.11966
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.11557
# 	====================================================================================================
# Epoch 15/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.702 seconds
# 	Mean Square Error: 0.11975
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.11147
# 	====================================================================================================
# Epoch 16/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.732 seconds
# 	Mean Square Error: 0.11519
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.11002
# 	====================================================================================================
# Epoch 17/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.733 seconds
# 	Mean Square Error: 0.11303
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.002 seconds
# 	Mean Square Error: 0.10748
# 	====================================================================================================
# Epoch 18/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.703 seconds
# 	Mean Square Error: 0.11153
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.002 seconds
# 	Mean Square Error: 0.1046
# 	====================================================================================================
# Epoch 19/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.743 seconds
# 	Mean Square Error: 0.11076
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.002 seconds
# 	Mean Square Error: 0.103
# 	====================================================================================================
# Epoch 20/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.726 seconds
# 	Mean Square Error: 0.11008
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.002 seconds
# 	Mean Square Error: 0.10159
# 	====================================================================================================
# Epoch 21/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.697 seconds
# 	Mean Square Error: 0.11084
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.004 seconds
# 	Mean Square Error: 0.10127
# 	====================================================================================================
# Epoch 22/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.714 seconds
# 	Mean Square Error: 0.11122
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.10214
# 	====================================================================================================
# Epoch 23/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.730 seconds
# 	Mean Square Error: 0.11099
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.10207
# 	====================================================================================================
# Epoch 24/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.708 seconds
# 	Mean Square Error: 0.11193
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.10099
# 	====================================================================================================
# Epoch 25/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.726 seconds
# 	Mean Square Error: 0.11488
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.002 seconds
# 	Mean Square Error: 0.10134
# 	====================================================================================================
# Epoch 26/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.735 seconds
# 	Mean Square Error: 0.12523
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.002 seconds
# 	Mean Square Error: 0.10796
# 	====================================================================================================
# Epoch 27/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.697 seconds
# 	Mean Square Error: 0.19859
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.26908
# 	====================================================================================================
# Epoch 28/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.734 seconds
# 	Mean Square Error: 0.22223
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.002 seconds
# 	Mean Square Error: 0.18679
# 	====================================================================================================
# Epoch 29/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.615 seconds
# 	Mean Square Error: 0.14577
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.1151
# 	====================================================================================================
# Epoch 30/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.591 seconds
# 	Mean Square Error: 0.14257
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.1087
# 	====================================================================================================
#   <div id="e2f45b15-a6e6-4f1e-a1bc-cfe0592304d1" data-root-id="p1475" style="display: contents;"></div>

# %%
scnn_stats = run_model(SCNN(), label="SCNN", color="red")
# Out:
# Epoch 1/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.059 seconds
# 	Mean Square Error: 0.58676
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.53447
# 	====================================================================================================
# Epoch 2/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.056 seconds
# 	Mean Square Error: 0.24757
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.15473
# 	====================================================================================================
# Epoch 3/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.053 seconds
# 	Mean Square Error: 0.19556
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.1169
# 	====================================================================================================
# Epoch 4/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.060 seconds
# 	Mean Square Error: 0.19106
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.12394
# 	====================================================================================================
# Epoch 5/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.059 seconds
# 	Mean Square Error: 0.18507
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.12544
# 	====================================================================================================
# Epoch 6/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.057 seconds
# 	Mean Square Error: 0.17947
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.1259
# 	====================================================================================================
# Epoch 7/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.056 seconds
# 	Mean Square Error: 0.1754
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.12678
# 	====================================================================================================
# Epoch 8/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.058 seconds
# 	Mean Square Error: 0.17242
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.12785
# 	====================================================================================================
# Epoch 9/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.063 seconds
# 	Mean Square Error: 0.17026
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.12898
# 	====================================================================================================
# Epoch 10/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.057 seconds
# 	Mean Square Error: 0.16868
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.13005
# 	====================================================================================================
# Epoch 11/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.059 seconds
# 	Mean Square Error: 0.1675
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.13103
# 	====================================================================================================
# Epoch 12/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.052 seconds
# 	Mean Square Error: 0.16661
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.13186
# 	====================================================================================================
# Epoch 13/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.057 seconds
# 	Mean Square Error: 0.1659
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.002 seconds
# 	Mean Square Error: 0.13255
# 	====================================================================================================
# Epoch 14/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.058 seconds
# 	Mean Square Error: 0.16534
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.13311
# 	====================================================================================================
# Epoch 15/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.058 seconds
# 	Mean Square Error: 0.16487
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.002 seconds
# 	Mean Square Error: 0.13356
# 	====================================================================================================
# Epoch 16/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.077 seconds
# 	Mean Square Error: 0.16447
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.13392
# 	====================================================================================================
# Epoch 17/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.074 seconds
# 	Mean Square Error: 0.16413
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.002 seconds
# 	Mean Square Error: 0.1342
# 	====================================================================================================
# Epoch 18/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.070 seconds
# 	Mean Square Error: 0.16383
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.002 seconds
# 	Mean Square Error: 0.13442
# 	====================================================================================================
# Epoch 19/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.055 seconds
# 	Mean Square Error: 0.16355
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.002 seconds
# 	Mean Square Error: 0.13459
# 	====================================================================================================
# Epoch 20/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.071 seconds
# 	Mean Square Error: 0.16331
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.002 seconds
# 	Mean Square Error: 0.13471
# 	====================================================================================================
# Epoch 21/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.078 seconds
# 	Mean Square Error: 0.16308
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.13481
# 	====================================================================================================
# Epoch 22/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.059 seconds
# 	Mean Square Error: 0.16287
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.13488
# 	====================================================================================================
# Epoch 23/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.079 seconds
# 	Mean Square Error: 0.16267
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.13493
# 	====================================================================================================
# Epoch 24/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.083 seconds
# 	Mean Square Error: 0.16248
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.13496
# 	====================================================================================================
# Epoch 25/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.063 seconds
# 	Mean Square Error: 0.16231
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.13499
# 	====================================================================================================
# Epoch 26/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.075 seconds
# 	Mean Square Error: 0.16214
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.135
# 	====================================================================================================
# Epoch 27/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.079 seconds
# 	Mean Square Error: 0.16199
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.13501
# 	====================================================================================================
# Epoch 28/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.081 seconds
# 	Mean Square Error: 0.16184
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.13502
# 	====================================================================================================
# Epoch 29/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.057 seconds
# 	Mean Square Error: 0.1617
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.001 seconds
# 	Mean Square Error: 0.13502
# 	====================================================================================================
# Epoch 30/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     39/39 Waiting for 0.077 seconds
# 	Mean Square Error: 0.16157
# 	====================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]      1/1 Waiting for 0.000 seconds
# 	Mean Square Error: 0.13501
# 	====================================================================================================
#   <div id="e878b5d9-51b3-40f0-b923-783fce8222ed" data-root-id="p1638" style="display: contents;"></div>

# %% [markdown]
# # Comparative Analyse

# %%
models = [mlp_stats, cnn_stats, lstm_stats, scnn_stats]

# %% [markdown]
# ### Extracting Visualization

# %%
# Linear plots
# Loss
loss = figure(width=800, height=400, title="Loss")
delta_loss = figure(width=800, height=400, title="Overfitting")

for fig in [loss, delta_loss]:
    fig.add_layout(Legend(), 'right')
    loss.line([0], [0.5], line_width=3, legend_label="Training", line_dash="dashed",line_color="black")
    fig.xaxis.axis_label = 'epoch'

delta_loss.yaxis.axis_label = "Val - Train Loss"

# Prediction
price_open = figure(width=800, height=400, title="Opening Price")
price_open_delta = figure(width=800, height=400, title="Opening Price Delta")

price_high = figure(width=800, height=400, title="Highest Price")
price_high_delta = figure(width=800, height=400, title="Highest Price Delta")

price_low = figure(width=800, height=400, title="Lowest Price")
price_low_delta = figure(width=800, height=400, title="Lowest Price Delta")

price_close = figure(width=800, height=400, title="Close Price")
price_close_delta = figure(width=800, height=400, title="Closing Price Delta")

vol = figure(width=800, height=400, title="Volume")
vol_delta = figure(width=800, height=400, title="Volume Delta")


# Create auxiliar arrays
x_epoches = np.arange(EPOCHS)
y_values = (y_val * std) + mean
x_days = np.arange(len(y_values))


# Set guide
for i, fig in enumerate([price_open, price_high, price_low, price_close, vol]):
    fig.add_layout(Legend(), 'right')
    fig.line(x_days, y_values[:,i], line_width=5, legend_label="Real Value", line_color="black")
    fig.xaxis.axis_label = 'day'

# Set guide
for i, fig in enumerate([price_open_delta, price_high_delta, price_low_delta, price_close_delta, vol_delta]):
    fig.add_layout(Legend(), 'right')
    fig.line(x_days, [0]*len(x_days), line_width=5, legend_label="Real Value", line_color="black")
    fig.xaxis.axis_label = 'day'

# Plot the lines
for stats in models:
    label = stats["Label"]
    color = stats["Color"]
    line_w = 3

    # Plot loss data
    loss.line(x_epoches, stats["Validation"]["Loss"], line_width=line_w, legend_label=label,line_color=color)
    loss.line(x_epoches, stats["Training"]["Loss"], line_width=line_w, line_dash="dashed", line_color=color)

    delta = stats["Validation"]["Loss"] - stats["Training"]["Loss"]
    delta_loss.line(x_epoches, delta, line_width=line_w, legend_label=label, line_color=color)

    # Plot predictions
    pred = (stats["Prediction"]["Open"][-VALIDATION_DAYS:] * std[0]) + mean[0]
    price_open.line(x_days, pred, line_width=line_w, legend_label=label, line_color=color)
    delta = pred - y_values[:,0]
    price_open_delta.line(x_days, delta, line_width=line_w, legend_label=label, line_color=color)

    pred = (stats["Prediction"]["High"][-VALIDATION_DAYS:] * std[1]) + mean[1]
    price_high.line(x_days, pred, line_width=line_w, legend_label=label, line_color=color)
    delta = pred - y_values[:,1]
    price_high_delta.line(x_days, delta, line_width=line_w, legend_label=label, line_color=color)

    pred = (stats["Prediction"]["Low"][-VALIDATION_DAYS:] * std[2]) + mean[2]
    price_low.line(x_days, pred, line_width=line_w, legend_label=label, line_color=color)
    delta = pred - y_values[:,2]
    price_low_delta.line(x_days, delta, line_width=line_w, legend_label=label, line_color=color)

    pred = (stats["Prediction"]["Close"][-VALIDATION_DAYS:] * std[3]) + mean[3]
    price_close.line(x_days, pred, line_width=line_w, legend_label=label, line_color=color)
    delta = pred - y_values[:,3]
    price_close_delta.line(x_days, delta, line_width=line_w, legend_label=label, line_color=color)

    pred = (stats["Prediction"]["Volume"][-VALIDATION_DAYS:] * std[4]) + mean[4]
    vol.line(x_days, pred, line_width=3, legend_label=label, line_color=color)
    delta = pred - y_values[:,4]
    vol_delta.line(x_days, delta, line_width=3, legend_label=label, line_color=color)

# %%
# Prepare histograms
model_labels = []

total_time_values = [[],[]]
epoch_time_values = [[],[]]

parameters = []

for stats in models:
    label = stats["Label"]
    model_labels.append(label)

    total_time_values[0].append(stats["Training"]["Time"])
    epoch_time_values[0].append(stats["Training"]["Time/Epoch"])
    total_time_values[1].append(stats["Validation"]["Time"])
    epoch_time_values[1].append(stats["Validation"]["Time/Epoch"])

    parameters.append(stats["Parameters"])

# %%
# Time related
total_time = figure(x_range=model_labels, width=800, height=400, title="Total Running Time")
epoch_time = figure(x_range=model_labels, width=800, height=400, title="Time per Epoch")

total_time.vbar(x=model_labels, top=total_time_values[0], color="navy", width=0.75,legend_label="Training")
total_time.vbar(x=model_labels, top=total_time_values[1], color="orange", width=0.5,legend_label="Validation")

epoch_time.vbar(x=model_labels, top=epoch_time_values[0], color="navy", width=0.75,legend_label="Training")
epoch_time.vbar(x=model_labels, top=epoch_time_values[1], color="orange", width=0.5,legend_label="Validation")

for fig in [total_time, epoch_time]:
    fig.legend.location = 'top_left'
    fig.yaxis.axis_label = 'seconds'
    fig.y_range.start = 0

# %%
# Parameter
param = figure(x_range=model_labels, width=800, height=400, title="Parameters")
param_exp = figure(x_range=model_labels, width=800, height=400, title="Parameters", y_axis_type="log",  y_range = [10 ** 2, 10 ** 5])

param.vbar(x=model_labels, top=parameters, color="navy", width=0.75)
param_exp.vbar(x=model_labels, bottom=[10 ** 0]*len(model_labels), top=parameters, color="navy", width=0.75)

param.y_range.start = 0

# %% [markdown]
# ### Visualizing

# %%
# Increase font size and make them all bold
for fig in [
    param, param_exp,
    loss, delta_loss,
    total_time, epoch_time,
    price_open, price_open_delta,
    price_high, price_high_delta,
    price_low, price_low_delta,
    price_close, price_close_delta,
    vol, vol_delta,
]:
    fig.title.text_font_size = "15pt"
    fig.title.padding = 5
    
    fig.yaxis.major_label_text_font_size = "12pt"
    fig.yaxis.major_label_text_font_style = "bold"
    fig.yaxis.axis_label_text_font_size = "12pt"
    fig.yaxis.axis_label_text_font_style = "bold"
    
    fig.xaxis.major_label_text_font_size = "12pt"
    fig.xaxis.major_label_text_font_style = "bold"
    fig.xaxis.axis_label_text_font_size = "12pt"
    fig.xaxis.axis_label_text_font_style = "bold"

# %%
# Create tabs using TabPanel
tabs = Tabs(tabs=[
    TabPanel(child=column(param, param_exp), title="Size"),
    TabPanel(child=column(loss, delta_loss), title="Loss"),
    TabPanel(child=column(total_time, epoch_time), title="Time"),
    TabPanel(child=column(price_open, price_open_delta), title="Open"),
    TabPanel(child=column(price_high, price_high_delta), title="High"),
    TabPanel(child=column(price_low, price_low_delta), title="Low"),
    TabPanel(child=column(price_close, price_close_delta), title="Close"),
    TabPanel(child=column(vol, vol_delta), title="Volume"),
])

# Show the tabs
show(tabs)
# Out:
#   <div id="b6af9475-9818-44dc-bc30-7fe7037e3a57" data-root-id="p2943" style="display: contents;"></div>
