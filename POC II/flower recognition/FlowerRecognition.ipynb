# %%
import numpy as np
import pandas as pd
import time

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

import os

import torch
import torch.nn.functional as F
import torchvision.transforms.v2 as transforms
from torch import nn, optim
from torch.utils.data import TensorDataset, DataLoader

from PIL import Image

from torchinfo import summary

torch.manual_seed(123)
np.random.seed(123)

if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

torch.set_default_device(device)
print(f"Using {device}")
# Out:
# Using cpu

# %%
from bokeh.io import show, output_notebook
from bokeh.models  import TabPanel, Tabs, LegendItem, Legend, ColumnDataSource
from bokeh.plotting import figure, Row
from bokeh.layouts import column
from bokeh.transform import dodge

output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="de4b2ed1-2c60-481d-be3a-b2133f92d640">Loading BokehJS ...</span>
#     </div>

# %%
# Hyper Parameters

EPOCHS = 30
BATCH = 32
TEST_SPLIT = 0.2

HEIGHT = 256
WIDTH  = 256
CLASSES = ["daisy", "dandelion", "rose", "sunflower", "tulip"]

TARGET_SIZE = 5            # daisy / dandelion / rose / sunflower / tulip

DATAPATH = "flowers"

# %% [markdown]
# # Data Exploration and Preparation

# %% [markdown]
# The data utilized for this project is available [here](https://www.kaggle.com/datasets/imsparsh/flowers-dataset).

# %% [markdown]
# Expected data directory structure:
#
# ./flowers/ \
#   ├── daisy/\
#   ├── dandelion/\
#   ├── rose/\
#   ├── sunflower/\
#   └── tulip/

# %% [markdown]
# Regarding sample size and class distribution, there are five flower categories: Daisy account for 764 samples (18%),
# Dandelion for 1052 (24%), Rose for 784 (18%), Sunflower for 733 (17%), and Tulip for 984 (23%), totaling 4317 samples.
# While not perfectly balanced, it is not unbalanced enough to justify over or undersampling to adjust for the bias.

# %%
# Data augmentation and normalization for training and validation
data_transforms = transforms.Compose([
    transforms.Resize(size=(HEIGHT,WIDTH)),
    transforms.RandomHorizontalFlip(),
    transforms.ToImage(),
    transforms.ToDtype(torch.float32, scale=True),
    transforms.Normalize([0.5, 0.5, 0.5], [0.25, 0.25, 0.25])
])

# %%
# Function to split dataset into train and validation sets
def split_dataset(data_dir, val_split=0.2):
    all_data = []
    for class_name in os.listdir(data_dir):
        class_dir = os.path.join(data_dir, class_name)
        if os.path.isdir(class_dir) and not class_name.startswith('.'):
            all_data += [(os.path.join(class_dir, img), class_name) for img in os.listdir(class_dir) if not img.startswith('.')]

    train_data, val_data = train_test_split(all_data, test_size=val_split, stratify=[item[1] for item in all_data])
    return train_data, val_data

# %%
# Custom Dataset class
class CustomDataset(TensorDataset):
    def __init__(self, data, class_to_idx, transform=None):
        self.data = data
        self.class_to_idx = class_to_idx
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        img_path, class_name = self.data[idx]
        image = Image.open(img_path).convert("RGB")
        label = self.class_to_idx[class_name]
        if self.transform:
            image = self.transform(image)
        return image, label

# %%
# Directory containing all images
data_dir = 'flowers'  # Replace with your dataset path

# %%
# Split dataset
train_data, val_data = split_dataset(data_dir, val_split=0.2)

# Get class names and indices
class_names = sorted({item[1] for item in train_data + val_data})
class_to_idx = {class_name: idx for idx, class_name in enumerate(class_names)}

# Create train and validation datasets
train_dataset = CustomDataset(train_data, class_to_idx, transform=data_transforms)
val_dataset = CustomDataset(val_data, class_to_idx, transform=data_transforms)

# Convert to torch tensors
training_loader = DataLoader(train_dataset, batch_size=BATCH, shuffle=True)
validation_loader = DataLoader(val_dataset, batch_size=BATCH, shuffle=False)

# %% [markdown]
# # Models Implementation

# %% [markdown]
# ### Multiple Layer Perceptron

# %%
class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(3 * HEIGHT * WIDTH, 64)
        self.fc2 = nn.Linear(64, TARGET_SIZE)

    def forward(self, x):
        x = self.flatten(x)
        x = F.relu(self.fc1(x))
        return self.fc2(x)

# %%
summary(MLP())
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# MLP                                      --
# ├─Flatten: 1-1                           --
# ├─Linear: 1-2                            12,582,976
# ├─Linear: 1-3                            325
# =================================================================
# Total params: 12,583,301
# Trainable params: 12,583,301
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# ### Convolutional Neural Network

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 4, kernel_size=8, stride=1, padding=0)
        self.relu = nn.ReLU()
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.conv2 = nn.Conv2d(4, 16, kernel_size=4, stride=1, padding=0)
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(57600, 128)
        self.fc2 = nn.Linear(128, TARGET_SIZE)

    def forward(self, x):
        x = self.pool(self.relu(self.conv1(x)))
        x = self.pool(self.relu(self.conv2(x)))
        x = self.flatten(x)
        x = F.relu(self.fc1(x))
        return self.fc2(x)

# %%
summary(CNN())
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# CNN                                      --
# ├─Conv2d: 1-1                            772
# ├─ReLU: 1-2                              --
# ├─MaxPool2d: 1-3                         --
# ├─Conv2d: 1-4                            1,040
# ├─Flatten: 1-5                           --
# ├─Linear: 1-6                            7,372,928
# ├─Linear: 1-7                            645
# =================================================================
# Total params: 7,375,385
# Trainable params: 7,375,385
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# ### Long-Short Term Memory

# %%
class LSTM(nn.Module):
    def __init__(self):
        super(LSTM, self).__init__()        
        # Bidirectional LSTM layers
        self.lstm = nn.LSTM(input_size=3 * HEIGHT, 
                            hidden_size=512,
                            num_layers=4,
                            batch_first=True,
                            bidirectional=True)
        
        self.fc1 = nn.Linear(2*512, TARGET_SIZE)

    def forward(self, x):
        x = x.permute(0, 2, 1, 3)  # (batch, 256, 3, 256)
        x = x.reshape(-1, 256, 3*256)  # (batch, 256, 3*256)
        x, (h_n, c_n) = self.lstm(x) 
        x = x[:,-1,:]
        return self.fc1(x)

# %%
summary(LSTM())
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# LSTM                                     --
# ├─LSTM: 1-1                              24,150,016
# ├─Linear: 1-2                            5,125
# =================================================================
# Total params: 24,155,141
# Trainable params: 24,155,141
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# ### Swarm Characteristic Neural Network

# %%
class SwarmFilter(nn.Module):
    def __init__(self, units=32):
        super(SwarmFilter, self).__init__()
        self.units = units
        self.filter = nn.Parameter(torch.randn(units))  # Trainable parameter with random initialization

    def forward(self, x):
        # Compute the mean along the last axis, keeping the dimensions
        mean_values = torch.mean(x, dim=-1, keepdim=True)
        return mean_values * self.filter

# %%
class SCNN(nn.Module):
    def __init__(self):
        super(SCNN, self).__init__()
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(3 * HEIGHT * WIDTH, 16)
        self.swarm1 = SwarmFilter(units=256)
        self.swarm2 = SwarmFilter(units=16)
        self.fc2 = nn.Linear(16, TARGET_SIZE) 

    def forward(self, x):
        x = self.flatten(x)
        x = F.relu(self.fc1(x))  
        x = self.swarm1(x)     
        x = self.swarm2(x)     
        return self.fc2(x)

# %%
summary(SCNN())
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# SCNN                                     --
# ├─Flatten: 1-1                           --
# ├─Linear: 1-2                            3,145,744
# ├─SwarmFilter: 1-3                       256
# ├─SwarmFilter: 1-4                       16
# ├─Linear: 1-5                            85
# =================================================================
# Total params: 3,146,101
# Trainable params: 3,146,101
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# # Running the models

# %% [markdown]
# ### Implementation

# %% [markdown]
# ##### Visuals

# %%
def progressbar(i, total, start):
    x = int(100*i/total)
    print(f"\t[{ u'█' * x }{ '.' * (100-x) }] { i : 6.0f}/{ total } Waiting for {time.time()-start:5.3f} seconds", end='\r')
    if i == total:
        print()

# %%
def gather_stats(loss, cm, display=True):
    
    accuracy = sum([cm[i,i] for i in range(len(cm))]) / cm.sum()
    precision = []
    recall = []

    if display:
        print(f"\t{'='*102}")
        print(f"\tClassification Statistics{' '*20}Accuracy: {accuracy:.5}{' '*24}Loss: {loss:.5}")
        print(f"\t{'='*102}")
        print(f"\tClass{' '*40}Precision{' '*32}Recall")
        print(f"\t{'-'*102}")
    
    for i in range(TARGET_SIZE):
        # Extract individual confusion matrix values
        TP = cm[i, i]
        FP = cm[:, i].sum() - TP
        FN = cm[i, :].sum() - TP

        # Calculate individual metrics
        pre = TP / (TP + FP) if (TP + FP) > 0 else 0
        rec = TP / (TP + FN) if (TP + FN) > 0 else 0

        # Save the result
        precision.append(pre)
        recall.append(rec)

        if display:
            print(f"\t{CLASSES[i]:20}{' '*25}{pre:0.4f}{' '*35}{rec:0.4f}")
        
    # Calculate general metrics
    pre = sum(precision)/TARGET_SIZE
    rec = sum(recall)/TARGET_SIZE
    precision.append(pre)
    recall.append(rec)
    if display:
        print(f"\t->Macro Avg.{' '*33}{pre:0.4f}{' '*35}{rec:0.4f}")

    pre = accuracy
    rec = accuracy
    precision.append(pre)
    recall.append(rec)
    if display:
        print(f"\t->Micro Avg.{' '*33}{pre:0.4f}{' '*35}{rec:0.4f}")
        print(f"\t{'='*102}") 
    
    return accuracy, precision, recall

# %% [markdown]
# ##### Training and Validation

# %%
def train_epoch(model, optimizer, criterion):
    total_loss = 0.
    confusion = np.zeros((TARGET_SIZE,TARGET_SIZE))
    size = len(training_loader)
    start = time.time()
    for i, data in enumerate(training_loader):
        # Update progress bar
        progressbar(i,size,start)
        
        # Every data instance is an input + label pair
        inputs, labels = data
        
        # Zero your gradients for every batch!
        optimizer.zero_grad()
        
        # Make predictions for this batch
        outputs = model(inputs)

        # Compute the loss and its gradients
        loss = criterion(outputs, labels)
        loss.backward()
        
        # Adjust learning weights
        optimizer.step()
        
        # Gather data and report
        preds = outputs.data.max(1)[1]
        total_loss += loss.item()
        confusion += confusion_matrix(labels.detach().numpy(), preds.detach().numpy(), labels=[0,1,2,3,4])
        
    # Finish progress bar
    progressbar(size,size,start)

    # return average loss during training
    return total_loss / size, confusion

# %%
def validate_epoch(model, criterion):
    total_loss = 0.
    confusion = np.zeros((TARGET_SIZE,TARGET_SIZE))
    size = len(validation_loader)
    start = time.time()
    for i, data in enumerate(validation_loader):
        # Update progress bar
        progressbar(i,size,start)
        
        # Every data instance is an input + label pair
        inputs, labels = data
        
        # Make predictions for this batch
        outputs = model(inputs)
        
        # Compute the loss and its gradients
        loss = criterion(outputs, labels)
                
        # Gather data and report
        preds = outputs.data.max(1)[1]
        total_loss += loss.item()
        confusion += confusion_matrix(labels.detach().numpy(), preds.detach().numpy(), labels=[0,1,2,3,4])

    # Finish progress bar
    progressbar(size,size,start)

    # return average loss during training
    return total_loss / size, confusion

# %% [markdown]
# ##### Data Collection

# %%
def run_model(model, label="", color="navy", epochs=EPOCHS):
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss()

    stats = {
        "Label": label,
        "Color": color,
        "Training": {
            "Loss": [],
            "Accuracy": [],
            "Precision": [],
            "Recall": [],
            "Time": 0.0,
            "Time/Epoch": 0.0
        },
        "Validation": {
            "Loss": [],
            "Accuracy": [],
            "Precision": [],
            "Recall": [],
            "Time": 0.0,
            "Time/Epoch": 0.0
        },
        "Parameters": sum(p.numel() for p in model.parameters()),
    }
    
    train_time = 0
    val_time = 0
    
    for epoch in range(epochs):
        
        # Set the model to training mode
        model.train()  
        
        # Train epoch
        print(f"Epoch {epoch + 1}/{epochs}")
        print(f"\tTraining")
        start = time.time()
        train_loss, train_cm = train_epoch(model, optimizer, criterion)
        train_time += time.time() - start
        # Print training stats for the epoch
        train_acc, train_pre, train_rec = gather_stats(train_loss, train_cm)
        
        # Run validation
        model.eval()
        val_loss = 0.0
        val_cm = np.zeros((2,2))
    
        print(f"\tValidation")
        start = time.time()
        with torch.no_grad():  # Disable gradient calculation during validation
            # Run validation
            val_loss, val_cm = validate_epoch(model, criterion)
        val_time += time.time() - start
        # Print validation stats
        val_acc, val_pre, val_rec = gather_stats(val_loss, val_cm)

        # save stats
        stats["Training"]["Loss"].append(train_loss)
        stats["Validation"]["Loss"].append(val_loss)

        # save only the final per class stats
        stats["Training"]["Accuracy"].append(train_acc)
        stats["Training"]["Precision"].append(train_pre)
        stats["Training"]["Recall"].append(train_rec)

        stats["Validation"]["Accuracy"].append(val_acc)
        stats["Validation"]["Precision"].append(val_pre)
        stats["Validation"]["Recall"].append(val_rec)
    
    stats["Training"]["Loss"] = np.array(stats["Training"]["Loss"])
    stats["Validation"]["Loss"] = np.array(stats["Validation"]["Loss"])
    
    stats["Training"]["Time"] = train_time
    stats["Training"]["Time/Epoch"] = train_time / epochs

    stats["Validation"]["Time"] = val_time
    stats["Validation"]["Time/Epoch"] = val_time / epochs
    
    return stats

# %% [markdown]
# ### Running

# %%
mlp_stats = run_model(MLP(), label="MLP", color="green")
# Out:
# Epoch 1/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 11.814 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.29047                        Loss: 13.325
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.2751                                   0.1931
# 	dandelion                                    0.3160                                   0.2090
# 	rose                                         0.3270                                   0.2727
# 	sunflower                                    0.3819                                   0.2235
# 	tulip                                        0.2542                                   0.5172
# 	->Macro Avg.                                 0.3108                                   0.2831
# 	->Micro Avg.                                 0.2905                                   0.2905
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.093 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.27778                        Loss: 12.101
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3538                                   0.1503
# 	dandelion                                    0.4390                                   0.0857
# 	rose                                         0.4091                                   0.2293
# 	sunflower                                    0.1915                                   0.1224
# 	tulip                                        0.2517                                   0.7360
# 	->Macro Avg.                                 0.3290                                   0.2648
# 	->Micro Avg.                                 0.2778                                   0.2778
# 	======================================================================================================
# Epoch 2/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 9.580 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.29453                        Loss: 6.5994
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3189                                   0.0966
# 	dandelion                                    0.4274                                   0.1853
# 	rose                                         0.3768                                   0.2121
# 	sunflower                                    0.3723                                   0.0870
# 	tulip                                        0.2561                                   0.7853
# 	->Macro Avg.                                 0.3503                                   0.2732
# 	->Micro Avg.                                 0.2945                                   0.2945
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 1.651 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.28125                        Loss: 7.5382
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4138                                   0.0784
# 	dandelion                                    0.3077                                   0.0952
# 	rose                                         0.3415                                   0.2675
# 	sunflower                                    0.4231                                   0.0748
# 	tulip                                        0.2544                                   0.8020
# 	->Macro Avg.                                 0.3481                                   0.2636
# 	->Micro Avg.                                 0.2812                                   0.2812
# 	======================================================================================================
# Epoch 3/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 9.330 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.28236                        Loss: 5.5881
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4293                                   0.1293
# 	dandelion                                    0.3732                                   0.1223
# 	rose                                         0.3377                                   0.1627
# 	sunflower                                    0.3659                                   0.0768
# 	tulip                                        0.2516                                   0.8208
# 	->Macro Avg.                                 0.3515                                   0.2624
# 	->Micro Avg.                                 0.2824                                   0.2824
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 1.652 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.27778                        Loss: 8.3079
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.2093                                   0.0588
# 	dandelion                                    0.2973                                   0.1571
# 	rose                                         0.3704                                   0.3185
# 	sunflower                                    0.5556                                   0.0680
# 	tulip                                        0.2478                                   0.7005
# 	->Macro Avg.                                 0.3361                                   0.2606
# 	->Micro Avg.                                 0.2778                                   0.2778
# 	======================================================================================================
# Epoch 4/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 9.394 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.3342                        Loss: 3.723
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4292                                   0.1588
# 	dandelion                                    0.4899                                   0.2874
# 	rose                                         0.5392                                   0.2632
# 	sunflower                                    0.4694                                   0.0785
# 	tulip                                        0.2593                                   0.7675
# 	->Macro Avg.                                 0.4374                                   0.3111
# 	->Micro Avg.                                 0.3342                                   0.3342
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 1.630 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.30671                        Loss: 7.0339
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.2500                                   0.1307
# 	dandelion                                    0.3464                                   0.2524
# 	rose                                         0.4953                                   0.3376
# 	sunflower                                    0.4444                                   0.0816
# 	tulip                                        0.2555                                   0.6447
# 	->Macro Avg.                                 0.3583                                   0.2894
# 	->Micro Avg.                                 0.3067                                   0.3067
# 	======================================================================================================
# Epoch 5/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 9.314 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.33768                        Loss: 3.3675
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3910                                   0.1702
# 	dandelion                                    0.3947                                   0.3159
# 	rose                                         0.4923                                   0.2552
# 	sunflower                                    0.4310                                   0.0853
# 	tulip                                        0.2828                                   0.7446
# 	->Macro Avg.                                 0.3984                                   0.3142
# 	->Micro Avg.                                 0.3377                                   0.3377
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 1.701 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.32639                        Loss: 5.2491
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3051                                   0.1176
# 	dandelion                                    0.3801                                   0.4000
# 	rose                                         0.4375                                   0.1783
# 	sunflower                                    0.3571                                   0.0680
# 	tulip                                        0.2886                                   0.7208
# 	->Macro Avg.                                 0.3537                                   0.2970
# 	->Micro Avg.                                 0.3264                                   0.3264
# 	======================================================================================================
# Epoch 6/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 9.953 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.37938                        Loss: 2.6587
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4425                                   0.2079
# 	dandelion                                    0.4354                                   0.4086
# 	rose                                         0.5697                                   0.3062
# 	sunflower                                    0.5321                                   0.0990
# 	tulip                                        0.3052                                   0.7484
# 	->Macro Avg.                                 0.4570                                   0.3540
# 	->Micro Avg.                                 0.3794                                   0.3794
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 1.933 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.34838                        Loss: 5.4115
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.2632                                   0.1307
# 	dandelion                                    0.4095                                   0.4095
# 	rose                                         0.5227                                   0.2930
# 	sunflower                                    0.4138                                   0.0816
# 	tulip                                        0.2972                                   0.6954
# 	->Macro Avg.                                 0.3813                                   0.3221
# 	->Micro Avg.                                 0.3484                                   0.3484
# 	======================================================================================================
# Epoch 7/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 11.232 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.38488                        Loss: 2.6944
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4380                                   0.2946
# 	dandelion                                    0.4398                                   0.3907
# 	rose                                         0.5271                                   0.2951
# 	sunflower                                    0.5141                                   0.1246
# 	tulip                                        0.3120                                   0.7141
# 	->Macro Avg.                                 0.4462                                   0.3638
# 	->Micro Avg.                                 0.3849                                   0.3849
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.088 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.34606                        Loss: 5.4658
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3269                                   0.1111
# 	dandelion                                    0.3775                                   0.6238
# 	rose                                         0.5088                                   0.1847
# 	sunflower                                    0.3429                                   0.0816
# 	tulip                                        0.2949                                   0.5584
# 	->Macro Avg.                                 0.3702                                   0.3119
# 	->Micro Avg.                                 0.3461                                   0.3461
# 	======================================================================================================
# Epoch 8/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 11.229 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.41819                        Loss: 2.0753
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4729                                   0.2995
# 	dandelion                                    0.4478                                   0.3919
# 	rose                                         0.5717                                   0.4067
# 	sunflower                                    0.3809                                   0.4420
# 	tulip                                        0.3466                                   0.5299
# 	->Macro Avg.                                 0.4440                                   0.4140
# 	->Micro Avg.                                 0.4182                                   0.4182
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.090 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.3588                        Loss: 6.426
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3677                                   0.3725
# 	dandelion                                    0.2918                                   0.3571
# 	rose                                         0.4186                                   0.3439
# 	sunflower                                    0.3931                                   0.7007
# 	tulip                                        0.3443                                   0.1066
# 	->Macro Avg.                                 0.3631                                   0.3762
# 	->Micro Avg.                                 0.3588                                   0.3588
# 	======================================================================================================
# Epoch 9/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 11.170 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.44628                        Loss: 2.2328
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4597                                   0.2897
# 	dandelion                                    0.4713                                   0.5071
# 	rose                                         0.5419                                   0.2887
# 	sunflower                                    0.3715                                   0.8362
# 	tulip                                        0.5226                                   0.3380
# 	->Macro Avg.                                 0.4734                                   0.4519
# 	->Micro Avg.                                 0.4463                                   0.4463
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.076 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.40278                        Loss: 4.0301
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3226                                   0.0654
# 	dandelion                                    0.3909                                   0.6571
# 	rose                                         0.4803                                   0.3885
# 	sunflower                                    0.4098                                   0.7415
# 	tulip                                        0.3448                                   0.1523
# 	->Macro Avg.                                 0.3897                                   0.4010
# 	->Micro Avg.                                 0.4028                                   0.4028
# 	======================================================================================================
# Epoch 10/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 11.230 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.45641                        Loss: 2.001
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4529                                   0.3224
# 	dandelion                                    0.4413                                   0.4513
# 	rose                                         0.5788                                   0.4099
# 	sunflower                                    0.3934                                   0.8191
# 	tulip                                        0.5314                                   0.3329
# 	->Macro Avg.                                 0.4796                                   0.4671
# 	->Micro Avg.                                 0.4564                                   0.4564
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.195 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.41782                        Loss: 4.6886
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4800                                   0.3922
# 	dandelion                                    0.4524                                   0.2714
# 	rose                                         0.5339                                   0.4013
# 	sunflower                                    0.3429                                   0.8912
# 	tulip                                        0.4425                                   0.2538
# 	->Macro Avg.                                 0.4503                                   0.4420
# 	->Micro Avg.                                 0.4178                                   0.4178
# 	======================================================================================================
# Epoch 11/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 11.283 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.46597                        Loss: 1.9642
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4654                                   0.3191
# 	dandelion                                    0.4519                                   0.4240
# 	rose                                         0.5979                                   0.3700
# 	sunflower                                    0.3953                                   0.8567
# 	tulip                                        0.5512                                   0.4104
# 	->Macro Avg.                                 0.4923                                   0.4760
# 	->Micro Avg.                                 0.4660                                   0.4660
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.128 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.39699                        Loss: 4.3997
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3500                                   0.1373
# 	dandelion                                    0.3835                                   0.4857
# 	rose                                         0.6230                                   0.2420
# 	sunflower                                    0.3634                                   0.8503
# 	tulip                                        0.4286                                   0.2893
# 	->Macro Avg.                                 0.4297                                   0.4009
# 	->Micro Avg.                                 0.3970                                   0.3970
# 	======================================================================================================
# Epoch 12/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 11.352 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.49899                        Loss: 1.8369
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5063                                   0.3306
# 	dandelion                                    0.4780                                   0.4774
# 	rose                                         0.5964                                   0.4195
# 	sunflower                                    0.4430                                   0.8823
# 	tulip                                        0.5603                                   0.4307
# 	->Macro Avg.                                 0.5168                                   0.5081
# 	->Micro Avg.                                 0.4990                                   0.4990
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.182 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.43171                        Loss: 4.2406
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3860                                   0.2876
# 	dandelion                                    0.4300                                   0.4238
# 	rose                                         0.4530                                   0.3376
# 	sunflower                                    0.4427                                   0.7891
# 	tulip                                        0.4329                                   0.3604
# 	->Macro Avg.                                 0.4289                                   0.4397
# 	->Micro Avg.                                 0.4317                                   0.4317
# 	======================================================================================================
# Epoch 13/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 11.589 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.51781                        Loss: 1.381
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5487                                   0.3502
# 	dandelion                                    0.4890                                   0.5523
# 	rose                                         0.6085                                   0.4115
# 	sunflower                                    0.4559                                   0.8635
# 	tulip                                        0.5969                                   0.4384
# 	->Macro Avg.                                 0.5398                                   0.5232
# 	->Micro Avg.                                 0.5178                                   0.5178
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.131 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.42708                        Loss: 3.8247
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3398                                   0.2288
# 	dandelion                                    0.3916                                   0.5762
# 	rose                                         0.5238                                   0.2102
# 	sunflower                                    0.4673                                   0.6803
# 	tulip                                        0.4571                                   0.4061
# 	->Macro Avg.                                 0.4359                                   0.4203
# 	->Micro Avg.                                 0.4271                                   0.4271
# 	======================================================================================================
# Epoch 14/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 11.359 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.5126                        Loss: 1.4831
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5132                                   0.3175
# 	dandelion                                    0.4879                                   0.5048
# 	rose                                         0.6158                                   0.4115
# 	sunflower                                    0.4556                                   0.8584
# 	tulip                                        0.5727                                   0.4956
# 	->Macro Avg.                                 0.5290                                   0.5175
# 	->Micro Avg.                                 0.5126                                   0.5126
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.163 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.44213                        Loss: 3.4503
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4105                                   0.5098
# 	dandelion                                    0.4186                                   0.2571
# 	rose                                         0.4941                                   0.2675
# 	sunflower                                    0.4485                                   0.8299
# 	tulip                                        0.4574                                   0.4365
# 	->Macro Avg.                                 0.4458                                   0.4602
# 	->Micro Avg.                                 0.4421                                   0.4421
# 	======================================================================================================
# Epoch 15/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 11.738 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.52563                        Loss: 1.6323
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5153                                   0.3306
# 	dandelion                                    0.4904                                   0.5487
# 	rose                                         0.6000                                   0.4545
# 	sunflower                                    0.4970                                   0.8498
# 	tulip                                        0.5732                                   0.4676
# 	->Macro Avg.                                 0.5352                                   0.5303
# 	->Micro Avg.                                 0.5256                                   0.5256
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.103 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.41551                        Loss: 3.3963
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4000                                   0.2484
# 	dandelion                                    0.3899                                   0.4048
# 	rose                                         0.6444                                   0.1847
# 	sunflower                                    0.4000                                   0.8299
# 	tulip                                        0.4229                                   0.4315
# 	->Macro Avg.                                 0.4514                                   0.4198
# 	->Micro Avg.                                 0.4155                                   0.4155
# 	======================================================================================================
# Epoch 16/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 11.491 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.52737                        Loss: 1.5588
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5481                                   0.3732
# 	dandelion                                    0.5200                                   0.5404
# 	rose                                         0.5913                                   0.4338
# 	sunflower                                    0.4674                                   0.8686
# 	tulip                                        0.5824                                   0.4536
# 	->Macro Avg.                                 0.5418                                   0.5339
# 	->Micro Avg.                                 0.5274                                   0.5274
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.118 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.41898                        Loss: 4.3682
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3710                                   0.1503
# 	dandelion                                    0.4190                                   0.4190
# 	rose                                         0.6447                                   0.3121
# 	sunflower                                    0.3636                                   0.8707
# 	tulip                                        0.4512                                   0.3756
# 	->Macro Avg.                                 0.4499                                   0.4256
# 	->Micro Avg.                                 0.4190                                   0.4190
# 	======================================================================================================
# Epoch 17/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 11.598 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.51028                        Loss: 1.485
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5140                                   0.3617
# 	dandelion                                    0.4862                                   0.4798
# 	rose                                         0.5916                                   0.4067
# 	sunflower                                    0.4495                                   0.8652
# 	tulip                                        0.5924                                   0.4765
# 	->Macro Avg.                                 0.5267                                   0.5180
# 	->Micro Avg.                                 0.5103                                   0.5103
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.147 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.40278                        Loss: 3.8355
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.2500                                   0.1111
# 	dandelion                                    0.4286                                   0.5000
# 	rose                                         0.5000                                   0.2229
# ...
# 	->Macro Avg.                                 0.5855                                   0.5674
# 	->Micro Avg.                                 0.5613                                   0.5613
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.137 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.43287                        Loss: 5.6339
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4128                                   0.4641
# 	dandelion                                    0.3838                                   0.3381
# 	rose                                         0.5246                                   0.4076
# 	sunflower                                    0.4137                                   0.7823
# 	tulip                                        0.4953                                   0.2690
# 	->Macro Avg.                                 0.4460                                   0.4522
# 	->Micro Avg.                                 0.4329                                   0.4329
# 	======================================================================================================
# Epoch 26/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 11.473 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.55604                        Loss: 1.4885
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5738                                   0.4452
# 	dandelion                                    0.5381                                   0.4608
# 	rose                                         0.6580                                   0.4848
# 	sunflower                                    0.4716                                   0.9078
# 	tulip                                        0.6347                                   0.5388
# 	->Macro Avg.                                 0.5753                                   0.5675
# 	->Micro Avg.                                 0.5560                                   0.5560
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.167 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.45718                        Loss: 4.4728
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5741                                   0.2026
# 	dandelion                                    0.3897                                   0.6476
# 	rose                                         0.4198                                   0.4331
# 	sunflower                                    0.5665                                   0.6667
# 	tulip                                        0.4921                                   0.3147
# 	->Macro Avg.                                 0.4884                                   0.4529
# 	->Micro Avg.                                 0.4572                                   0.4572
# 	======================================================================================================
# Epoch 27/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 11.437 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.55836                        Loss: 1.6788
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5987                                   0.4419
# 	dandelion                                    0.5281                                   0.5582
# 	rose                                         0.6179                                   0.4514
# 	sunflower                                    0.4981                                   0.8891
# 	tulip                                        0.6316                                   0.4879
# 	->Macro Avg.                                 0.5749                                   0.5657
# 	->Micro Avg.                                 0.5584                                   0.5584
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.118 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.45718                        Loss: 4.0057
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.6739                                   0.2026
# 	dandelion                                    0.4072                                   0.7000
# 	rose                                         0.4318                                   0.2420
# 	sunflower                                    0.5260                                   0.6190
# 	tulip                                        0.4490                                   0.4467
# 	->Macro Avg.                                 0.4976                                   0.4421
# 	->Micro Avg.                                 0.4572                                   0.4572
# 	======================================================================================================
# Epoch 28/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 11.430 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.55749                        Loss: 1.5516
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5910                                   0.4517
# 	dandelion                                    0.5168                                   0.5119
# 	rose                                         0.6225                                   0.4498
# 	sunflower                                    0.5014                                   0.8857
# 	tulip                                        0.6280                                   0.5299
# 	->Macro Avg.                                 0.5720                                   0.5658
# 	->Micro Avg.                                 0.5575                                   0.5575
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.143 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.43287                        Loss: 3.3461
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4522                                   0.3399
# 	dandelion                                    0.4728                                   0.4143
# 	rose                                         0.5259                                   0.3885
# 	sunflower                                    0.3478                                   0.8163
# 	tulip                                        0.5192                                   0.2741
# 	->Macro Avg.                                 0.4636                                   0.4466
# 	->Micro Avg.                                 0.4329                                   0.4329
# 	======================================================================================================
# Epoch 29/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 11.486 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.58818                        Loss: 1.5114
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.6320                                   0.4779
# 	dandelion                                    0.5655                                   0.5689
# 	rose                                         0.6499                                   0.4944
# 	sunflower                                    0.5279                                   0.9044
# 	tulip                                        0.6335                                   0.5337
# 	->Macro Avg.                                 0.6018                                   0.5959
# 	->Micro Avg.                                 0.5882                                   0.5882
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.206 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.43056                        Loss: 4.1585
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4035                                   0.3007
# 	dandelion                                    0.4607                                   0.3905
# 	rose                                         0.4655                                   0.1720
# 	sunflower                                    0.4192                                   0.8299
# 	tulip                                        0.4260                                   0.4822
# 	->Macro Avg.                                 0.4350                                   0.4351
# 	->Micro Avg.                                 0.4306                                   0.4306
# 	======================================================================================================
# Epoch 30/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 11.473 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.58326                        Loss: 1.6302
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.6427                                   0.4681
# 	dandelion                                    0.5501                                   0.5736
# 	rose                                         0.6088                                   0.4864
# 	sunflower                                    0.5295                                   0.8874
# 	tulip                                        0.6491                                   0.5337
# 	->Macro Avg.                                 0.5961                                   0.5898
# 	->Micro Avg.                                 0.5833                                   0.5833
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.152 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.42361                        Loss: 3.741
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4405                                   0.2418
# 	dandelion                                    0.4202                                   0.4762
# 	rose                                         0.4732                                   0.3376
# 	sunflower                                    0.4189                                   0.7551
# 	tulip                                        0.3939                                   0.3299
# 	->Macro Avg.                                 0.4293                                   0.4281
# 	->Micro Avg.                                 0.4236                                   0.4236
# 	======================================================================================================

# %%
cnn_stats = run_model(CNN(), label="CNN", color="navy")
# Out:
# Epoch 1/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 17.296 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.36693                        Loss: 1.8032
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3403                                   0.3470
# 	dandelion                                    0.3519                                   0.3967
# 	rose                                         0.4606                                   0.2520
# 	sunflower                                    0.3533                                   0.4420
# 	tulip                                        0.3776                                   0.3863
# 	->Macro Avg.                                 0.3768                                   0.3648
# 	->Micro Avg.                                 0.3669                                   0.3669
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.776 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.51157                        Loss: 1.2383
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5096                                   0.5229
# 	dandelion                                    0.5381                                   0.5048
# 	rose                                         0.4627                                   0.5924
# 	sunflower                                    0.5051                                   0.6803
# 	tulip                                        0.5676                                   0.3198
# 	->Macro Avg.                                 0.5166                                   0.5240
# 	->Micro Avg.                                 0.5116                                   0.5116
# 	======================================================================================================
# Epoch 2/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 17.801 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.53982                        Loss: 1.1335
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5119                                   0.4566
# 	dandelion                                    0.5038                                   0.6235
# 	rose                                         0.5467                                   0.4482
# 	sunflower                                    0.5593                                   0.6195
# 	tulip                                        0.5917                                   0.5286
# 	->Macro Avg.                                 0.5427                                   0.5353
# 	->Micro Avg.                                 0.5398                                   0.5398
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.800 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.54745                        Loss: 1.1026
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5188                                   0.5425
# 	dandelion                                    0.5088                                   0.6857
# 	rose                                         0.5750                                   0.4395
# 	sunflower                                    0.5723                                   0.6190
# 	tulip                                        0.6056                                   0.4365
# 	->Macro Avg.                                 0.5561                                   0.5447
# 	->Micro Avg.                                 0.5475                                   0.5475
# 	======================================================================================================
# Epoch 3/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 17.838 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.62091                        Loss: 0.98047
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.6020                                   0.5794
# 	dandelion                                    0.5953                                   0.6865
# 	rose                                         0.6360                                   0.5183
# 	sunflower                                    0.6494                                   0.7048
# 	tulip                                        0.6345                                   0.6023
# 	->Macro Avg.                                 0.6234                                   0.6182
# 	->Micro Avg.                                 0.6209                                   0.6209
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.886 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.54051                        Loss: 1.1237
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5385                                   0.6405
# 	dandelion                                    0.5412                                   0.6571
# 	rose                                         0.4865                                   0.5732
# 	sunflower                                    0.7600                                   0.2585
# 	tulip                                        0.5365                                   0.5228
# 	->Macro Avg.                                 0.5725                                   0.5305
# 	->Micro Avg.                                 0.5405                                   0.5405
# 	======================================================================================================
# Epoch 4/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 17.247 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.67709                        Loss: 0.85643
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.6911                                   0.6628
# 	dandelion                                    0.6511                                   0.7292
# 	rose                                         0.6726                                   0.6061
# 	sunflower                                    0.6786                                   0.7133
# 	tulip                                        0.7012                                   0.6620
# 	->Macro Avg.                                 0.6789                                   0.6747
# 	->Micro Avg.                                 0.6771                                   0.6771
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.779 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.58796                        Loss: 1.0672
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.6870                                   0.5163
# 	dandelion                                    0.5638                                   0.7571
# 	rose                                         0.4954                                   0.6815
# 	sunflower                                    0.6000                                   0.7143
# 	tulip                                        0.7632                                   0.2944
# 	->Macro Avg.                                 0.6219                                   0.5927
# 	->Micro Avg.                                 0.5880                                   0.5880
# 	======================================================================================================
# Epoch 5/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 17.246 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.73907                        Loss: 0.70646
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.7644                                   0.7169
# 	dandelion                                    0.7131                                   0.7969
# 	rose                                         0.7375                                   0.7033
# 	sunflower                                    0.7175                                   0.7543
# 	tulip                                        0.7724                                   0.7116
# 	->Macro Avg.                                 0.7410                                   0.7366
# 	->Micro Avg.                                 0.7391                                   0.7391
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.753 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.58333                        Loss: 1.2101
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.8219                                   0.3922
# 	dandelion                                    0.5918                                   0.6905
# 	rose                                         0.5333                                   0.6115
# 	sunflower                                    0.4938                                   0.8163
# 	tulip                                        0.6748                                   0.4213
# 	->Macro Avg.                                 0.6231                                   0.5863
# 	->Micro Avg.                                 0.5833                                   0.5833
# 	======================================================================================================
# Epoch 6/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 17.272 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.819                        Loss: 0.51387
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.8305                                   0.7938
# 	dandelion                                    0.7903                                   0.8551
# 	rose                                         0.8450                                   0.7911
# 	sunflower                                    0.8092                                   0.8396
# 	tulip                                        0.8322                                   0.8069
# 	->Macro Avg.                                 0.8214                                   0.8173
# 	->Micro Avg.                                 0.8190                                   0.8190
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.865 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.61111                        Loss: 1.2477
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.7358                                   0.5098
# 	dandelion                                    0.7072                                   0.6095
# 	rose                                         0.6339                                   0.4522
# 	sunflower                                    0.5978                                   0.7279
# 	tulip                                        0.5035                                   0.7310
# 	->Macro Avg.                                 0.6356                                   0.6061
# 	->Micro Avg.                                 0.6111                                   0.6111
# 	======================================================================================================
# Epoch 7/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 17.307 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.87866                        Loss: 0.3783
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.9089                                   0.8494
# 	dandelion                                    0.8495                                   0.9050
# 	rose                                         0.8894                                   0.8469
# 	sunflower                                    0.8703                                   0.9044
# 	tulip                                        0.8883                                   0.8793
# 	->Macro Avg.                                 0.8813                                   0.8770
# 	->Micro Avg.                                 0.8787                                   0.8787
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.795 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.60532                        Loss: 1.2359
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5754                                   0.6732
# 	dandelion                                    0.6951                                   0.5429
# 	rose                                         0.5556                                   0.5096
# 	sunflower                                    0.6386                                   0.7211
# 	tulip                                        0.5687                                   0.6091
# 	->Macro Avg.                                 0.6067                                   0.6112
# 	->Micro Avg.                                 0.6053                                   0.6053
# 	======================================================================================================
# Epoch 8/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 17.523 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.90906                        Loss: 0.28049
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.9337                                   0.8985
# 	dandelion                                    0.8940                                   0.9311
# 	rose                                         0.9119                                   0.8915
# 	sunflower                                    0.8997                                   0.9181
# 	tulip                                        0.9125                                   0.9009
# 	->Macro Avg.                                 0.9103                                   0.9080
# 	->Micro Avg.                                 0.9091                                   0.9091
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.803 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.58102                        Loss: 1.3945
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5897                                   0.6013
# 	dandelion                                    0.6793                                   0.5952
# 	rose                                         0.5862                                   0.3248
# 	sunflower                                    0.5544                                   0.7279
# 	tulip                                        0.5205                                   0.6447
# 	->Macro Avg.                                 0.5860                                   0.5788
# 	->Micro Avg.                                 0.5810                                   0.5810
# 	======================================================================================================
# Epoch 9/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 17.708 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.94179                        Loss: 0.19186
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.9646                                   0.9362
# 	dandelion                                    0.9205                                   0.9489
# 	rose                                         0.9378                                   0.9378
# 	sunflower                                    0.9346                                   0.9505
# 	tulip                                        0.9571                                   0.9352
# 	->Macro Avg.                                 0.9429                                   0.9417
# 	->Micro Avg.                                 0.9418                                   0.9418
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.761 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.60995                        Loss: 1.5195
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.7292                                   0.4575
# 	dandelion                                    0.5907                                   0.7286
# 	rose                                         0.5817                                   0.5669
# 	sunflower                                    0.5938                                   0.7755
# 	tulip                                        0.6159                                   0.5127
# 	->Macro Avg.                                 0.6222                                   0.6082
# 	->Micro Avg.                                 0.6100                                   0.6100
# 	======================================================================================================
# Epoch 10/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 17.404 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.95511                        Loss: 0.14278
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.9782                                   0.9558
# 	dandelion                                    0.9469                                   0.9739
# 	rose                                         0.9473                                   0.9171
# 	sunflower                                    0.9645                                   0.9727
# 	tulip                                        0.9457                                   0.9517
# 	->Macro Avg.                                 0.9565                                   0.9542
# 	->Micro Avg.                                 0.9551                                   0.9551
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.765 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.59144                        Loss: 1.5888
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.6750                                   0.5294
# 	dandelion                                    0.6286                                   0.6286
# 	rose                                         0.4757                                   0.6242
# 	sunflower                                    0.5899                                   0.7143
# 	tulip                                        0.6333                                   0.4822
# 	->Macro Avg.                                 0.6005                                   0.5957
# 	->Micro Avg.                                 0.5914                                   0.5914
# 	======================================================================================================
# Epoch 11/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 17.424 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.96901                        Loss: 0.1087
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.9800                                   0.9640
# 	dandelion                                    0.9545                                   0.9727
# 	rose                                         0.9696                                   0.9665
# 	sunflower                                    0.9696                                   0.9795
# 	tulip                                        0.9755                                   0.9632
# 	->Macro Avg.                                 0.9699                                   0.9692
# 	->Micro Avg.                                 0.9690                                   0.9690
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.779 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.59375                        Loss: 1.7976
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.6636                                   0.4641
# 	dandelion                                    0.5840                                   0.6952
# 	rose                                         0.5410                                   0.6306
# 	sunflower                                    0.6087                                   0.6667
# 	tulip                                        0.6074                                   0.5025
# 	->Macro Avg.                                 0.6009                                   0.5918
# 	->Micro Avg.                                 0.5938                                   0.5938
# 	======================================================================================================
# Epoch 12/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 17.290 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.98118                        Loss: 0.077066
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.9852                                   0.9804
# 	dandelion                                    0.9717                                   0.9774
# 	rose                                         0.9791                                   0.9697
# 	sunflower                                    0.9864                                   0.9881
# 	tulip                                        0.9861                                   0.9898
# 	->Macro Avg.                                 0.9817                                   0.9811
# 	->Micro Avg.                                 0.9812                                   0.9812
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.872 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.59838                        Loss: 1.8833
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5759                                   0.5948
# 	dandelion                                    0.6684                                   0.6048
# 	rose                                         0.5785                                   0.4459
# 	sunflower                                    0.6136                                   0.7347
# 	tulip                                        0.5525                                   0.6142
# 	->Macro Avg.                                 0.5978                                   0.5989
# 	->Micro Avg.                                 0.5984                                   0.5984
# 	======================================================================================================
# Epoch 13/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 17.333 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.989                        Loss: 0.049008
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.9951                                   0.9885
# 	dandelion                                    0.9870                                   0.9941
# 	rose                                         0.9855                                   0.9777
# 	sunflower                                    0.9882                                   0.9966
# 	tulip                                        0.9898                                   0.9873
# 	->Macro Avg.                                 0.9891                                   0.9888
# 	->Micro Avg.                                 0.9890                                   0.9890
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.760 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.61343                        Loss: 1.9153
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.6423                                   0.5752
# 	dandelion                                    0.6617                                   0.6333
# 	rose                                         0.5435                                   0.6369
# 	sunflower                                    0.6690                                   0.6463
# 	tulip                                        0.5700                                   0.5787
# 	->Macro Avg.                                 0.6173                                   0.6141
# 	->Micro Avg.                                 0.6134                                   0.6134
# 	======================================================================================================
# Epoch 14/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 17.368 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.99537                        Loss: 0.028527
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.9984                                   0.9918
# 	dandelion                                    0.9917                                   0.9952
# 	rose                                         0.9952                                   0.9952
# 	sunflower                                    0.9949                                   0.9983
# 	tulip                                        0.9975                                   0.9962
# 	->Macro Avg.                                 0.9955                                   0.9954
# 	->Micro Avg.                                 0.9954                                   0.9954
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.769 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.61806                        Loss: 2.1699
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5695                                   0.5621
# 	dandelion                                    0.6837                                   0.6381
# 	rose                                         0.6118                                   0.5924
# 	sunflower                                    0.6386                                   0.7211
# 	tulip                                        0.5779                                   0.5838
# 	->Macro Avg.                                 0.6163                                   0.6195
# 	->Micro Avg.                                 0.6181                                   0.6181
# 	======================================================================================================
# Epoch 15/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 17.399 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.99566                        Loss: 0.020093
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.9967                                   0.9967
# 	dandelion                                    0.9976                                   0.9964
# 	rose                                         0.9984                                   0.9936
# 	sunflower                                    0.9932                                   0.9966
# 	tulip                                        0.9924                                   0.9949
# 	->Macro Avg.                                 0.9957                                   0.9957
# 	->Micro Avg.                                 0.9957                                   0.9957
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.791 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.60648                        Loss: 2.3582
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.6545                                   0.4706
# 	dandelion                                    0.5594                                   0.7619
# 	rose                                         0.5671                                   0.5924
# 	sunflower                                    0.6500                                   0.6190
# 	tulip                                        0.6585                                   0.5482
# 	->Macro Avg.                                 0.6179                                   0.5984
# 	->Micro Avg.                                 0.6065                                   0.6065
# 	======================================================================================================
# Epoch 16/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 17.508 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.99681                        Loss: 0.02161
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.9967                                   0.9984
# 	dandelion                                    0.9976                                   0.9964
# 	rose                                         0.9936                                   0.9936
# 	sunflower                                    1.0000                                   1.0000
# 	tulip                                        0.9962                                   0.9962
# 	->Macro Avg.                                 0.9968                                   0.9969
# 	->Micro Avg.                                 0.9968                                   0.9968
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.777 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.59954                        Loss: 2.4676
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4977                                   0.6993
# 	dandelion                                    0.6649                                   0.6143
# 	rose                                         0.6306                                   0.4459
# 	sunflower                                    0.6226                                   0.6735
# 	tulip                                        0.6108                                   0.5736
# 	->Macro Avg.                                 0.6053                                   0.6013
# 	->Micro Avg.                                 0.5995                                   0.5995
# 	======================================================================================================
# Epoch 17/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 17.472 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.99624                        Loss: 0.026851
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.9967                                   0.9984
# 	dandelion                                    0.9976                                   0.9964
# 	rose                                         0.9936                                   0.9920
# 	sunflower                                    0.9983                                   1.0000
# 	tulip                                        0.9949                                   0.9949
# 	->Macro Avg.                                 0.9962                                   0.9963
# 	->Micro Avg.                                 0.9962                                   0.9962
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.760 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.59144                        Loss: 2.242
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5367                                   0.6209
# 	dandelion                                    0.6121                                   0.6238
# ...
# 	->Macro Avg.                                 0.9878                                   0.9877
# 	->Micro Avg.                                 0.9875                                   0.9875
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.996 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.55787                        Loss: 3.4146
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.6000                                   0.4902
# 	dandelion                                    0.6270                                   0.5524
# 	rose                                         0.4619                                   0.6178
# 	sunflower                                    0.5525                                   0.6803
# 	tulip                                        0.5767                                   0.4772
# 	->Macro Avg.                                 0.5636                                   0.5636
# 	->Micro Avg.                                 0.5579                                   0.5579
# 	======================================================================================================
# Epoch 26/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 18.230 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.97973                        Loss: 0.06223
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.9804                                   0.9836
# 	dandelion                                    0.9820                                   0.9727
# 	rose                                         0.9841                                   0.9856
# 	sunflower                                    0.9728                                   0.9761
# 	tulip                                        0.9785                                   0.9822
# 	->Macro Avg.                                 0.9796                                   0.9801
# 	->Micro Avg.                                 0.9797                                   0.9797
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.909 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.53125                        Loss: 2.9304
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5029                                   0.5686
# 	dandelion                                    0.6916                                   0.3524
# 	rose                                         0.5000                                   0.5669
# 	sunflower                                    0.5345                                   0.6327
# 	tulip                                        0.5000                                   0.5888
# 	->Macro Avg.                                 0.5458                                   0.5419
# 	->Micro Avg.                                 0.5312                                   0.5312
# 	======================================================================================================
# Epoch 27/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 18.031 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.98552                        Loss: 0.054604
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.9935                                   0.9935
# 	dandelion                                    0.9822                                   0.9846
# 	rose                                         0.9824                                   0.9809
# 	sunflower                                    0.9846                                   0.9829
# 	tulip                                        0.9860                                   0.9860
# 	->Macro Avg.                                 0.9857                                   0.9856
# 	->Micro Avg.                                 0.9855                                   0.9855
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.896 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.60417                        Loss: 2.8647
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.6410                                   0.4902
# 	dandelion                                    0.5789                                   0.7333
# 	rose                                         0.6311                                   0.4904
# 	sunflower                                    0.6074                                   0.6735
# 	tulip                                        0.5969                                   0.5939
# 	->Macro Avg.                                 0.6111                                   0.5963
# 	->Micro Avg.                                 0.6042                                   0.6042
# 	======================================================================================================
# Epoch 28/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 17.988 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.99479                        Loss: 0.019941
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.9967                                   0.9984
# 	dandelion                                    0.9941                                   0.9964
# 	rose                                         0.9984                                   0.9936
# 	sunflower                                    0.9949                                   0.9932
# 	tulip                                        0.9911                                   0.9924
# 	->Macro Avg.                                 0.9950                                   0.9948
# 	->Micro Avg.                                 0.9948                                   0.9948
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.889 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.59838                        Loss: 2.7775
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5782                                   0.5556
# 	dandelion                                    0.6596                                   0.5905
# 	rose                                         0.5353                                   0.5796
# 	sunflower                                    0.5746                                   0.7075
# 	tulip                                        0.6348                                   0.5736
# 	->Macro Avg.                                 0.5965                                   0.6013
# 	->Micro Avg.                                 0.5984                                   0.5984
# 	======================================================================================================
# Epoch 29/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 17.973 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.99392                        Loss: 0.025672
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.9984                                   0.9984
# 	dandelion                                    0.9941                                   0.9929
# 	rose                                         0.9904                                   0.9904
# 	sunflower                                    0.9966                                   0.9949
# 	tulip                                        0.9911                                   0.9936
# 	->Macro Avg.                                 0.9941                                   0.9940
# 	->Micro Avg.                                 0.9939                                   0.9939
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.906 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.59722                        Loss: 3.2005
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.6827                                   0.4641
# 	dandelion                                    0.5354                                   0.8286
# 	rose                                         0.5658                                   0.5478
# 	sunflower                                    0.6301                                   0.6259
# 	tulip                                        0.6788                                   0.4721
# 	->Macro Avg.                                 0.6186                                   0.5877
# 	->Micro Avg.                                 0.5972                                   0.5972
# 	======================================================================================================
# Epoch 30/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 17.880 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.98523                        Loss: 0.049232
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.9918                                   0.9918
# 	dandelion                                    0.9821                                   0.9798
# 	rose                                         0.9825                                   0.9825
# 	sunflower                                    0.9864                                   0.9898
# 	tulip                                        0.9848                                   0.9848
# 	->Macro Avg.                                 0.9855                                   0.9857
# 	->Micro Avg.                                 0.9852                                   0.9852
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.951 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.5787                        Loss: 2.8288
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5957                                   0.5490
# 	dandelion                                    0.6071                                   0.6476
# 	rose                                         0.5161                                   0.5096
# 	sunflower                                    0.6343                                   0.5782
# 	tulip                                        0.5476                                   0.5838
# 	->Macro Avg.                                 0.5802                                   0.5736
# 	->Micro Avg.                                 0.5787                                   0.5787
# 	======================================================================================================

# %%
lstm_stats = run_model(LSTM(), label="LSTM", color="orange")
# Out:
# Epoch 1/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 214.414 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.25485                        Loss: 1.5764
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.0909                                   0.0049
# 	dandelion                                    0.2498                                   0.3385
# 	rose                                         0.2432                                   0.2265
# 	sunflower                                    0.3051                                   0.3191
# 	tulip                                        0.2431                                   0.3342
# 	->Macro Avg.                                 0.2264                                   0.2446
# 	->Micro Avg.                                 0.2549                                   0.2549
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 17.457 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.29514                        Loss: 1.5195
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.0000                                   0.0000
# 	dandelion                                    0.3099                                   0.6714
# 	rose                                         0.3251                                   0.4204
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.2330                                   0.2437
# 	->Macro Avg.                                 0.1736                                   0.2671
# 	->Micro Avg.                                 0.2951                                   0.2951
# 	======================================================================================================
# Epoch 2/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 225.203 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.32059                        Loss: 1.4621
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3116                                   0.1489
# 	dandelion                                    0.3007                                   0.3943
# 	rose                                         0.2676                                   0.2360
# 	sunflower                                    0.3834                                   0.4181
# 	tulip                                        0.3364                                   0.3698
# 	->Macro Avg.                                 0.3200                                   0.3134
# 	->Micro Avg.                                 0.3206                                   0.3206
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 13.219 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.35764                        Loss: 1.4249
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.2174                                   0.1634
# 	dandelion                                    0.3233                                   0.6667
# 	rose                                         0.3520                                   0.2803
# 	sunflower                                    0.5185                                   0.2857
# 	tulip                                        0.5273                                   0.2944
# 	->Macro Avg.                                 0.3877                                   0.3381
# 	->Micro Avg.                                 0.3576                                   0.3576
# 	======================================================================================================
# Epoch 3/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 211.081 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.37011                        Loss: 1.3626
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3049                                   0.2930
# 	dandelion                                    0.3289                                   0.3836
# 	rose                                         0.3164                                   0.2185
# 	sunflower                                    0.4239                                   0.5512
# 	tulip                                        0.4586                                   0.4015
# 	->Macro Avg.                                 0.3666                                   0.3696
# 	->Micro Avg.                                 0.3701                                   0.3701
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 13.262 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.33333                        Loss: 1.4461
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.0714                                   0.0065
# 	dandelion                                    0.2933                                   0.5810
# 	rose                                         0.2946                                   0.2102
# 	sunflower                                    0.3929                                   0.5238
# 	tulip                                        0.4365                                   0.2792
# 	->Macro Avg.                                 0.2977                                   0.3201
# 	->Micro Avg.                                 0.3333                                   0.3333
# 	======================================================================================================
# Epoch 4/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 211.275 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.39357                        Loss: 1.346
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3420                                   0.3650
# 	dandelion                                    0.3741                                   0.3884
# 	rose                                         0.3097                                   0.2711
# 	sunflower                                    0.4687                                   0.5870
# 	tulip                                        0.4581                                   0.3748
# 	->Macro Avg.                                 0.3905                                   0.3973
# 	->Micro Avg.                                 0.3936                                   0.3936
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 13.441 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.375                        Loss: 1.3886
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3553                                   0.6340
# 	dandelion                                    0.3009                                   0.1619
# 	rose                                         0.3509                                   0.1274
# 	sunflower                                    0.4043                                   0.6327
# 	tulip                                        0.4188                                   0.4061
# 	->Macro Avg.                                 0.3661                                   0.3924
# 	->Micro Avg.                                 0.3750                                   0.3750
# 	======================================================================================================
# Epoch 5/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 211.628 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.40226                        Loss: 1.3165
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3607                                   0.4239
# 	dandelion                                    0.3618                                   0.3979
# 	rose                                         0.3410                                   0.1882
# 	sunflower                                    0.4940                                   0.5614
# 	tulip                                        0.4366                                   0.4422
# 	->Macro Avg.                                 0.3988                                   0.4027
# 	->Micro Avg.                                 0.4023                                   0.4023
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 13.216 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.37269                        Loss: 1.3708
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.2241                                   0.1699
# 	dandelion                                    0.3551                                   0.7238
# 	rose                                         0.3824                                   0.2484
# 	sunflower                                    0.5306                                   0.1769
# 	tulip                                        0.4675                                   0.4010
# 	->Macro Avg.                                 0.3919                                   0.3440
# 	->Micro Avg.                                 0.3727                                   0.3727
# 	======================================================================================================
# Epoch 6/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 210.232 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.41297                        Loss: 1.3018
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3398                                   0.3159
# 	dandelion                                    0.3658                                   0.4501
# 	rose                                         0.3778                                   0.3206
# 	sunflower                                    0.5148                                   0.5631
# 	tulip                                        0.4778                                   0.4104
# 	->Macro Avg.                                 0.4152                                   0.4120
# 	->Micro Avg.                                 0.4130                                   0.4130
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 13.412 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.36227                        Loss: 1.3857
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.2925                                   0.4052
# 	dandelion                                    0.3757                                   0.3095
# 	rose                                         0.2000                                   0.0064
# 	sunflower                                    0.3769                                   0.6667
# 	tulip                                        0.4065                                   0.4416
# 	->Macro Avg.                                 0.3303                                   0.3659
# 	->Micro Avg.                                 0.3623                                   0.3623
# 	======================================================================================================
# Epoch 7/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 214.354 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.43933                        Loss: 1.2587
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3465                                   0.4026
# 	dandelion                                    0.4004                                   0.4489
# 	rose                                         0.4414                                   0.2823
# 	sunflower                                    0.5497                                   0.6041
# 	tulip                                        0.4801                                   0.4600
# 	->Macro Avg.                                 0.4436                                   0.4396
# 	->Micro Avg.                                 0.4393                                   0.4393
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 13.755 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.37963                        Loss: 1.3983
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3186                                   0.6144
# 	dandelion                                    0.4000                                   0.2667
# 	rose                                         0.3475                                   0.5732
# 	sunflower                                    0.5517                                   0.3265
# 	tulip                                        0.4819                                   0.2030
# 	->Macro Avg.                                 0.4200                                   0.3968
# 	->Micro Avg.                                 0.3796                                   0.3796
# 	======================================================================================================
# Epoch 8/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 211.933 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.45844                        Loss: 1.215
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3847                                   0.4943
# 	dandelion                                    0.4076                                   0.3931
# 	rose                                         0.4557                                   0.4019
# 	sunflower                                    0.5513                                   0.5956
# 	tulip                                        0.5209                                   0.4435
# 	->Macro Avg.                                 0.4641                                   0.4657
# 	->Micro Avg.                                 0.4584                                   0.4584
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 13.323 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.40394                        Loss: 1.3758
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.2840                                   0.6013
# 	dandelion                                    0.4102                                   0.5000
# 	rose                                         0.4583                                   0.3503
# 	sunflower                                    0.5905                                   0.4218
# 	tulip                                        0.5932                                   0.1777
# 	->Macro Avg.                                 0.4672                                   0.4102
# 	->Micro Avg.                                 0.4039                                   0.4039
# 	======================================================================================================
# Epoch 9/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 211.385 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.48219                        Loss: 1.2032
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3958                                   0.4321
# 	dandelion                                    0.4461                                   0.5261
# 	rose                                         0.4514                                   0.3780
# 	sunflower                                    0.6092                                   0.6092
# 	tulip                                        0.5337                                   0.4625
# 	->Macro Avg.                                 0.4873                                   0.4816
# 	->Micro Avg.                                 0.4822                                   0.4822
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 13.382 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.41551                        Loss: 1.3553
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3544                                   0.3660
# 	dandelion                                    0.3601                                   0.5762
# 	rose                                         0.4217                                   0.4459
# 	sunflower                                    0.5182                                   0.3878
# 	tulip                                        0.5851                                   0.2792
# 	->Macro Avg.                                 0.4479                                   0.4110
# 	->Micro Avg.                                 0.4155                                   0.4155
# 	======================================================================================================
# Epoch 10/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 211.499 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.4958                        Loss: 1.1629
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4334                                   0.4419
# 	dandelion                                    0.4571                                   0.5119
# 	rose                                         0.4576                                   0.4386
# 	sunflower                                    0.6169                                   0.6212
# 	tulip                                        0.5345                                   0.4727
# 	->Macro Avg.                                 0.4999                                   0.4972
# 	->Micro Avg.                                 0.4958                                   0.4958
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 13.507 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.41088                        Loss: 1.3738
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4462                                   0.1895
# 	dandelion                                    0.3669                                   0.4333
# 	rose                                         0.3855                                   0.4076
# 	sunflower                                    0.4424                                   0.4966
# 	tulip                                        0.4455                                   0.4975
# 	->Macro Avg.                                 0.4173                                   0.4049
# 	->Micro Avg.                                 0.4109                                   0.4109
# 	======================================================================================================
# Epoch 11/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 211.818 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.5013                        Loss: 1.1597
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4423                                   0.4075
# 	dandelion                                    0.4602                                   0.4941
# 	rose                                         0.4542                                   0.5136
# 	sunflower                                    0.6037                                   0.6109
# 	tulip                                        0.5643                                   0.4905
# 	->Macro Avg.                                 0.5049                                   0.5033
# 	->Micro Avg.                                 0.5013                                   0.5013
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 13.504 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.41088                        Loss: 1.4065
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3263                                   0.5033
# 	dandelion                                    0.3750                                   0.3143
# 	rose                                         0.4930                                   0.2229
# 	sunflower                                    0.4663                                   0.6122
# 	tulip                                        0.4628                                   0.4416
# 	->Macro Avg.                                 0.4247                                   0.4189
# 	->Micro Avg.                                 0.4109                                   0.4109
# 	======================================================================================================
# Epoch 12/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 242.239 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.51057                        Loss: 1.133
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4216                                   0.4534
# 	dandelion                                    0.4559                                   0.5214
# 	rose                                         0.4883                                   0.4322
# 	sunflower                                    0.6492                                   0.6536
# 	tulip                                        0.5712                                   0.4994
# 	->Macro Avg.                                 0.5172                                   0.5120
# 	->Micro Avg.                                 0.5106                                   0.5106
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 19.107 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.41435                        Loss: 1.4692
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.2500                                   0.1242
# 	dandelion                                    0.4007                                   0.5762
# 	rose                                         0.4505                                   0.2611
# 	sunflower                                    0.4520                                   0.5442
# 	tulip                                        0.4450                                   0.4924
# 	->Macro Avg.                                 0.3996                                   0.3996
# 	->Micro Avg.                                 0.4144                                   0.4144
# 	======================================================================================================
# Epoch 13/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 227.081 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.52939                        Loss: 1.1169
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4537                                   0.4648
# 	dandelion                                    0.4817                                   0.5309
# 	rose                                         0.5209                                   0.4976
# 	sunflower                                    0.6359                                   0.6229
# 	tulip                                        0.5785                                   0.5337
# 	->Macro Avg.                                 0.5341                                   0.5300
# 	->Micro Avg.                                 0.5294                                   0.5294
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 13.965 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.4213                        Loss: 1.3854
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3245                                   0.3987
# 	dandelion                                    0.4062                                   0.4333
# 	rose                                         0.4417                                   0.3376
# 	sunflower                                    0.4897                                   0.4830
# 	tulip                                        0.4706                                   0.4467
# 	->Macro Avg.                                 0.4265                                   0.4199
# 	->Micro Avg.                                 0.4213                                   0.4213
# 	======================================================================================================
# Epoch 14/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 223.732 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.54098                        Loss: 1.086
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4961                                   0.5172
# 	dandelion                                    0.4718                                   0.5463
# 	rose                                         0.5224                                   0.4641
# 	sunflower                                    0.6632                                   0.6451
# 	tulip                                        0.5924                                   0.5375
# 	->Macro Avg.                                 0.5492                                   0.5420
# 	->Micro Avg.                                 0.5410                                   0.5410
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 14.152 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.40278                        Loss: 1.3724
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3427                                   0.3203
# 	dandelion                                    0.3670                                   0.5190
# 	rose                                         0.4026                                   0.3949
# 	sunflower                                    0.5037                                   0.4626
# 	tulip                                        0.4444                                   0.3046
# 	->Macro Avg.                                 0.4121                                   0.4003
# 	->Micro Avg.                                 0.4028                                   0.4028
# 	======================================================================================================
# Epoch 15/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 225.715 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.56704                        Loss: 1.0489
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5053                                   0.4681
# 	dandelion                                    0.5015                                   0.6069
# 	rose                                         0.5405                                   0.5215
# 	sunflower                                    0.7041                                   0.6741
# 	tulip                                        0.6254                                   0.5578
# 	->Macro Avg.                                 0.5753                                   0.5657
# 	->Micro Avg.                                 0.5670                                   0.5670
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 13.942 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.41667                        Loss: 1.5089
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3856                                   0.3856
# 	dandelion                                    0.3916                                   0.5333
# 	rose                                         0.3796                                   0.2611
# 	sunflower                                    0.4867                                   0.4966
# 	tulip                                        0.4491                                   0.3807
# 	->Macro Avg.                                 0.4185                                   0.4115
# 	->Micro Avg.                                 0.4167                                   0.4167
# 	======================================================================================================
# Epoch 16/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 223.453 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.57573                        Loss: 1.0359
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5065                                   0.5074
# 	dandelion                                    0.5318                                   0.5855
# 	rose                                         0.5712                                   0.5311
# 	sunflower                                    0.6894                                   0.6741
# 	tulip                                        0.6029                                   0.5807
# 	->Macro Avg.                                 0.5804                                   0.5757
# 	->Micro Avg.                                 0.5757                                   0.5757
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 13.925 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.41435                        Loss: 1.4691
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3675                                   0.2810
# 	dandelion                                    0.3808                                   0.6238
# 	rose                                         0.4386                                   0.1592
# 	sunflower                                    0.5082                                   0.4218
# 	tulip                                        0.4330                                   0.4924
# 	->Macro Avg.                                 0.4256                                   0.3956
# 	->Micro Avg.                                 0.4144                                   0.4144
# 	======================================================================================================
# Epoch 17/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 226.522 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.59658                        Loss: 0.9992
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5623                                   0.5172
# 	dandelion                                    0.5348                                   0.6663
# 	rose                                         0.5900                                   0.5279
# 	sunflower                                    0.6939                                   0.6809
# 	tulip                                        0.6416                                   0.5756
# 	->Macro Avg.                                 0.6045                                   0.5936
# 	->Micro Avg.                                 0.5966                                   0.5966
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 15.386 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.42014                        Loss: 1.4268
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3333                                   0.2680
# 	dandelion                                    0.4070                                   0.5000
# ...
# 	->Macro Avg.                                 0.6753                                   0.6686
# 	->Micro Avg.                                 0.6704                                   0.6704
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 12.874 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.43866                        Loss: 1.4462
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3500                                   0.2745
# 	dandelion                                    0.4113                                   0.5524
# 	rose                                         0.4625                                   0.2357
# 	sunflower                                    0.5000                                   0.5578
# 	tulip                                        0.4679                                   0.5178
# 	->Macro Avg.                                 0.4383                                   0.4276
# 	->Micro Avg.                                 0.4387                                   0.4387
# 	======================================================================================================
# Epoch 26/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 194.395 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.68404                        Loss: 0.80105
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.6407                                   0.6187
# 	dandelion                                    0.6403                                   0.7209
# 	rose                                         0.6827                                   0.6348
# 	sunflower                                    0.7632                                   0.7423
# 	tulip                                        0.7139                                   0.6912
# 	->Macro Avg.                                 0.6881                                   0.6816
# 	->Micro Avg.                                 0.6840                                   0.6840
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 13.423 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.45486                        Loss: 1.5111
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4010                                   0.5033
# 	dandelion                                    0.4537                                   0.4429
# 	rose                                         0.4545                                   0.2866
# 	sunflower                                    0.5125                                   0.5578
# 	tulip                                        0.4615                                   0.4873
# 	->Macro Avg.                                 0.4567                                   0.4556
# 	->Micro Avg.                                 0.4549                                   0.4549
# 	======================================================================================================
# Epoch 27/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 195.857 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.70432                        Loss: 0.76769
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.6561                                   0.6743
# 	dandelion                                    0.6682                                   0.7007
# 	rose                                         0.6893                                   0.6475
# 	sunflower                                    0.7900                                   0.8089
# 	tulip                                        0.7304                                   0.6989
# 	->Macro Avg.                                 0.7068                                   0.7061
# 	->Micro Avg.                                 0.7043                                   0.7043
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 13.651 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.44213                        Loss: 1.5834
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3516                                   0.2941
# 	dandelion                                    0.4452                                   0.6000
# 	rose                                         0.4058                                   0.3567
# 	sunflower                                    0.5290                                   0.4966
# 	tulip                                        0.4633                                   0.4162
# 	->Macro Avg.                                 0.4390                                   0.4327
# 	->Micro Avg.                                 0.4421                                   0.4421
# 	======================================================================================================
# Epoch 28/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 197.026 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.72082                        Loss: 0.72269
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.6830                                   0.6628
# 	dandelion                                    0.6800                                   0.7245
# 	rose                                         0.7050                                   0.6746
# 	sunflower                                    0.8027                                   0.8123
# 	tulip                                        0.7468                                   0.7306
# 	->Macro Avg.                                 0.7235                                   0.7210
# 	->Micro Avg.                                 0.7208                                   0.7208
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 13.816 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.44676                        Loss: 1.5996
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4262                                   0.3399
# 	dandelion                                    0.4571                                   0.4571
# 	rose                                         0.4224                                   0.4331
# 	sunflower                                    0.4369                                   0.6599
# 	tulip                                        0.4899                                   0.3706
# 	->Macro Avg.                                 0.4465                                   0.4521
# 	->Micro Avg.                                 0.4468                                   0.4468
# 	======================================================================================================
# Epoch 29/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 195.795 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.71706                        Loss: 0.71977
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.6806                                   0.6661
# 	dandelion                                    0.6699                                   0.7375
# 	rose                                         0.7221                                   0.6507
# 	sunflower                                    0.8045                                   0.8003
# 	tulip                                        0.7321                                   0.7255
# 	->Macro Avg.                                 0.7218                                   0.7160
# 	->Micro Avg.                                 0.7171                                   0.7171
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 13.095 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.46875                        Loss: 1.5219
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5154                                   0.4379
# 	dandelion                                    0.5393                                   0.4905
# 	rose                                         0.4352                                   0.2994
# 	sunflower                                    0.5137                                   0.5102
# 	tulip                                        0.3910                                   0.5736
# 	->Macro Avg.                                 0.4789                                   0.4623
# 	->Micro Avg.                                 0.4688                                   0.4688
# 	======================================================================================================
# Epoch 30/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 191.908 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.7104                        Loss: 0.72728
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.6639                                   0.6498
# 	dandelion                                    0.6530                                   0.7173
# 	rose                                         0.7243                                   0.6619
# 	sunflower                                    0.8028                                   0.7850
# 	tulip                                        0.7360                                   0.7332
# 	->Macro Avg.                                 0.7160                                   0.7094
# 	->Micro Avg.                                 0.7104                                   0.7104
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 13.199 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.42593                        Loss: 1.5743
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4074                                   0.2157
# 	dandelion                                    0.4368                                   0.5762
# 	rose                                         0.3659                                   0.3822
# 	sunflower                                    0.4678                                   0.5442
# 	tulip                                        0.4327                                   0.3756
# 	->Macro Avg.                                 0.4221                                   0.4188
# 	->Micro Avg.                                 0.4259                                   0.4259
# 	======================================================================================================

# %%
scnn_stats = run_model(SCNN(), label="SCNN", color="red")
# Out:
# Epoch 1/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 9.393 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.1755                        Loss: 1.5897
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.1577                                   0.8151
# 	dandelion                                    0.3661                                   0.1283
# 	rose                                         0.0000                                   0.0000
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.0000                                   0.0000
# 	->Macro Avg.                                 0.1048                                   0.1887
# 	->Micro Avg.                                 0.1755                                   0.1755
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 1.940 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.1956                        Loss: 1.5294
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.0877                                   0.3203
# 	dandelion                                    0.3934                                   0.5714
# 	rose                                         0.0000                                   0.0000
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.0000                                   0.0000
# 	->Macro Avg.                                 0.0962                                   0.1783
# 	->Micro Avg.                                 0.1956                                   0.1956
# 	======================================================================================================
# Epoch 2/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 9.092 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.30466                        Loss: 1.5227
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.1393                                   0.1113
# 	dandelion                                    0.3350                                   0.7078
# 	rose                                         0.0000                                   0.0000
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.3272                                   0.4930
# 	->Macro Avg.                                 0.1603                                   0.2624
# 	->Micro Avg.                                 0.3047                                   0.3047
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 1.896 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.30903                        Loss: 1.5107
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3069                                   0.8105
# 	dandelion                                    0.1923                                   0.0238
# 	rose                                         0.0000                                   0.0000
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.3180                                   0.7005
# 	->Macro Avg.                                 0.1634                                   0.3070
# 	->Micro Avg.                                 0.3090                                   0.3090
# 	======================================================================================================
# Epoch 3/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 8.850 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.32378                        Loss: 1.4981
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.2832                                   0.1817
# 	dandelion                                    0.3257                                   0.5903
# 	rose                                         0.0000                                   0.0000
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.3322                                   0.6480
# 	->Macro Avg.                                 0.1882                                   0.2840
# 	->Micro Avg.                                 0.3238                                   0.3238
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 1.939 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.32523                        Loss: 1.5082
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.2500                                   0.0065
# 	dandelion                                    0.3299                                   0.7667
# 	rose                                         0.0000                                   0.0000
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.3199                                   0.6041
# 	->Macro Avg.                                 0.1800                                   0.2755
# 	->Micro Avg.                                 0.3252                                   0.3252
# 	======================================================================================================
# Epoch 4/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 8.925 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.33768                        Loss: 1.4824
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3595                                   0.1424
# 	dandelion                                    0.3438                                   0.6378
# 	rose                                         0.0000                                   0.0000
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.3287                                   0.6887
# 	->Macro Avg.                                 0.2064                                   0.2938
# 	->Micro Avg.                                 0.3377                                   0.3377
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 1.873 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.33218                        Loss: 1.4837
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4242                                   0.0915
# 	dandelion                                    0.3326                                   0.6810
# 	rose                                         0.0000                                   0.0000
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.3242                                   0.6599
# 	->Macro Avg.                                 0.2162                                   0.2865
# 	->Micro Avg.                                 0.3322                                   0.3322
# 	======================================================================================================
# Epoch 5/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 8.619 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.35187                        Loss: 1.4635
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3831                                   0.3110
# 	dandelion                                    0.3697                                   0.5439
# 	rose                                         0.0000                                   0.0000
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.3300                                   0.7205
# 	->Macro Avg.                                 0.2166                                   0.3151
# 	->Micro Avg.                                 0.3519                                   0.3519
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 1.950 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.33565                        Loss: 1.4748
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4400                                   0.3595
# 	dandelion                                    0.3287                                   0.4524
# 	rose                                         0.0000                                   0.0000
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.3111                                   0.7107
# 	->Macro Avg.                                 0.2160                                   0.3045
# 	->Micro Avg.                                 0.3356                                   0.3356
# 	======================================================================================================
# Epoch 6/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 8.778 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.34521                        Loss: 1.4491
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4158                                   0.1293
# 	dandelion                                    0.3580                                   0.6330
# 	rose                                         0.0000                                   0.0000
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.3269                                   0.7370
# 	->Macro Avg.                                 0.2201                                   0.2999
# 	->Micro Avg.                                 0.3452                                   0.3452
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.109 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.32755                        Loss: 1.4689
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3665                                   0.6732
# 	dandelion                                    0.2867                                   0.2048
# 	rose                                         0.0000                                   0.0000
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.3164                                   0.6954
# 	->Macro Avg.                                 0.1939                                   0.3147
# 	->Micro Avg.                                 0.3275                                   0.3275
# 	======================================================================================================
# Epoch 7/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 8.595 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.35853                        Loss: 1.4322
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4336                                   0.2029
# 	dandelion                                    0.3687                                   0.6152
# 	rose                                         0.0000                                   0.0000
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.3383                                   0.7573
# 	->Macro Avg.                                 0.2281                                   0.3151
# 	->Micro Avg.                                 0.3585                                   0.3585
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 1.910 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.33681                        Loss: 1.4937
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.0000                                   0.0000
# 	dandelion                                    0.3401                                   0.8000
# 	rose                                         0.0000                                   0.0000
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.3324                                   0.6244
# 	->Macro Avg.                                 0.1345                                   0.2849
# 	->Micro Avg.                                 0.3368                                   0.3368
# 	======================================================================================================
# Epoch 8/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 8.381 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.35766                        Loss: 1.4199
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4419                                   0.2177
# 	dandelion                                    0.3663                                   0.6021
# 	rose                                         0.0000                                   0.0000
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.3365                                   0.7560
# 	->Macro Avg.                                 0.2289                                   0.3152
# 	->Micro Avg.                                 0.3577                                   0.3577
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 1.851 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.33449                        Loss: 1.464
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4409                                   0.3660
# 	dandelion                                    0.3568                                   0.3857
# 	rose                                         0.0000                                   0.0000
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.2980                                   0.7716
# 	->Macro Avg.                                 0.2192                                   0.3047
# 	->Micro Avg.                                 0.3345                                   0.3345
# 	======================================================================================================
# Epoch 9/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 8.263 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.36027                        Loss: 1.4059
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3935                                   0.1784
# 	dandelion                                    0.3742                                   0.6021
# 	rose                                         0.0000                                   0.0000
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.3449                                   0.7980
# 	->Macro Avg.                                 0.2225                                   0.3157
# 	->Micro Avg.                                 0.3603                                   0.3603
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 1.965 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.33333                        Loss: 1.4673
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4706                                   0.1046
# 	dandelion                                    0.3424                                   0.6619
# 	rose                                         0.0000                                   0.0000
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.3137                                   0.6751
# 	->Macro Avg.                                 0.2253                                   0.2883
# 	->Micro Avg.                                 0.3333                                   0.3333
# 	======================================================================================================
# Epoch 10/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 8.976 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.36693                        Loss: 1.3963
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4508                                   0.2324
# 	dandelion                                    0.3832                                   0.6057
# 	rose                                         0.0000                                   0.0000
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.3403                                   0.7814
# 	->Macro Avg.                                 0.2349                                   0.3239
# 	->Micro Avg.                                 0.3669                                   0.3669
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.237 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.34259                        Loss: 1.4684
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5312                                   0.1111
# 	dandelion                                    0.3720                                   0.5810
# 	rose                                         0.0000                                   0.0000
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.3115                                   0.7970
# 	->Macro Avg.                                 0.2429                                   0.2978
# 	->Micro Avg.                                 0.3426                                   0.3426
# 	======================================================================================================
# Epoch 11/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 8.772 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.36606                        Loss: 1.3782
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4539                                   0.2013
# 	dandelion                                    0.3840                                   0.6116
# 	rose                                         0.0000                                   0.0000
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.3400                                   0.7954
# 	->Macro Avg.                                 0.2356                                   0.3217
# 	->Micro Avg.                                 0.3661                                   0.3661
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 1.994 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.34954                        Loss: 1.4685
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5000                                   0.2353
# 	dandelion                                    0.3556                                   0.6095
# 	rose                                         0.0000                                   0.0000
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.3194                                   0.7005
# 	->Macro Avg.                                 0.2350                                   0.3091
# 	->Micro Avg.                                 0.3495                                   0.3495
# 	======================================================================================================
# Epoch 12/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 8.782 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.37591                        Loss: 1.3614
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4769                                   0.2029
# 	dandelion                                    0.3940                                   0.6378
# 	rose                                         0.2162                                   0.0128
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.3508                                   0.7992
# 	->Macro Avg.                                 0.2876                                   0.3305
# 	->Micro Avg.                                 0.3759                                   0.3759
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 1.908 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.32523                        Loss: 1.4523
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.0000                                   0.0000
# 	dandelion                                    0.3429                                   0.6286
# 	rose                                         0.0000                                   0.0000
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.3124                                   0.7563
# 	->Macro Avg.                                 0.1310                                   0.2770
# 	->Micro Avg.                                 0.3252                                   0.3252
# 	======================================================================================================
# Epoch 13/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 8.895 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.38083                        Loss: 1.3455
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5035                                   0.2340
# 	dandelion                                    0.3938                                   0.6342
# 	rose                                         0.0000                                   0.0000
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.3519                                   0.8107
# 	->Macro Avg.                                 0.2498                                   0.3358
# 	->Micro Avg.                                 0.3808                                   0.3808
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.020 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.33565                        Loss: 1.5193
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4434                                   0.3072
# 	dandelion                                    0.3120                                   0.5810
# 	rose                                         0.0000                                   0.0000
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.3297                                   0.6142
# 	->Macro Avg.                                 0.2170                                   0.3005
# 	->Micro Avg.                                 0.3356                                   0.3356
# 	======================================================================================================
# Epoch 14/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 8.735 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.38257                        Loss: 1.3345
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5134                                   0.2504
# 	dandelion                                    0.3997                                   0.6437
# 	rose                                         0.2500                                   0.0016
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.3482                                   0.7942
# 	->Macro Avg.                                 0.3023                                   0.3380
# 	->Micro Avg.                                 0.3826                                   0.3826
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 1.938 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.34028                        Loss: 1.4978
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4204                                   0.4314
# 	dandelion                                    0.3201                                   0.4238
# 	rose                                         0.0000                                   0.0000
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.3240                                   0.7056
# 	->Macro Avg.                                 0.2129                                   0.3122
# 	->Micro Avg.                                 0.3403                                   0.3403
# 	======================================================================================================
# Epoch 15/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 9.047 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.4011                        Loss: 1.3176
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5434                                   0.3486
# 	dandelion                                    0.4087                                   0.6140
# 	rose                                         0.6250                                   0.0080
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.3635                                   0.8259
# 	->Macro Avg.                                 0.3881                                   0.3593
# 	->Micro Avg.                                 0.4011                                   0.4011
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.049 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.3206                        Loss: 1.5014
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.0000                                   0.0000
# 	dandelion                                    0.3557                                   0.5810
# 	rose                                         0.0000                                   0.0000
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.2975                                   0.7868
# 	->Macro Avg.                                 0.1306                                   0.2736
# 	->Micro Avg.                                 0.3206                                   0.3206
# 	======================================================================================================
# Epoch 16/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 8.629 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.39618                        Loss: 1.3055
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5152                                   0.3044
# 	dandelion                                    0.4109                                   0.6164
# 	rose                                         0.1667                                   0.0016
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.3631                                   0.8412
# 	->Macro Avg.                                 0.2912                                   0.3527
# 	->Micro Avg.                                 0.3962                                   0.3962
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.205 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.33449                        Loss: 1.5009
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.1818                                   0.0131
# 	dandelion                                    0.3603                                   0.7000
# 	rose                                         0.0000                                   0.0000
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.3146                                   0.7107
# 	->Macro Avg.                                 0.1713                                   0.2847
# 	->Micro Avg.                                 0.3345                                   0.3345
# 	======================================================================================================
# Epoch 17/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 8.899 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.39618                        Loss: 1.2863
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4729                                   0.3142
# 	dandelion                                    0.4206                                   0.5914
# 	rose                                         0.2447                                   0.0367
# 	sunflower                                    0.0000                                   0.0000
# 	tulip                                        0.3703                                   0.8323
# 	->Macro Avg.                                 0.3017                                   0.3549
# 	->Micro Avg.                                 0.3962                                   0.3962
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 1.925 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.33102                        Loss: 1.5135
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.0000                                   0.0000
# 	dandelion                                    0.3415                                   0.7286
# 	rose                                         0.0000                                   0.0000
# ...
# 	->Macro Avg.                                 0.4755                                   0.4644
# 	->Micro Avg.                                 0.4752                                   0.4752
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 1.871 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.33681                        Loss: 1.5915
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4634                                   0.2484
# 	dandelion                                    0.3227                                   0.4810
# 	rose                                         0.1667                                   0.0382
# 	sunflower                                    0.4615                                   0.4082
# 	tulip                                        0.2838                                   0.4365
# 	->Macro Avg.                                 0.3396                                   0.3224
# 	->Micro Avg.                                 0.3368                                   0.3368
# 	======================================================================================================
# Epoch 26/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 8.151 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.49783                        Loss: 1.1648
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5856                                   0.4141
# 	dandelion                                    0.4464                                   0.6176
# 	rose                                         0.3905                                   0.1053
# 	sunflower                                    0.6135                                   0.6365
# 	tulip                                        0.4699                                   0.6442
# 	->Macro Avg.                                 0.5012                                   0.4835
# 	->Micro Avg.                                 0.4978                                   0.4978
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 1.834 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.36921                        Loss: 1.7142
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5882                                   0.2614
# 	dandelion                                    0.3409                                   0.6476
# 	rose                                         0.4091                                   0.0573
# 	sunflower                                    0.5182                                   0.3878
# 	tulip                                        0.2906                                   0.3909
# 	->Macro Avg.                                 0.4294                                   0.3490
# 	->Micro Avg.                                 0.3692                                   0.3692
# 	======================================================================================================
# Epoch 27/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 8.093 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.50217                        Loss: 1.1448
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5482                                   0.3912
# 	dandelion                                    0.4375                                   0.6069
# 	rose                                         0.4589                                   0.1069
# 	sunflower                                    0.6544                                   0.6655
# 	tulip                                        0.4761                                   0.6696
# 	->Macro Avg.                                 0.5150                                   0.4880
# 	->Micro Avg.                                 0.5022                                   0.5022
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 1.828 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.34259                        Loss: 1.7008
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4124                                   0.4771
# 	dandelion                                    0.2938                                   0.2476
# 	rose                                         0.3021                                   0.1847
# 	sunflower                                    0.4500                                   0.4286
# 	tulip                                        0.2883                                   0.4010
# 	->Macro Avg.                                 0.3493                                   0.3478
# 	->Micro Avg.                                 0.3426                                   0.3426
# 	======================================================================================================
# Epoch 28/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 8.266 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.51636                        Loss: 1.1366
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.5864                                   0.4223
# 	dandelion                                    0.4397                                   0.5891
# 	rose                                         0.4550                                   0.1531
# 	sunflower                                    0.6727                                   0.6980
# 	tulip                                        0.4916                                   0.6658
# 	->Macro Avg.                                 0.5291                                   0.5056
# 	->Micro Avg.                                 0.5164                                   0.5164
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 2.051 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.35995                        Loss: 1.7997
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4902                                   0.3268
# 	dandelion                                    0.3199                                   0.6048
# 	rose                                         0.1905                                   0.0255
# 	sunflower                                    0.5195                                   0.2721
# 	tulip                                        0.3371                                   0.4569
# 	->Macro Avg.                                 0.3714                                   0.3372
# 	->Micro Avg.                                 0.3600                                   0.3600
# 	======================================================================================================
# Epoch 29/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 9.350 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.53229                        Loss: 1.1119
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.6046                                   0.4779
# 	dandelion                                    0.4598                                   0.5903
# 	rose                                         0.4478                                   0.1643
# 	sunflower                                    0.6759                                   0.7116
# 	tulip                                        0.5077                                   0.6722
# 	->Macro Avg.                                 0.5391                                   0.5232
# 	->Micro Avg.                                 0.5323                                   0.5323
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 1.931 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.34954                        Loss: 1.8207
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.4609                                   0.3856
# 	dandelion                                    0.3048                                   0.4238
# 	rose                                         0.2564                                   0.1274
# 	sunflower                                    0.5000                                   0.3129
# 	tulip                                        0.3212                                   0.4467
# 	->Macro Avg.                                 0.3687                                   0.3393
# 	->Micro Avg.                                 0.3495                                   0.3495
# 	======================================================================================================
# Epoch 30/30
# 	Training
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]    108/108 Waiting for 8.425 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.53171                        Loss: 1.1076
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.6038                                   0.4190
# 	dandelion                                    0.4511                                   0.6247
# 	rose                                         0.4409                                   0.1308
# 	sunflower                                    0.7025                                   0.7253
# 	tulip                                        0.5103                                   0.6950
# 	->Macro Avg.                                 0.5417                                   0.5190
# 	->Micro Avg.                                 0.5317                                   0.5317
# 	======================================================================================================
# 	Validation
# 	[████████████████████████████████████████████████████████████████████████████████████████████████████]     27/27 Waiting for 1.880 seconds
# 	======================================================================================================
# 	Classification Statistics                    Accuracy: 0.34838                        Loss: 1.7889
# 	======================================================================================================
# 	Class                                        Precision                                Recall
# 	------------------------------------------------------------------------------------------------------
# 	daisy                                        0.3934                                   0.4706
# 	dandelion                                    0.2902                                   0.2667
# 	rose                                         0.2542                                   0.1911
# 	sunflower                                    0.6190                                   0.3537
# 	tulip                                        0.3182                                   0.4619
# 	->Macro Avg.                                 0.3750                                   0.3488
# 	->Micro Avg.                                 0.3484                                   0.3484
# 	======================================================================================================

# %% [markdown]
# # Comparative Analyse

# %%
models = [mlp_stats, cnn_stats, lstm_stats, scnn_stats]

# %% [markdown]
# ### Extracting Visualization

# %%
# Define line plots
# Loss
loss = figure(width=800, height=400, title="Loss")
delta_loss = figure(width=800, height=400, title="Overfitting")

loss.add_layout(Legend(), 'right')
delta_loss.add_layout(Legend(), 'right')

loss.line([0], [0.5], line_width=2, legend_label="Training", line_dash="dashed",line_color="black")
delta_loss.yaxis.axis_label = "Val - Train Loss"

for fig in [loss, delta_loss]:
    fig.xaxis.axis_label = 'epoch'

# Create auxiliar arrays
x_epoches = np.arange(EPOCHS)

# Plot lines
for stats in models:
    label = stats["Label"]
    color = stats["Color"]
    line_w = 3

    # Plot loss data
    loss.line(x_epoches, stats["Validation"]["Loss"], line_width=line_w, legend_label=label,line_color=color)
    loss.line(x_epoches, stats["Training"]["Loss"], line_width=line_w, line_dash="dashed", line_color=color)

    delta = stats["Validation"]["Loss"] - stats["Training"]["Loss"]
    delta_loss.line(x_epoches, delta, line_width=line_w, legend_label=label, line_color=color)

# %%
# Prepare histograms
model_labels = []
model_colors = []

total_time_values = [[],[]]
epoch_time_values = [[],[]]

parameters = []

acc  = [[],[]]
pre  = [[],[]]
rec  = [[],[]]

class_labels = ["Daisy", "Dandelion", "Rose", "Sunflower", "Tulip", "Macro Avg.", "Micro Avg."]

for stats in models:
    label = stats["Label"]
    color = stats["Color"]
    model_labels.append(label)
    model_colors.append(color)

    total_time_values[0].append(stats["Training"]["Time"])
    epoch_time_values[0].append(stats["Training"]["Time/Epoch"])
    total_time_values[1].append(stats["Validation"]["Time"])
    epoch_time_values[1].append(stats["Validation"]["Time/Epoch"])


    parameters.append(stats["Parameters"])

    idx_t = -1
    idx_v = -1
    for i in range(len(stats["Training"]["Accuracy"])):
        if stats["Training"]["Accuracy"][i] > stats["Training"]["Accuracy"][idx_t]:
            idx_t = i
        if stats["Validation"]["Accuracy"][i] > stats["Validation"]["Accuracy"][idx_v]:
            idx_v = i
    
    acc[0].append(stats["Training"]["Accuracy"][idx_t])
    acc[1].append(stats["Validation"]["Accuracy"][idx_v])
    
    pre[0].append(stats["Training"]["Precision"][idx_t])
    pre[1].append(stats["Validation"]["Precision"][idx_v])
    
    rec[0].append(stats["Training"]["Recall"][idx_t])
    rec[1].append(stats["Validation"]["Recall"][idx_v])


pre = np.array(pre)
t_pre = {
    "Label": class_labels,
    "MLP":  pre[0,0],
    "CNN":  pre[0,1],
    "LSTM": pre[0,2],
    "SCNN": pre[0,3],
}
t_pre = ColumnDataSource(data=t_pre)
v_pre = {
    "Label": class_labels,
    "MLP":  pre[1,0],
    "CNN":  pre[1,1],
    "LSTM": pre[1,2],
    "SCNN": pre[1,3],
}
v_pre = ColumnDataSource(data=v_pre)

rec = np.array(rec)
t_rec = {
    "Label": class_labels,
    "MLP":  rec[0,0],
    "CNN":  rec[0,1],
    "LSTM": rec[0,2],
    "SCNN": rec[0,3],
}
t_rec = ColumnDataSource(data=t_rec)
v_rec = {
    "Label": class_labels,
    "MLP":  rec[1,0],
    "CNN":  rec[1,1],
    "LSTM": rec[1,2],
    "SCNN": rec[1,3],
}
v_rec = ColumnDataSource(data=v_rec)

# %%
# Time related
total_time = figure(x_range=model_labels, width=800, height=400, title="Total Running Time")
epoch_time = figure(x_range=model_labels, width=800, height=400, title="Time per Epoch")

total_time.vbar(x=model_labels, top=total_time_values[0], color="navy", width=0.75,legend_label="Training")
total_time.vbar(x=model_labels, top=total_time_values[1], color="orange", width=0.5,legend_label="Validation")

epoch_time.vbar(x=model_labels, top=epoch_time_values[0], color="navy", width=0.75,legend_label="Training")
epoch_time.vbar(x=model_labels, top=epoch_time_values[1], color="orange", width=0.5,legend_label="Validation")

for fig in [total_time, epoch_time]:
    fig.legend.location = 'top_left'
    fig.yaxis.axis_label = 'seconds'
    fig.y_range.start = 0

# %%
# Parameter
param = figure(x_range=model_labels, width=800, height=400, title="Parameters")
param_exp = figure(x_range=model_labels, width=800, height=400, title="Parameters", y_axis_type="log",  y_range = [10 ** 6, 10 ** 8])

param.vbar(x=model_labels, top=parameters, color="navy", width=0.75)
param_exp.vbar(x=model_labels, bottom=[10 ** 0]*len(model_labels), top=parameters, color="navy", width=0.75)

param.y_range.start = 0

# %%
# Metrics
t_accuracy  = figure(x_range=model_labels, width=800, height=400, title="Training Accuracy")
v_accuracy  = figure(x_range=model_labels, width=800, height=400, title="Validation Accuracy")

t_precision = figure(x_range=class_labels, width=800, height=400, title="Training Precision")
v_precision = figure(x_range=class_labels, width=800, height=400, title="Validation Precision")

t_recall    = figure(x_range=class_labels, width=800, height=400, title="Training Recall")
v_recall    = figure(x_range=class_labels, width=800, height=400, title="Validation Recall")

for fig in [
    t_accuracy, t_precision, t_recall,
    v_accuracy, v_precision, v_recall
]:
    fig.y_range.start=0
    fig.y_range.end=1
    fig.add_layout(Legend(), 'right')

t_accuracy.vbar(x=model_labels, top=acc[0], color="navy", width=0.75)
v_accuracy.vbar(x=model_labels, top=acc[1], color="navy", width=0.75)

for i, model in enumerate(model_labels):
    color = model_colors[i]

    offset = -0.27
    step = 0.18
    width = 0.15

    t_precision.vbar(x=dodge('Label', offset+i*step, range=t_precision.x_range),
                     top=model, color=color, width=width, legend_label=model, source=t_pre)
    v_precision.vbar(x=dodge('Label', offset+i*step, range=v_precision.x_range),
                     top=model, color=color, width=width, legend_label=model, source=v_pre)

    t_recall.vbar(x=dodge('Label', offset+i*step, range=t_recall.x_range),
                       top=model, color=color, width=width, legend_label=model, source=t_rec)
    v_recall.vbar(x=dodge('Label', offset+i*step, range=v_recall.x_range),
                       top=model, color=color, width=width, legend_label=model, source=v_rec)

# %% [markdown]
# ### Visualizing

# %%
# Increase font size and make them all bold
for fig in [
    param, param_exp,
    loss, delta_loss,
    total_time, epoch_time,
    t_accuracy, v_accuracy,
    t_precision, v_precision,
    t_recall, v_recall,
]:
    fig.title.text_font_size = "15pt"
    fig.title.padding = 5
    
    fig.yaxis.major_label_text_font_size = "12pt"
    fig.yaxis.major_label_text_font_style = "bold"
    fig.yaxis.axis_label_text_font_size = "12pt"
    fig.yaxis.axis_label_text_font_style = "bold"
    
    fig.xaxis.major_label_text_font_size = "12pt"
    fig.xaxis.major_label_text_font_style = "bold"
    fig.xaxis.axis_label_text_font_size = "12pt"
    fig.xaxis.axis_label_text_font_style = "bold"

# %%
# Create tabs
tabs = Tabs(tabs=[
    TabPanel(child=column(param, param_exp), title="Size"),
    TabPanel(child=column(loss, delta_loss), title="Loss"),
    TabPanel(child=column(total_time, epoch_time), title="Time"),
    TabPanel(child=column(t_accuracy, v_accuracy), title="Accuracy"),
    TabPanel(child=column(t_precision, v_precision), title="Precision"),
    TabPanel(child=column(t_recall, v_recall), title="Recall"),
])

# Show the tabs
show(tabs)
# Out:
#   <div id="f3783977-549f-4353-b47e-f44b36a78c89" data-root-id="p1846" style="display: contents;"></div>
